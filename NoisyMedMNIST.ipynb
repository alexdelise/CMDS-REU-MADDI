# %%
import math
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from torchvision.transforms import Compose, ToTensor, GaussianBlur
import matplotlib.pyplot as plt
import numpy as np
import torchvision.transforms.functional as TF

# MedMNIST import
import medmnist
from medmnist import INFO

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# --- MedMNIST Data setup ---
data_flag = 'retinamnist'
info = INFO[data_flag]
DataClass = getattr(medmnist, info['python_class'])
train_dataset = DataClass(split='train', download=True)
numSamples = len(train_dataset)
# Out:
# Using device: cuda
# Using downloaded and verified file: C:\Users\alexr\.medmnist\retinamnist.npz

# %%
# Prepare data tensors 
def _get_tensor(ds, n):
    """Stack first n samples, convert to float32 in [0,1]."""
    imgs = []
    for i in range(n):
        x, _ = ds[i]
        if isinstance(x, torch.Tensor):
            t = x.float() / 255.0
        elif isinstance(x, np.ndarray):
            t = torch.from_numpy(x).float() / 255.0
            if t.ndim == 3:
                t = t.permute(2, 0, 1)
        else:
            t = TF.to_tensor(x)
        imgs.append(t[0])
    return torch.stack(imgs).to(device)

# Load and prepare dataset
X_raw = _get_tensor(train_dataset, numSamples)  # (N, H, W)
dim = X_raw[0].numel() 
r = 25  # bottleneck 


# X Stuff
X = X_raw.view(numSamples, -1).T  # (dim, numSamples)
gammaX = 1 / (numSamples) * X @ X.T + 1e-5 * torch.eye(dim, device=device)
L_X = torch.linalg.cholesky(gammaX)

# E Stuff
noiseSigma = 0.05
E = torch.randn_like(X) * noiseSigma
gammaE = noiseSigma**2 * torch.eye(dim, device=device)
L_E = torch.linalg.cholesky(gammaE)

# Y Stuff
Y = X + E

# Construct optimal matrices
zeroBlock = torch.zeros_like(L_X)
C = torch.cat([L_X, zeroBlock], dim=1)
U, S, Vh = torch.linalg.svd(C)
U_r, S_r, Vh_r = U[:, :r], torch.diag(S[:r]), Vh[:r, :]
S = torch.cat([L_X, L_E], dim=1)
M_r = U_r @ S_r @ Vh_r @ torch.linalg.pinv(S)

# %%
# --- Autoencoder setup -------------------------------------------------------
batch_size = 128
num_epochs = 200

# Define Linear Autoencoder model
class LinearAutoencoder(nn.Module):
    def __init__(self, input_dim, bottleneck_dim):
        super().__init__()
        self.encoder = nn.Linear(input_dim, bottleneck_dim, bias=False)
        self.decoder = nn.Linear(bottleneck_dim, input_dim, bias=False)

    def forward(self, x):
        return self.decoder(self.encoder(x))

# Instantiate model, optimizer, and loss
model     = LinearAutoencoder(input_dim=dim, bottleneck_dim=r).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.MSELoss()

# Prepare training data tensors
X_tensor = X.T  # Shape (numSamples, dim)
Y_tensor = Y.T

# Training loop using average per-sample L2 error -----------------------------
train_errors = []
for epoch in range(1, num_epochs + 1):
    model.train()
    optimizer.zero_grad()

    outputs = model(Y_tensor)
    target  = X_tensor

    loss = criterion(outputs, target)
    loss.backward()
    optimizer.step()

    # Evaluate and store error after each epoch
    with torch.no_grad():
        A_learned = model.decoder.weight @ model.encoder.weight

        diffs = A_learned @ Y - X
        avg_l2_err = torch.norm(diffs, dim=0).mean().item()

        train_errors.append(avg_l2_err)

print(f"Final average per-sample L2 training error (learned): {train_errors[-1]:.4f}")

# --- Compact 2×2 gallery comparing Optimal vs Learned reconstructions --------
from matplotlib import gridspec

# Example sample index for plotting
idx = 100


# Prepare images for plotting
x_img     = X[:, idx].view(28, 28).cpu()
input_img = Y[:, idx].view(28, 28).cpu()

opt_img   = (M_r @ X)[:, idx].view(28, 28).cpu()
learn_img = (A_learned @ X)[:, idx].view(28, 28).cpu()

# Errors
err_opt   = torch.abs(opt_img   - x_img)
err_learn = torch.abs(learn_img - x_img)
err_vmin, err_vmax = 0.0, max(err_opt.max(), err_learn.max()).item()

# Create 2×3 plot grid (Original/Input | Optimal/Learned | Errors)
fig = plt.figure(figsize=(8, 4.2))
gs  = gridspec.GridSpec(
    2, 4,
    width_ratios=[1, 1, 1, 0.06],
    wspace=0.20, hspace=0.30
)

# row 0
ax = fig.add_subplot(gs[0, 0])
ax.imshow(x_img, cmap='gray')
ax.set_title(r'Original $\mathbf{x}$', pad=4)
ax.axis('off')

ax = fig.add_subplot(gs[0, 1])
ax.imshow(opt_img, cmap='gray')
ax.set_title(r'Optimal $\widehat{\mathbf{A}}_{25} (\mathbf{x} + \varepsilon)$', pad=4)
ax.axis('off')

ax = fig.add_subplot(gs[0, 2])
im = ax.imshow(err_opt, cmap='inferno', vmin=err_vmin, vmax=err_vmax)
ax.set_title(r'$|\mathbf{A}_{\text{opt}} (\mathbf{x} + \varepsilon) - \mathbf{x}|$', pad=4)
ax.axis('off')

# row 1
ax = fig.add_subplot(gs[1, 0])
ax.imshow(input_img, cmap='gray')
ax.set_title(r'Observation $\mathbf{x} + \varepsilon$', pad=4)
ax.axis('off')

ax = fig.add_subplot(gs[1, 1])
ax.imshow(learn_img, cmap='gray')
ax.set_title(r'Learned $\mathbf{A}_{25} (\mathbf{x} + \varepsilon)$', pad=4)
ax.axis('off')

ax = fig.add_subplot(gs[1, 2])
ax.imshow(err_learn, cmap='inferno', vmin=err_vmin, vmax=err_vmax)
ax.set_title(r'$|\mathbf{A}_{25} (\mathbf{x} + \varepsilon) - \mathbf{x}|$', pad=4)
ax.axis('off')

# color-bar
cax = fig.add_subplot(gs[:, 3])
plt.colorbar(im, cax=cax)
cax.yaxis.tick_right()
plt.show()
# Out:
# Final average per-sample L2 training error (learned): 2.7352

# %%
import os, pickle, torch
from collections import defaultdict
import matplotlib.pyplot as plt
import medmnist
from torch import nn, optim
import numpy as np
import torchvision.transforms.functional as TF

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
 
# pastel-Everforest colours 
ef_pastel   = ['#a7c080', '#d3869b', "#83c0c0", '#e69875', '#a988b0', "#b8912f"]
line_styles = {'theory': '-',  'learned': '--'}
markers     = {'theory': 'o',  'learned': 's'}
lw, ms      = 1.5, 4

save_root = "Noisy"
matrices_root = os.path.join(save_root, "MedMNIST", "Matrices")
tests_root    = os.path.join(save_root, "MedMNIST", "Pics")
os.makedirs(matrices_root, exist_ok=True)
os.makedirs(tests_root, exist_ok=True)

def run_rank_sweep(data_flag, ranks, train_epochs=350, lr=1e-3):
    info        = INFO[data_flag]
    DataClass   = getattr(medmnist, info['python_class'])
    train_ds    = DataClass(split='train', download=True)

    numSamples  = len(train_ds)
    X_raw       = _get_tensor(train_ds, numSamples)
    dim         = X_raw[0].numel()

    X = X_raw.view(numSamples, -1).T  # (dim, numSamples)

    noiseSigma = 0.05
    E = torch.randn_like(X) * noiseSigma
    Y = X + E

    gammaX = 1 / numSamples * X @ X.T + 1e-5 * torch.eye(dim, device=device)
    gammaE = noiseSigma**2 * torch.eye(dim, device=device)

    L_X = torch.linalg.cholesky(gammaX)
    L_E = torch.linalg.cholesky(gammaE)

    zeroBlock = torch.zeros_like(L_X)
    C = torch.cat([L_X, zeroBlock], dim=1)
    U, S, Vh = torch.linalg.svd(C)

    S_full = torch.cat([L_X, L_E], dim=1)

    theory_err, learned_err = [], []
    ds_dir = os.path.join(matrices_root, data_flag)
    os.makedirs(ds_dir, exist_ok=True)

    for r in ranks:
        if r % 100 == 0:
            print(f"On Rank {r}")

        U_r = U[:, :r]
        S_r = torch.diag(S[:r])
        Vh_r = Vh[:r, :]
        M_r = U_r @ S_r @ Vh_r @ torch.linalg.pinv(S_full)

        X_recon = M_r @ Y
        diffs_opt = X_recon - X
        avg_l2_opt = torch.norm(diffs_opt, dim=0).mean().item()
        theory_err.append(avg_l2_opt)

        model = LinearAutoencoder(dim, r).to(device)
        optimizer = optim.Adam(model.parameters(), lr=lr)
        criterion = nn.MSELoss()

        X_tensor = X.T
        Y_tensor = Y.T

        for _ in range(train_epochs):
            model.train()
            optimizer.zero_grad()
            outputs = model(Y_tensor)
            loss = criterion(outputs, X_tensor)
            loss.backward()
            optimizer.step()

        with torch.no_grad():
            A_learned = model.decoder.weight @ model.encoder.weight
            diffs_learn = A_learned @ X - X
            avg_l2_learn = torch.norm(diffs_learn, dim=0).mean().item()
        learned_err.append(avg_l2_learn)

        dump_path = os.path.join(ds_dir, f"rank_{r:03d}.pkl")
        with open(dump_path, "wb") as f:
            pickle.dump(
                {
                    "optimalMatrix": M_r.cpu(),
                    "encoderWeight": model.encoder.weight.cpu(),
                    "decoderWeight": model.decoder.weight.cpu(),
                },
                f,
                protocol=pickle.HIGHEST_PROTOCOL,
            )

    return theory_err, learned_err

# run all requested datasets (original sizes of: 200k, 100k, 50k, 10k, 1k)
datasets  = ['tissuemnist', 'chestmnist', 'organamnist', 'retinamnist']
ranks     = list(range(25, 776, 25))
results   = defaultdict(dict)
num_epochs = 200 # define here for training / plot naming

for flag in datasets:
    print(f"\n▶ Running rank sweep for {flag} …")
    th, le = run_rank_sweep(flag, ranks, train_epochs=num_epochs)
    results[flag]['theory']  = th
    results[flag]['learned'] = le
# Out:
# ▶ Running rank sweep for tissuemnist …
# Using downloaded and verified file: C:\Users\alexr\.medmnist\tissuemnist.npz
# On Rank 100
# On Rank 200
# On Rank 300
# On Rank 400
# On Rank 500
# On Rank 600
# On Rank 700
#
# ▶ Running rank sweep for chestmnist …
# Using downloaded and verified file: C:\Users\alexr\.medmnist\chestmnist.npz
# On Rank 100
# On Rank 200
# On Rank 300
# On Rank 400
# On Rank 500
# On Rank 600
# On Rank 700
#
# ▶ Running rank sweep for organamnist …
# Using downloaded and verified file: C:\Users\alexr\.medmnist\organamnist.npz
# On Rank 100
# On Rank 200
# On Rank 300
# On Rank 400
# On Rank 500
# On Rank 600
# On Rank 700
#
# ▶ Running rank sweep for retinamnist …
# Using downloaded and verified file: C:\Users\alexr\.medmnist\retinamnist.npz
# On Rank 100
# On Rank 200
# On Rank 300
# On Rank 400
# On Rank 500
# On Rank 600
# On Rank 700

# %%
# ── combined plot -----------------------------------------------------------
plt.figure(figsize=(7.8, 4.7))
short_label = {'theory': 'O', 'learned': 'L'}

for i, flag in enumerate(datasets):
    col = ef_pastel[i % len(ef_pastel)]
    for kind in ('theory', 'learned'):
        plt.plot(ranks,
                 results[flag][kind],
                 line_styles[kind],
                 marker=markers[kind],
                 color=col,
                 lw=lw,
                 ms=ms,
                 label=f"{flag} ({short_label[kind]})")


plt.xlabel('Rank $r$')
plt.ylabel(r'Average $\ell_2$ Reconstruction Error')
plt.yscale('log')
#plt.title('Average $\ell_2$ Error vs. Rank (Affine Linear)')
plt.legend(ncol=3, fontsize='small')
plt.tight_layout()

# Save final plot with shortened name including epoch info
plot_path = os.path.join(tests_root, f"noisy_ranksweep_{num_epochs}ep.png")
plt.savefig(plot_path)
plt.show()

# %%
# ── Inspect stored matrices & compare singular values (4 decimals) ─────────
#    • Lists datasets / ranks, loads each pickle
#    • Computes singular values of
#        – Bayes–optimal map  Mr
#        – Learned map        A = W_dec @ W_enc
#    • Prints top-k singular values (rounded to 4 decimals) and relative ℓ2 error

import os, pickle, torch

base_dir  = "Noisy/MedMNIST/Matrices"  # updated save path for Affine Linear sweep
top_k     = 10                              # how many singular values to show
torch.set_printoptions(edgeitems=3, linewidth=120, sci_mode=False)

for dataset in sorted(os.listdir(base_dir)):
    ds_dir = os.path.join(base_dir, dataset)
    if not os.path.isdir(ds_dir):
        continue

    print(f"\n══════════  {dataset.upper()}  ══════════")
    for fname in sorted(fn for fn in os.listdir(ds_dir) if fn.endswith(".pkl")):
        rank   = int(fname.split("_")[1].split(".")[0])        # rank_050.pkl → 50
        fpath  = os.path.join(ds_dir, fname)

        # ── load matrices ───────────────────────────────────────────────────
        with open(fpath, "rb") as f:
            mats = pickle.load(f)

        Mr   = mats["optimalMatrix"]
        Wenc = mats["encoderWeight"]
        Wdec = mats["decoderWeight"]
        #bvec = mats["biasVector"]       # also load biasVector if needed later
        A    = Wdec @ Wenc              # learned full map

        # ── singular values ────────────────────────────────────────────────
        s_opt    = torch.linalg.svdvals(Mr)
        s_learn  = torch.linalg.svdvals(A)

        rel_err = torch.norm(s_opt - s_learn) / torch.norm(s_opt)

        # Round singular values to 4 decimal places for print
        s_opt_rounded   = [round(v.item(), 4) for v in s_opt[:top_k]]
        s_learn_rounded = [round(v.item(), 4) for v in s_learn[:top_k]]

        print(f"\n— Rank {rank:3d} —  ({fpath})")
        print(f"Relative ℓ₂ error on singular values: {rel_err:.3e}")
        print(f"Top {top_k} σ(M_r):", s_opt_rounded)
        print(f"Top {top_k} σ(A)  :", s_learn_rounded)

        # Uncomment next lines if you want FULL singular value lists
        # print("\nAll σ(M_r):\n", s_opt.cpu())
        # print("\nAll σ(A):\n",   s_learn.cpu())
# Out:
# ══════════  BREASTMNIST  ══════════
#
# — Rank  25 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_025.pkl)
# Relative ℓ₂ error on singular values: 7.337e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [2.3706, 2.0844, 1.9541, 1.9053, 1.8829, 1.8282, 1.8208, 1.8069, 1.7579, 1.7462]
#
# — Rank  50 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_050.pkl)
# Relative ℓ₂ error on singular values: 3.431e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [2.0102, 1.7349, 1.6559, 1.5951, 1.5565, 1.5316, 1.4885, 1.45, 1.4141, 1.4039]
#
# — Rank  75 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_075.pkl)
# Relative ℓ₂ error on singular values: 2.447e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.8585, 1.5583, 1.541, 1.4916, 1.4736, 1.4496, 1.4333, 1.4049, 1.3521, 1.3156]
#
# — Rank 100 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_100.pkl)
# Relative ℓ₂ error on singular values: 2.230e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.749, 1.4862, 1.4475, 1.4155, 1.4002, 1.3819, 1.3682, 1.3497, 1.3404, 1.3334]
#
# — Rank 125 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_125.pkl)
# Relative ℓ₂ error on singular values: 2.306e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.7983, 1.4175, 1.4073, 1.3687, 1.3567, 1.3427, 1.3338, 1.309, 1.301, 1.2862]
#
# — Rank 150 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_150.pkl)
# Relative ℓ₂ error on singular values: 2.334e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.5781, 1.3783, 1.3612, 1.3482, 1.3435, 1.3275, 1.2921, 1.2887, 1.2734, 1.2677]
#
# — Rank 175 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_175.pkl)
# Relative ℓ₂ error on singular values: 2.430e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.6234, 1.3595, 1.3262, 1.3229, 1.3004, 1.2939, 1.2759, 1.2683, 1.2655, 1.2545]
#
# — Rank 200 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_200.pkl)
# Relative ℓ₂ error on singular values: 2.415e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.5516, 1.3279, 1.3075, 1.3011, 1.29, 1.2775, 1.2663, 1.2527, 1.2451, 1.2393]
#
# — Rank 225 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_225.pkl)
# Relative ℓ₂ error on singular values: 2.376e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.5716, 1.3128, 1.3044, 1.2949, 1.2849, 1.2766, 1.2617, 1.2545, 1.2461, 1.242]
#
# — Rank 250 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_250.pkl)
# Relative ℓ₂ error on singular values: 2.345e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.563, 1.3076, 1.2895, 1.2768, 1.2727, 1.2588, 1.2423, 1.2347, 1.2263, 1.2193]
#
# — Rank 275 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_275.pkl)
# Relative ℓ₂ error on singular values: 2.262e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.4557, 1.2995, 1.282, 1.267, 1.2579, 1.2545, 1.2408, 1.2262, 1.222, 1.2149]
#
# — Rank 300 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_300.pkl)
# Relative ℓ₂ error on singular values: 2.186e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.5324, 1.2655, 1.2558, 1.2548, 1.2433, 1.2374, 1.2205, 1.2168, 1.2105, 1.2042]
#
# — Rank 325 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_325.pkl)
# Relative ℓ₂ error on singular values: 2.168e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.5155, 1.2773, 1.2683, 1.2538, 1.2423, 1.2344, 1.231, 1.2294, 1.2236, 1.2068]
#
# — Rank 350 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_350.pkl)
# Relative ℓ₂ error on singular values: 2.138e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.483, 1.2599, 1.2473, 1.2388, 1.2378, 1.2277, 1.2153, 1.211, 1.2076, 1.2044]
#
# — Rank 375 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_375.pkl)
# Relative ℓ₂ error on singular values: 2.117e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.4803, 1.2576, 1.2531, 1.238, 1.2273, 1.2213, 1.212, 1.209, 1.2023, 1.1999]
#
# — Rank 400 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_400.pkl)
# Relative ℓ₂ error on singular values: 2.165e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.4958, 1.2553, 1.252, 1.2262, 1.2247, 1.2164, 1.2124, 1.2072, 1.2051, 1.1993]
#
# — Rank 425 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_425.pkl)
# Relative ℓ₂ error on singular values: 2.140e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.3949, 1.2534, 1.2401, 1.2317, 1.2291, 1.2212, 1.2106, 1.2057, 1.1972, 1.1899]
#
# — Rank 450 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_450.pkl)
# Relative ℓ₂ error on singular values: 2.174e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.4019, 1.2374, 1.2321, 1.222, 1.2178, 1.2051, 1.2004, 1.1969, 1.194, 1.1871]
#
# — Rank 475 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_475.pkl)
# Relative ℓ₂ error on singular values: 2.221e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.4898, 1.2478, 1.2321, 1.2269, 1.2099, 1.2062, 1.2012, 1.1953, 1.1924, 1.1817]
#
# — Rank 500 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_500.pkl)
# Relative ℓ₂ error on singular values: 2.248e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.3363, 1.2416, 1.2303, 1.2276, 1.2178, 1.2029, 1.1987, 1.1946, 1.1918, 1.179]
#
# — Rank 525 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_525.pkl)
# Relative ℓ₂ error on singular values: 2.292e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.4206, 1.2351, 1.2238, 1.2206, 1.2065, 1.2038, 1.1956, 1.192, 1.1832, 1.1792]
#
# — Rank 550 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_550.pkl)
# Relative ℓ₂ error on singular values: 2.329e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.3825, 1.2287, 1.2242, 1.2122, 1.2034, 1.1989, 1.1954, 1.1922, 1.1829, 1.1799]
#
# — Rank 575 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_575.pkl)
# Relative ℓ₂ error on singular values: 2.361e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.2971, 1.2398, 1.2256, 1.2194, 1.215, 1.2043, 1.1952, 1.1905, 1.1883, 1.1824]
#
# — Rank 600 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_600.pkl)
# Relative ℓ₂ error on singular values: 2.402e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.3726, 1.2345, 1.2265, 1.2189, 1.2136, 1.2016, 1.1935, 1.1912, 1.1828, 1.1736]
#
# — Rank 625 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_625.pkl)
# Relative ℓ₂ error on singular values: 2.465e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.4451, 1.2307, 1.2191, 1.2137, 1.2009, 1.1977, 1.1968, 1.1832, 1.1798, 1.17]
#
# — Rank 650 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_650.pkl)
# Relative ℓ₂ error on singular values: 2.476e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.3007, 1.2288, 1.216, 1.2065, 1.202, 1.1934, 1.1893, 1.1839, 1.1808, 1.174]
#
# — Rank 675 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_675.pkl)
# Relative ℓ₂ error on singular values: 2.500e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.3109, 1.2267, 1.2108, 1.2065, 1.2013, 1.1961, 1.188, 1.1793, 1.1778, 1.1762]
#
# — Rank 700 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_700.pkl)
# Relative ℓ₂ error on singular values: 2.542e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.4512, 1.2173, 1.2118, 1.2024, 1.2015, 1.1992, 1.1917, 1.1831, 1.1784, 1.1708]
#
# — Rank 725 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_725.pkl)
# Relative ℓ₂ error on singular values: 2.563e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.317, 1.2263, 1.2143, 1.2124, 1.1983, 1.1917, 1.1891, 1.1797, 1.1763, 1.1707]
#
# — Rank 750 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_750.pkl)
# Relative ℓ₂ error on singular values: 2.603e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.4331, 1.2204, 1.2078, 1.1992, 1.1921, 1.188, 1.184, 1.177, 1.1736, 1.1664]
#
# — Rank 775 —  (Noisy/MedMNIST/Matrices\breastmnist\rank_775.pkl)
# Relative ℓ₂ error on singular values: 2.615e-01
# Top 10 σ(M_r): [1.0001, 0.9993, 0.9987, 0.9982, 0.9973, 0.9965, 0.9959, 0.9942, 0.9931, 0.9918]
# Top 10 σ(A)  : [1.2644, 1.2176, 1.2076, 1.1999, 1.1956, 1.1915, 1.1873, 1.1802, 1.1756, 1.1722]
#
# ══════════  CHESTMNIST  ══════════
#
# — Rank  25 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_025.pkl)
# Relative ℓ₂ error on singular values: 8.505e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [2.6076, 2.167, 2.0998, 2.0602, 1.9756, 1.9379, 1.9266, 1.8872, 1.8579, 1.8442]
#
# — Rank  50 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_050.pkl)
# Relative ℓ₂ error on singular values: 4.155e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [2.2618, 1.7839, 1.7417, 1.6553, 1.6418, 1.6129, 1.5623, 1.5499, 1.5185, 1.4963]
#
# — Rank  75 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_075.pkl)
# Relative ℓ₂ error on singular values: 2.714e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [2.1527, 1.6662, 1.5675, 1.5576, 1.5061, 1.4294, 1.4143, 1.3917, 1.3693, 1.3375]
#
# — Rank 100 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_100.pkl)
# Relative ℓ₂ error on singular values: 2.050e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.9571, 1.5368, 1.4619, 1.4506, 1.4188, 1.3611, 1.2938, 1.2668, 1.2574, 1.241]
#
# — Rank 125 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_125.pkl)
# Relative ℓ₂ error on singular values: 1.910e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.9836, 1.4596, 1.4232, 1.4024, 1.4021, 1.3756, 1.2609, 1.2172, 1.2016, 1.1883]
#
# — Rank 150 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_150.pkl)
# Relative ℓ₂ error on singular values: 1.781e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.9039, 1.4275, 1.3907, 1.3649, 1.3555, 1.334, 1.256, 1.2009, 1.1787, 1.1715]
#
# — Rank 175 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_175.pkl)
# Relative ℓ₂ error on singular values: 1.647e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.7729, 1.4166, 1.3863, 1.349, 1.331, 1.3226, 1.2855, 1.1722, 1.1479, 1.1153]
#
# — Rank 200 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_200.pkl)
# Relative ℓ₂ error on singular values: 1.574e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.7376, 1.3639, 1.335, 1.3308, 1.3066, 1.2765, 1.2645, 1.1472, 1.1086, 1.0945]
#
# — Rank 225 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_225.pkl)
# Relative ℓ₂ error on singular values: 1.507e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.6518, 1.3332, 1.3161, 1.3115, 1.2916, 1.2764, 1.261, 1.1716, 1.1099, 1.0892]
#
# — Rank 250 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_250.pkl)
# Relative ℓ₂ error on singular values: 1.533e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.7232, 1.3517, 1.3268, 1.2922, 1.2691, 1.2614, 1.254, 1.2102, 1.1739, 1.1453]
#
# — Rank 275 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_275.pkl)
# Relative ℓ₂ error on singular values: 1.524e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.6624, 1.3034, 1.2957, 1.2859, 1.2692, 1.2563, 1.2483, 1.1652, 1.1506, 1.1277]
#
# — Rank 300 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_300.pkl)
# Relative ℓ₂ error on singular values: 1.519e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.5972, 1.2955, 1.2867, 1.2766, 1.2503, 1.2404, 1.2358, 1.2093, 1.1902, 1.1757]
#
# — Rank 325 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_325.pkl)
# Relative ℓ₂ error on singular values: 1.602e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.6976, 1.2988, 1.2851, 1.2532, 1.2463, 1.2242, 1.2156, 1.2019, 1.1739, 1.1635]
#
# — Rank 350 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_350.pkl)
# Relative ℓ₂ error on singular values: 1.631e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.6964, 1.2764, 1.2649, 1.2586, 1.2455, 1.2253, 1.2141, 1.1968, 1.1893, 1.1592]
#
# — Rank 375 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_375.pkl)
# Relative ℓ₂ error on singular values: 1.656e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.5803, 1.2644, 1.2549, 1.2527, 1.2392, 1.2272, 1.2198, 1.2048, 1.1869, 1.1734]
#
# — Rank 400 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_400.pkl)
# Relative ℓ₂ error on singular values: 1.734e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.6115, 1.2694, 1.257, 1.2495, 1.2402, 1.2323, 1.2148, 1.2044, 1.1927, 1.1846]
#
# — Rank 425 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_425.pkl)
# Relative ℓ₂ error on singular values: 1.790e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.6216, 1.2764, 1.2701, 1.2268, 1.2234, 1.212, 1.2069, 1.1991, 1.1853, 1.1693]
#
# — Rank 450 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_450.pkl)
# Relative ℓ₂ error on singular values: 1.867e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.5784, 1.2543, 1.2427, 1.2367, 1.2247, 1.2205, 1.2062, 1.1982, 1.1808, 1.173]
#
# — Rank 475 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_475.pkl)
# Relative ℓ₂ error on singular values: 1.899e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.5012, 1.2818, 1.2602, 1.2496, 1.222, 1.2187, 1.201, 1.1896, 1.1731, 1.1612]
#
# — Rank 500 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_500.pkl)
# Relative ℓ₂ error on singular values: 1.975e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.6124, 1.264, 1.2466, 1.2341, 1.2318, 1.2213, 1.2104, 1.2046, 1.1947, 1.1855]
#
# — Rank 525 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_525.pkl)
# Relative ℓ₂ error on singular values: 2.040e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.6376, 1.2508, 1.2423, 1.2316, 1.2247, 1.2145, 1.206, 1.1948, 1.1841, 1.1745]
#
# — Rank 550 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_550.pkl)
# Relative ℓ₂ error on singular values: 2.093e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.5613, 1.2337, 1.2284, 1.2202, 1.2109, 1.2004, 1.1971, 1.1886, 1.1851, 1.1639]
#
# — Rank 575 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_575.pkl)
# Relative ℓ₂ error on singular values: 2.119e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.5283, 1.2418, 1.2281, 1.2257, 1.2101, 1.2083, 1.1965, 1.1842, 1.1802, 1.175]
#
# — Rank 600 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_600.pkl)
# Relative ℓ₂ error on singular values: 2.178e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.5564, 1.2284, 1.2248, 1.2178, 1.2103, 1.205, 1.2022, 1.1851, 1.1791, 1.1726]
#
# — Rank 625 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_625.pkl)
# Relative ℓ₂ error on singular values: 2.239e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.6207, 1.2359, 1.2297, 1.2226, 1.2162, 1.2099, 1.1955, 1.1885, 1.1714, 1.1646]
#
# — Rank 650 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_650.pkl)
# Relative ℓ₂ error on singular values: 2.274e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.5418, 1.232, 1.2206, 1.2066, 1.2018, 1.1974, 1.1924, 1.1761, 1.1713, 1.1659]
#
# — Rank 675 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_675.pkl)
# Relative ℓ₂ error on singular values: 2.324e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.505, 1.2284, 1.2252, 1.2131, 1.207, 1.2005, 1.1985, 1.1946, 1.1716, 1.1638]
#
# — Rank 700 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_700.pkl)
# Relative ℓ₂ error on singular values: 2.349e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.3831, 1.2366, 1.2289, 1.2189, 1.2142, 1.1936, 1.1904, 1.1842, 1.1757, 1.1629]
#
# — Rank 725 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_725.pkl)
# Relative ℓ₂ error on singular values: 2.405e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.5499, 1.2355, 1.2188, 1.207, 1.2005, 1.1965, 1.1951, 1.1776, 1.1654, 1.1605]
#
# — Rank 750 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_750.pkl)
# Relative ℓ₂ error on singular values: 2.438e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.4589, 1.2279, 1.2165, 1.2111, 1.2017, 1.192, 1.1896, 1.1831, 1.1804, 1.1727]
#
# — Rank 775 —  (Noisy/MedMNIST/Matrices\chestmnist\rank_775.pkl)
# Relative ℓ₂ error on singular values: 2.503e-01
# Top 10 σ(M_r): [0.9999, 0.9993, 0.999, 0.9988, 0.9987, 0.9978, 0.9969, 0.9945, 0.9944, 0.9932]
# Top 10 σ(A)  : [1.5692, 1.2361, 1.2221, 1.2123, 1.203, 1.1922, 1.1898, 1.1846, 1.1755, 1.1716]
#
# ══════════  ORGANAMNIST  ══════════
#
# — Rank  25 —  (Noisy/MedMNIST/Matrices\organamnist\rank_025.pkl)
# Relative ℓ₂ error on singular values: 6.595e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [2.3071, 1.9225, 1.8899, 1.8302, 1.8091, 1.7819, 1.7095, 1.7029, 1.6954, 1.6762]
#
# — Rank  50 —  (Noisy/MedMNIST/Matrices\organamnist\rank_050.pkl)
# Relative ℓ₂ error on singular values: 2.823e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.9055, 1.6286, 1.6008, 1.5389, 1.4473, 1.4273, 1.403, 1.3982, 1.3725, 1.3493]
#
# — Rank  75 —  (Noisy/MedMNIST/Matrices\organamnist\rank_075.pkl)
# Relative ℓ₂ error on singular values: 2.231e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.6902, 1.4941, 1.4349, 1.4224, 1.3944, 1.3676, 1.2885, 1.262, 1.2216, 1.2169]
#
# — Rank 100 —  (Noisy/MedMNIST/Matrices\organamnist\rank_100.pkl)
# Relative ℓ₂ error on singular values: 2.607e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.6105, 1.3988, 1.372, 1.3585, 1.3382, 1.3121, 1.2726, 1.2353, 1.2097, 1.1841]
#
# — Rank 125 —  (Noisy/MedMNIST/Matrices\organamnist\rank_125.pkl)
# Relative ℓ₂ error on singular values: 3.147e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.5383, 1.3608, 1.3474, 1.3459, 1.3137, 1.2968, 1.2833, 1.2814, 1.2615, 1.2391]
#
# — Rank 150 —  (Noisy/MedMNIST/Matrices\organamnist\rank_150.pkl)
# Relative ℓ₂ error on singular values: 3.588e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.4949, 1.3543, 1.3174, 1.3019, 1.2959, 1.2841, 1.2651, 1.2543, 1.2356, 1.2129]
#
# — Rank 175 —  (Noisy/MedMNIST/Matrices\organamnist\rank_175.pkl)
# Relative ℓ₂ error on singular values: 3.949e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.4618, 1.3158, 1.3085, 1.2906, 1.2664, 1.2586, 1.2538, 1.2454, 1.2326, 1.2248]
#
# — Rank 200 —  (Noisy/MedMNIST/Matrices\organamnist\rank_200.pkl)
# Relative ℓ₂ error on singular values: 4.282e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.3763, 1.279, 1.2677, 1.2596, 1.2435, 1.2364, 1.2317, 1.2259, 1.2218, 1.2111]
#
# — Rank 225 —  (Noisy/MedMNIST/Matrices\organamnist\rank_225.pkl)
# Relative ℓ₂ error on singular values: 4.570e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.386, 1.278, 1.2553, 1.2522, 1.2488, 1.236, 1.2258, 1.2203, 1.214, 1.2064]
#
# — Rank 250 —  (Noisy/MedMNIST/Matrices\organamnist\rank_250.pkl)
# Relative ℓ₂ error on singular values: 4.809e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.413, 1.2556, 1.2471, 1.2441, 1.2386, 1.2234, 1.2174, 1.2111, 1.2093, 1.2075]
#
# — Rank 275 —  (Noisy/MedMNIST/Matrices\organamnist\rank_275.pkl)
# Relative ℓ₂ error on singular values: 5.052e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.3258, 1.247, 1.2406, 1.2234, 1.2189, 1.214, 1.209, 1.2007, 1.1973, 1.1914]
#
# — Rank 300 —  (Noisy/MedMNIST/Matrices\organamnist\rank_300.pkl)
# Relative ℓ₂ error on singular values: 5.232e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.3503, 1.2443, 1.2249, 1.2203, 1.2165, 1.2045, 1.2002, 1.1967, 1.1906, 1.1891]
#
# — Rank 325 —  (Noisy/MedMNIST/Matrices\organamnist\rank_325.pkl)
# Relative ℓ₂ error on singular values: 5.414e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.3282, 1.2279, 1.2258, 1.2176, 1.2091, 1.2028, 1.1953, 1.1919, 1.182, 1.1794]
#
# — Rank 350 —  (Noisy/MedMNIST/Matrices\organamnist\rank_350.pkl)
# Relative ℓ₂ error on singular values: 5.580e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.3354, 1.2248, 1.2235, 1.21, 1.205, 1.193, 1.1903, 1.1835, 1.1766, 1.1755]
#
# — Rank 375 —  (Noisy/MedMNIST/Matrices\organamnist\rank_375.pkl)
# Relative ℓ₂ error on singular values: 5.718e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.269, 1.2141, 1.2088, 1.2075, 1.2009, 1.1956, 1.1942, 1.1837, 1.1771, 1.1727]
#
# — Rank 400 —  (Noisy/MedMNIST/Matrices\organamnist\rank_400.pkl)
# Relative ℓ₂ error on singular values: 5.870e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.3009, 1.2183, 1.2127, 1.2023, 1.1963, 1.1933, 1.1902, 1.1827, 1.172, 1.171]
#
# — Rank 425 —  (Noisy/MedMNIST/Matrices\organamnist\rank_425.pkl)
# Relative ℓ₂ error on singular values: 5.989e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.3029, 1.2074, 1.2033, 1.1982, 1.1953, 1.1847, 1.1824, 1.1737, 1.166, 1.1625]
#
# — Rank 450 —  (Noisy/MedMNIST/Matrices\organamnist\rank_450.pkl)
# Relative ℓ₂ error on singular values: 6.117e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.3237, 1.217, 1.202, 1.2005, 1.1941, 1.1869, 1.1859, 1.1797, 1.1713, 1.1702]
#
# — Rank 475 —  (Noisy/MedMNIST/Matrices\organamnist\rank_475.pkl)
# Relative ℓ₂ error on singular values: 6.219e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.2897, 1.2142, 1.1974, 1.1947, 1.1881, 1.1781, 1.1737, 1.1671, 1.164, 1.161]
#
# — Rank 500 —  (Noisy/MedMNIST/Matrices\organamnist\rank_500.pkl)
# Relative ℓ₂ error on singular values: 6.320e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.3009, 1.2023, 1.1952, 1.191, 1.1877, 1.1806, 1.1767, 1.1714, 1.165, 1.1638]
#
# — Rank 525 —  (Noisy/MedMNIST/Matrices\organamnist\rank_525.pkl)
# Relative ℓ₂ error on singular values: 6.410e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.3118, 1.2101, 1.2022, 1.1924, 1.1838, 1.1791, 1.1761, 1.1693, 1.1675, 1.1622]
#
# — Rank 550 —  (Noisy/MedMNIST/Matrices\organamnist\rank_550.pkl)
# Relative ℓ₂ error on singular values: 6.516e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.292, 1.2061, 1.1919, 1.1841, 1.1816, 1.1717, 1.1688, 1.1654, 1.1626, 1.1615]
#
# — Rank 575 —  (Noisy/MedMNIST/Matrices\organamnist\rank_575.pkl)
# Relative ℓ₂ error on singular values: 6.598e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.2649, 1.1944, 1.1866, 1.1805, 1.1781, 1.1741, 1.1699, 1.1633, 1.1626, 1.1588]
#
# — Rank 600 —  (Noisy/MedMNIST/Matrices\organamnist\rank_600.pkl)
# Relative ℓ₂ error on singular values: 6.670e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.3145, 1.1878, 1.1864, 1.1805, 1.1789, 1.1735, 1.1656, 1.1621, 1.1585, 1.1528]
#
# — Rank 625 —  (Noisy/MedMNIST/Matrices\organamnist\rank_625.pkl)
# Relative ℓ₂ error on singular values: 6.753e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.2643, 1.2015, 1.1989, 1.1843, 1.1805, 1.1728, 1.1686, 1.1653, 1.1601, 1.1587]
#
# — Rank 650 —  (Noisy/MedMNIST/Matrices\organamnist\rank_650.pkl)
# Relative ℓ₂ error on singular values: 6.829e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.2325, 1.1996, 1.1937, 1.1845, 1.1752, 1.1709, 1.1627, 1.1612, 1.1555, 1.1551]
#
# — Rank 675 —  (Noisy/MedMNIST/Matrices\organamnist\rank_675.pkl)
# Relative ℓ₂ error on singular values: 6.888e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.2217, 1.1934, 1.1842, 1.1769, 1.1742, 1.1685, 1.1617, 1.1557, 1.1544, 1.1534]
#
# — Rank 700 —  (Noisy/MedMNIST/Matrices\organamnist\rank_700.pkl)
# Relative ℓ₂ error on singular values: 6.956e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.2521, 1.1844, 1.1774, 1.1751, 1.17, 1.1633, 1.1572, 1.1549, 1.1498, 1.1453]
#
# — Rank 725 —  (Noisy/MedMNIST/Matrices\organamnist\rank_725.pkl)
# Relative ℓ₂ error on singular values: 7.012e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.2077, 1.1865, 1.1778, 1.1736, 1.1721, 1.1666, 1.1642, 1.1572, 1.1549, 1.1512]
#
# — Rank 750 —  (Noisy/MedMNIST/Matrices\organamnist\rank_750.pkl)
# Relative ℓ₂ error on singular values: 7.073e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.2439, 1.1847, 1.1807, 1.1753, 1.1671, 1.1605, 1.1588, 1.1526, 1.1498, 1.1465]
#
# — Rank 775 —  (Noisy/MedMNIST/Matrices\organamnist\rank_775.pkl)
# Relative ℓ₂ error on singular values: 7.123e-01
# Top 10 σ(M_r): [0.9999, 0.9996, 0.9996, 0.9994, 0.9988, 0.9986, 0.9981, 0.9979, 0.9978, 0.9974]
# Top 10 σ(A)  : [1.2354, 1.1838, 1.1798, 1.1755, 1.1677, 1.1582, 1.1574, 1.1534, 1.1516, 1.1499]
#
# ══════════  ORGANCMNIST  ══════════
#
# — Rank  25 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_025.pkl)
# Relative ℓ₂ error on singular values: 5.125e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.9407, 1.8433, 1.7799, 1.6796, 1.6318, 1.5967, 1.5745, 1.5486, 1.534, 1.5203]
#
# — Rank  50 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_050.pkl)
# Relative ℓ₂ error on singular values: 2.302e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.5855, 1.5194, 1.4931, 1.4619, 1.4313, 1.4083, 1.3666, 1.3454, 1.2916, 1.2844]
#
# — Rank  75 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_075.pkl)
# Relative ℓ₂ error on singular values: 2.221e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.5326, 1.4062, 1.4015, 1.3812, 1.3551, 1.3339, 1.3278, 1.3184, 1.2894, 1.2767]
#
# — Rank 100 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_100.pkl)
# Relative ℓ₂ error on singular values: 2.617e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.4138, 1.3452, 1.337, 1.3314, 1.321, 1.3091, 1.2967, 1.2874, 1.2711, 1.2634]
#
# — Rank 125 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_125.pkl)
# Relative ℓ₂ error on singular values: 3.109e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.3363, 1.3329, 1.3154, 1.3029, 1.2967, 1.2721, 1.2688, 1.2586, 1.2533, 1.24]
#
# — Rank 150 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_150.pkl)
# Relative ℓ₂ error on singular values: 3.503e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.329, 1.2858, 1.2741, 1.263, 1.2543, 1.2513, 1.2406, 1.2386, 1.2304, 1.2195]
#
# — Rank 175 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_175.pkl)
# Relative ℓ₂ error on singular values: 3.838e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.318, 1.2681, 1.2549, 1.2486, 1.2258, 1.2226, 1.2194, 1.2146, 1.207, 1.2031]
#
# — Rank 200 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_200.pkl)
# Relative ℓ₂ error on singular values: 4.149e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.2518, 1.2352, 1.2344, 1.229, 1.2189, 1.2128, 1.2088, 1.2047, 1.203, 1.1971]
#
# — Rank 225 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_225.pkl)
# Relative ℓ₂ error on singular values: 4.401e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.2671, 1.2341, 1.2265, 1.2177, 1.212, 1.2066, 1.1998, 1.1916, 1.1899, 1.1844]
#
# — Rank 250 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_250.pkl)
# Relative ℓ₂ error on singular values: 4.646e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.2534, 1.2272, 1.2158, 1.2122, 1.2016, 1.2009, 1.196, 1.1874, 1.1829, 1.1799]
#
# — Rank 275 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_275.pkl)
# Relative ℓ₂ error on singular values: 4.859e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.2533, 1.2194, 1.2035, 1.2015, 1.1974, 1.1911, 1.1879, 1.1867, 1.179, 1.1735]
#
# — Rank 300 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_300.pkl)
# Relative ℓ₂ error on singular values: 5.052e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.2188, 1.2116, 1.2025, 1.1969, 1.1904, 1.1871, 1.1836, 1.1812, 1.1713, 1.1684]
#
# — Rank 325 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_325.pkl)
# Relative ℓ₂ error on singular values: 5.236e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.2705, 1.2004, 1.1961, 1.1933, 1.1898, 1.1799, 1.1749, 1.1695, 1.1673, 1.1654]
#
# — Rank 350 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_350.pkl)
# Relative ℓ₂ error on singular values: 5.390e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.2003, 1.1933, 1.1894, 1.1857, 1.1804, 1.1785, 1.1671, 1.1664, 1.1607, 1.1564]
#
# — Rank 375 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_375.pkl)
# Relative ℓ₂ error on singular values: 5.516e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.2014, 1.1925, 1.184, 1.1802, 1.1792, 1.175, 1.1669, 1.1641, 1.1588, 1.1569]
#
# — Rank 400 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_400.pkl)
# Relative ℓ₂ error on singular values: 5.663e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.1986, 1.1891, 1.1841, 1.1797, 1.1717, 1.1676, 1.1666, 1.1622, 1.1572, 1.1524]
#
# — Rank 425 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_425.pkl)
# Relative ℓ₂ error on singular values: 5.773e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.2274, 1.1818, 1.172, 1.1676, 1.1671, 1.1646, 1.1618, 1.156, 1.1524, 1.15]
#
# — Rank 450 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_450.pkl)
# Relative ℓ₂ error on singular values: 5.889e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.1941, 1.1814, 1.1719, 1.1697, 1.1621, 1.1593, 1.1567, 1.1519, 1.1476, 1.1438]
#
# — Rank 475 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_475.pkl)
# Relative ℓ₂ error on singular values: 5.984e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.1924, 1.1738, 1.1667, 1.163, 1.1601, 1.1541, 1.1522, 1.1484, 1.1454, 1.1429]
#
# — Rank 500 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_500.pkl)
# Relative ℓ₂ error on singular values: 6.084e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.2009, 1.1679, 1.164, 1.1584, 1.1529, 1.1515, 1.1478, 1.1469, 1.1431, 1.1404]
#
# — Rank 525 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_525.pkl)
# Relative ℓ₂ error on singular values: 6.183e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.1937, 1.1749, 1.1675, 1.162, 1.1595, 1.1543, 1.1502, 1.1464, 1.1409, 1.1404]
#
# — Rank 550 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_550.pkl)
# Relative ℓ₂ error on singular values: 6.265e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.1779, 1.1665, 1.1622, 1.1593, 1.1518, 1.1492, 1.1435, 1.1413, 1.1409, 1.1355]
#
# — Rank 575 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_575.pkl)
# Relative ℓ₂ error on singular values: 6.355e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.183, 1.1706, 1.1582, 1.1549, 1.1534, 1.1501, 1.1447, 1.1401, 1.1381, 1.1342]
#
# — Rank 600 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_600.pkl)
# Relative ℓ₂ error on singular values: 6.430e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.1887, 1.1667, 1.1626, 1.1579, 1.1548, 1.1535, 1.1471, 1.1458, 1.1402, 1.1356]
#
# — Rank 625 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_625.pkl)
# Relative ℓ₂ error on singular values: 6.480e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.2669, 1.1621, 1.1543, 1.1514, 1.1504, 1.1438, 1.1437, 1.1386, 1.1352, 1.1303]
#
# — Rank 650 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_650.pkl)
# Relative ℓ₂ error on singular values: 6.560e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.2014, 1.1676, 1.1524, 1.1496, 1.1481, 1.1428, 1.1413, 1.1371, 1.1354, 1.1338]
#
# — Rank 675 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_675.pkl)
# Relative ℓ₂ error on singular values: 6.622e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.1828, 1.157, 1.1535, 1.1483, 1.143, 1.1397, 1.1369, 1.1344, 1.1321, 1.1301]
#
# — Rank 700 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_700.pkl)
# Relative ℓ₂ error on singular values: 6.699e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.2052, 1.1664, 1.1626, 1.15, 1.1478, 1.1433, 1.1415, 1.14, 1.1375, 1.1315]
#
# — Rank 725 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_725.pkl)
# Relative ℓ₂ error on singular values: 6.741e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.185, 1.1592, 1.151, 1.1484, 1.1429, 1.139, 1.1373, 1.1324, 1.1272, 1.1258]
#
# — Rank 750 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_750.pkl)
# Relative ℓ₂ error on singular values: 6.770e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.1909, 1.1581, 1.1524, 1.1496, 1.1416, 1.1381, 1.1364, 1.1339, 1.1291, 1.1261]
#
# — Rank 775 —  (Noisy/MedMNIST/Matrices\organcmnist\rank_775.pkl)
# Relative ℓ₂ error on singular values: 6.837e-01
# Top 10 σ(M_r): [1.0003, 0.9998, 0.9995, 0.9995, 0.9989, 0.9986, 0.9982, 0.9978, 0.9974, 0.9973]
# Top 10 σ(A)  : [1.1805, 1.1534, 1.153, 1.1518, 1.144, 1.1387, 1.1363, 1.1345, 1.1321, 1.1288]
#
# ══════════  ORGANSMNIST  ══════════
#
# — Rank  25 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_025.pkl)
# Relative ℓ₂ error on singular values: 5.574e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [2.0421, 1.8514, 1.8306, 1.7053, 1.685, 1.6608, 1.6212, 1.6051, 1.5902, 1.5802]
#
# — Rank  50 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_050.pkl)
# Relative ℓ₂ error on singular values: 2.417e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.627, 1.5251, 1.5029, 1.4936, 1.4835, 1.4408, 1.3843, 1.3617, 1.3362, 1.3078]
#
# — Rank  75 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_075.pkl)
# Relative ℓ₂ error on singular values: 2.217e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.4598, 1.4177, 1.3838, 1.3767, 1.3562, 1.354, 1.3293, 1.3245, 1.3139, 1.2901]
#
# — Rank 100 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_100.pkl)
# Relative ℓ₂ error on singular values: 2.641e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.4088, 1.3752, 1.3411, 1.3298, 1.3138, 1.3079, 1.2975, 1.2887, 1.2833, 1.2661]
#
# — Rank 125 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_125.pkl)
# Relative ℓ₂ error on singular values: 3.077e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.3562, 1.3024, 1.2991, 1.291, 1.2874, 1.2766, 1.2659, 1.2513, 1.2421, 1.2337]
#
# — Rank 150 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_150.pkl)
# Relative ℓ₂ error on singular values: 3.502e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.3461, 1.2928, 1.2773, 1.2632, 1.2543, 1.2479, 1.2418, 1.2372, 1.2326, 1.2238]
#
# — Rank 175 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_175.pkl)
# Relative ℓ₂ error on singular values: 3.861e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.3154, 1.2706, 1.2634, 1.2569, 1.246, 1.2381, 1.2323, 1.2228, 1.2161, 1.2072]
#
# — Rank 200 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_200.pkl)
# Relative ℓ₂ error on singular values: 4.159e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.2781, 1.257, 1.2444, 1.2359, 1.2265, 1.2209, 1.2138, 1.2109, 1.1994, 1.1921]
#
# — Rank 225 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_225.pkl)
# Relative ℓ₂ error on singular values: 4.423e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.2948, 1.2359, 1.2326, 1.2206, 1.2183, 1.2116, 1.2095, 1.2032, 1.1952, 1.1925]
#
# — Rank 250 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_250.pkl)
# Relative ℓ₂ error on singular values: 4.660e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.2492, 1.2395, 1.2183, 1.2126, 1.2053, 1.202, 1.1969, 1.1913, 1.1877, 1.1845]
#
# — Rank 275 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_275.pkl)
# Relative ℓ₂ error on singular values: 4.856e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.2395, 1.221, 1.2151, 1.2067, 1.1994, 1.1965, 1.1916, 1.1866, 1.184, 1.181]
#
# — Rank 300 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_300.pkl)
# Relative ℓ₂ error on singular values: 5.065e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.2582, 1.2137, 1.2046, 1.1956, 1.1907, 1.1801, 1.1759, 1.1714, 1.1685, 1.1653]
#
# — Rank 325 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_325.pkl)
# Relative ℓ₂ error on singular values: 5.215e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.2653, 1.2032, 1.1936, 1.1891, 1.182, 1.1779, 1.1762, 1.1723, 1.1697, 1.1666]
#
# — Rank 350 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_350.pkl)
# Relative ℓ₂ error on singular values: 5.391e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.2354, 1.2069, 1.2025, 1.1995, 1.1866, 1.1828, 1.1787, 1.177, 1.1699, 1.1655]
#
# — Rank 375 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_375.pkl)
# Relative ℓ₂ error on singular values: 5.517e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.2017, 1.193, 1.1864, 1.1796, 1.1718, 1.1712, 1.1656, 1.1572, 1.1546, 1.153]
#
# — Rank 400 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_400.pkl)
# Relative ℓ₂ error on singular values: 5.655e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.2158, 1.1917, 1.1833, 1.175, 1.1726, 1.1708, 1.1679, 1.1594, 1.1591, 1.1514]
#
# — Rank 425 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_425.pkl)
# Relative ℓ₂ error on singular values: 5.762e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.2303, 1.1929, 1.1892, 1.1807, 1.1746, 1.169, 1.1654, 1.1583, 1.1525, 1.151]
#
# — Rank 450 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_450.pkl)
# Relative ℓ₂ error on singular values: 5.892e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.2065, 1.1884, 1.1849, 1.1783, 1.1638, 1.1625, 1.1592, 1.1583, 1.1538, 1.1508]
#
# — Rank 475 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_475.pkl)
# Relative ℓ₂ error on singular values: 6.001e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.2007, 1.1841, 1.1724, 1.1706, 1.1645, 1.1609, 1.1589, 1.1563, 1.1516, 1.1473]
#
# — Rank 500 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_500.pkl)
# Relative ℓ₂ error on singular values: 6.093e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.2156, 1.1782, 1.1741, 1.1674, 1.162, 1.1611, 1.1584, 1.1554, 1.1515, 1.1437]
#
# — Rank 525 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_525.pkl)
# Relative ℓ₂ error on singular values: 6.177e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.2088, 1.1864, 1.175, 1.1698, 1.1638, 1.1586, 1.1583, 1.154, 1.1468, 1.1442]
#
# — Rank 550 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_550.pkl)
# Relative ℓ₂ error on singular values: 6.274e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.185, 1.1737, 1.1697, 1.164, 1.1595, 1.1557, 1.1494, 1.1454, 1.1442, 1.1399]
#
# — Rank 575 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_575.pkl)
# Relative ℓ₂ error on singular values: 6.347e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.179, 1.1636, 1.1613, 1.1591, 1.1551, 1.1503, 1.1495, 1.1415, 1.1412, 1.1402]
#
# — Rank 600 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_600.pkl)
# Relative ℓ₂ error on singular values: 6.420e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.1873, 1.1715, 1.1655, 1.1612, 1.1554, 1.1536, 1.1498, 1.1466, 1.1397, 1.1371]
#
# — Rank 625 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_625.pkl)
# Relative ℓ₂ error on singular values: 6.501e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.2104, 1.1696, 1.1609, 1.155, 1.1525, 1.1498, 1.1468, 1.1422, 1.1404, 1.1376]
#
# — Rank 650 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_650.pkl)
# Relative ℓ₂ error on singular values: 6.542e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.2017, 1.1631, 1.1548, 1.1545, 1.1484, 1.1453, 1.1437, 1.1384, 1.1349, 1.1348]
#
# — Rank 675 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_675.pkl)
# Relative ℓ₂ error on singular values: 6.616e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.2103, 1.1662, 1.1566, 1.1522, 1.1505, 1.1438, 1.1401, 1.1369, 1.1333, 1.1297]
#
# — Rank 700 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_700.pkl)
# Relative ℓ₂ error on singular values: 6.676e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.1848, 1.1602, 1.154, 1.1481, 1.1465, 1.142, 1.1393, 1.1345, 1.1318, 1.1294]
#
# — Rank 725 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_725.pkl)
# Relative ℓ₂ error on singular values: 6.736e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.2062, 1.16, 1.1505, 1.1486, 1.1406, 1.1393, 1.1372, 1.1338, 1.1296, 1.1284]
#
# — Rank 750 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_750.pkl)
# Relative ℓ₂ error on singular values: 6.792e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.2012, 1.1588, 1.1551, 1.1465, 1.1448, 1.1396, 1.1381, 1.1352, 1.1341, 1.1316]
#
# — Rank 775 —  (Noisy/MedMNIST/Matrices\organsmnist\rank_775.pkl)
# Relative ℓ₂ error on singular values: 6.838e-01
# Top 10 σ(M_r): [1.0002, 0.9997, 0.9995, 0.9992, 0.9991, 0.9987, 0.9985, 0.9979, 0.9973, 0.9972]
# Top 10 σ(A)  : [1.1666, 1.1532, 1.1498, 1.1459, 1.1428, 1.1399, 1.1363, 1.1351, 1.1304, 1.1295]
#
# ══════════  RETINAMNIST  ══════════
#
# — Rank  25 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_025.pkl)
# Relative ℓ₂ error on singular values: 8.828e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [2.4773, 2.1988, 2.0629, 1.9932, 1.9918, 1.9365, 1.9043, 1.8453, 1.8326, 1.8257]
#
# — Rank  50 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_050.pkl)
# Relative ℓ₂ error on singular values: 5.185e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# ...
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.7111, 1.3051, 1.2858, 1.2836, 1.2723, 1.2647, 1.1166, 1.046, 1.0024, 0.9893]
#
# — Rank 275 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_275.pkl)
# Relative ℓ₂ error on singular values: 4.691e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.711, 1.3187, 1.2919, 1.276, 1.259, 1.249, 1.1603, 1.1083, 0.9758, 0.9717]
#
# — Rank 300 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_300.pkl)
# Relative ℓ₂ error on singular values: 4.805e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.6045, 1.3008, 1.2878, 1.2591, 1.2551, 1.2317, 1.165, 1.155, 0.9924, 0.9706]
#
# — Rank 325 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_325.pkl)
# Relative ℓ₂ error on singular values: 4.985e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.6349, 1.3026, 1.2784, 1.275, 1.265, 1.2241, 1.1733, 1.1296, 0.973, 0.9349]
#
# — Rank 350 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_350.pkl)
# Relative ℓ₂ error on singular values: 5.132e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.6355, 1.279, 1.2655, 1.2464, 1.2313, 1.228, 1.1853, 1.1362, 0.9636, 0.9272]
#
# — Rank 375 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_375.pkl)
# Relative ℓ₂ error on singular values: 5.234e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.6023, 1.269, 1.257, 1.2433, 1.2287, 1.2078, 1.1789, 1.1324, 0.9532, 0.912]
#
# — Rank 400 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_400.pkl)
# Relative ℓ₂ error on singular values: 5.377e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.6282, 1.2766, 1.2637, 1.2455, 1.2247, 1.2136, 1.1955, 1.1468, 0.9488, 0.936]
#
# — Rank 425 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_425.pkl)
# Relative ℓ₂ error on singular values: 5.477e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.5863, 1.2823, 1.2599, 1.2491, 1.2322, 1.2036, 1.1963, 1.1681, 0.989, 0.9135]
#
# — Rank 450 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_450.pkl)
# Relative ℓ₂ error on singular values: 5.570e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.5791, 1.2826, 1.2619, 1.2454, 1.2387, 1.2006, 1.1866, 1.1439, 1.0144, 0.9094]
#
# — Rank 475 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_475.pkl)
# Relative ℓ₂ error on singular values: 5.681e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.5741, 1.2695, 1.2528, 1.2509, 1.2364, 1.2122, 1.1905, 1.1798, 1.0217, 0.9078]
#
# — Rank 500 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_500.pkl)
# Relative ℓ₂ error on singular values: 5.783e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.5777, 1.2734, 1.2334, 1.2243, 1.2203, 1.2034, 1.2002, 1.1749, 0.9847, 0.8899]
#
# — Rank 525 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_525.pkl)
# Relative ℓ₂ error on singular values: 5.840e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.5606, 1.2591, 1.2502, 1.2315, 1.2229, 1.2048, 1.1655, 1.1472, 1.0117, 0.9217]
#
# — Rank 550 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_550.pkl)
# Relative ℓ₂ error on singular values: 5.910e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.5692, 1.238, 1.2325, 1.2254, 1.2038, 1.1806, 1.1755, 1.1503, 1.03, 0.9282]
#
# — Rank 575 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_575.pkl)
# Relative ℓ₂ error on singular values: 5.971e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.4282, 1.2552, 1.2294, 1.211, 1.2045, 1.1891, 1.1828, 1.1659, 1.019, 0.9061]
#
# — Rank 600 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_600.pkl)
# Relative ℓ₂ error on singular values: 6.057e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.5486, 1.2528, 1.2328, 1.2202, 1.2127, 1.2059, 1.1894, 1.1705, 1.0344, 0.923]
#
# — Rank 625 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_625.pkl)
# Relative ℓ₂ error on singular values: 6.121e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.5243, 1.2645, 1.2409, 1.2267, 1.209, 1.2047, 1.1876, 1.1668, 1.0074, 0.9598]
#
# — Rank 650 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_650.pkl)
# Relative ℓ₂ error on singular values: 6.167e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.5062, 1.2523, 1.2422, 1.2382, 1.2186, 1.2097, 1.1905, 1.1528, 1.0117, 0.9457]
#
# — Rank 675 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_675.pkl)
# Relative ℓ₂ error on singular values: 6.226e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.4992, 1.244, 1.2375, 1.2159, 1.2111, 1.1944, 1.1737, 1.1564, 1.0251, 0.9673]
#
# — Rank 700 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_700.pkl)
# Relative ℓ₂ error on singular values: 6.263e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.5445, 1.2371, 1.2252, 1.2173, 1.196, 1.1909, 1.1867, 1.1413, 1.048, 0.9915]
#
# — Rank 725 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_725.pkl)
# Relative ℓ₂ error on singular values: 6.336e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.5715, 1.2365, 1.2239, 1.2128, 1.2089, 1.196, 1.1866, 1.1507, 1.0452, 0.9603]
#
# — Rank 750 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_750.pkl)
# Relative ℓ₂ error on singular values: 6.361e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.4957, 1.2286, 1.2233, 1.2096, 1.1964, 1.1925, 1.1788, 1.1325, 1.0561, 0.9738]
#
# — Rank 775 —  (Noisy/MedMNIST/Matrices\retinamnist\rank_775.pkl)
# Relative ℓ₂ error on singular values: 6.439e-01
# Top 10 σ(M_r): [1.0, 0.9991, 0.9987, 0.9983, 0.9976, 0.9958, 0.9934, 0.9903, 0.9879, 0.9856]
# Top 10 σ(A)  : [1.5498, 1.2366, 1.2161, 1.2101, 1.1988, 1.1937, 1.1727, 1.1424, 1.0731, 0.9412]
#
# ══════════  TISSUEMNIST  ══════════
#
# — Rank  25 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_025.pkl)
# Relative ℓ₂ error on singular values: 3.656e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.6658, 1.6287, 1.5277, 1.5027, 1.4816, 1.464, 1.4211, 1.3738, 1.3661, 1.3557]
#
# — Rank  50 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_050.pkl)
# Relative ℓ₂ error on singular values: 1.873e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.421, 1.3959, 1.361, 1.3498, 1.3354, 1.3202, 1.3143, 1.2914, 1.2371, 1.2097]
#
# — Rank  75 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_075.pkl)
# Relative ℓ₂ error on singular values: 1.879e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.2938, 1.2771, 1.2683, 1.2525, 1.2427, 1.2347, 1.2315, 1.2218, 1.2033, 1.2016]
#
# — Rank 100 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_100.pkl)
# Relative ℓ₂ error on singular values: 1.986e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.2531, 1.2418, 1.2261, 1.2202, 1.2097, 1.2077, 1.2063, 1.1933, 1.18, 1.1759]
#
# — Rank 125 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_125.pkl)
# Relative ℓ₂ error on singular values: 2.097e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.2016, 1.1925, 1.1865, 1.1778, 1.17, 1.1647, 1.158, 1.1567, 1.1501, 1.1452]
#
# — Rank 150 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_150.pkl)
# Relative ℓ₂ error on singular values: 2.064e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.1832, 1.1658, 1.1602, 1.1524, 1.1518, 1.1439, 1.141, 1.1402, 1.1329, 1.1272]
#
# — Rank 175 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_175.pkl)
# Relative ℓ₂ error on singular values: 2.037e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.1578, 1.1508, 1.1417, 1.1387, 1.1323, 1.1307, 1.1262, 1.1208, 1.1148, 1.1113]
#
# — Rank 200 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_200.pkl)
# Relative ℓ₂ error on singular values: 2.009e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.1517, 1.1454, 1.1392, 1.1366, 1.133, 1.1305, 1.123, 1.1173, 1.1115, 1.1086]
#
# — Rank 225 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_225.pkl)
# Relative ℓ₂ error on singular values: 1.947e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.1306, 1.1255, 1.1201, 1.1173, 1.1136, 1.1131, 1.1049, 1.1035, 1.102, 1.0991]
#
# — Rank 250 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_250.pkl)
# Relative ℓ₂ error on singular values: 1.940e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.1208, 1.1112, 1.1084, 1.1048, 1.1024, 1.0997, 1.0975, 1.0909, 1.0894, 1.0852]
#
# — Rank 275 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_275.pkl)
# Relative ℓ₂ error on singular values: 1.854e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.1113, 1.1051, 1.1021, 1.1004, 1.0972, 1.0941, 1.0915, 1.0881, 1.0854, 1.0836]
#
# — Rank 300 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_300.pkl)
# Relative ℓ₂ error on singular values: 1.836e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.1017, 1.0998, 1.0971, 1.0934, 1.0881, 1.0872, 1.0821, 1.0784, 1.077, 1.0759]
#
# — Rank 325 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_325.pkl)
# Relative ℓ₂ error on singular values: 1.795e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.1069, 1.102, 1.1003, 1.0956, 1.0931, 1.0914, 1.0867, 1.0846, 1.0799, 1.0785]
#
# — Rank 350 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_350.pkl)
# Relative ℓ₂ error on singular values: 1.752e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.1007, 1.0963, 1.0947, 1.0901, 1.0897, 1.0879, 1.0837, 1.0817, 1.0769, 1.0743]
#
# — Rank 375 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_375.pkl)
# Relative ℓ₂ error on singular values: 1.736e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.0935, 1.0912, 1.0873, 1.0824, 1.0817, 1.0797, 1.0751, 1.0706, 1.067, 1.0654]
#
# — Rank 400 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_400.pkl)
# Relative ℓ₂ error on singular values: 1.725e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.0919, 1.0896, 1.0859, 1.083, 1.0793, 1.0746, 1.0734, 1.0707, 1.0693, 1.0683]
#
# — Rank 425 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_425.pkl)
# Relative ℓ₂ error on singular values: 1.675e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.0871, 1.0838, 1.0822, 1.0795, 1.0781, 1.0755, 1.0741, 1.071, 1.0699, 1.0671]
#
# — Rank 450 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_450.pkl)
# Relative ℓ₂ error on singular values: 1.701e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.0932, 1.0874, 1.0831, 1.0819, 1.0785, 1.0743, 1.0696, 1.0665, 1.0645, 1.0619]
#
# — Rank 475 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_475.pkl)
# Relative ℓ₂ error on singular values: 1.698e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.0823, 1.0809, 1.0792, 1.0736, 1.0727, 1.0686, 1.068, 1.0671, 1.0649, 1.0617]
#
# — Rank 500 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_500.pkl)
# Relative ℓ₂ error on singular values: 1.705e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.0811, 1.0775, 1.075, 1.0708, 1.0695, 1.0665, 1.0635, 1.0627, 1.0588, 1.0577]
#
# — Rank 525 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_525.pkl)
# Relative ℓ₂ error on singular values: 1.729e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.0839, 1.0758, 1.0749, 1.07, 1.0688, 1.0658, 1.0641, 1.0635, 1.0593, 1.0575]
#
# — Rank 550 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_550.pkl)
# Relative ℓ₂ error on singular values: 1.724e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.079, 1.0744, 1.0718, 1.0701, 1.0658, 1.0612, 1.0609, 1.0601, 1.0565, 1.0549]
#
# — Rank 575 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_575.pkl)
# Relative ℓ₂ error on singular values: 1.745e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.0853, 1.0783, 1.0724, 1.0705, 1.068, 1.0656, 1.0628, 1.0604, 1.0587, 1.0573]
#
# — Rank 600 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_600.pkl)
# Relative ℓ₂ error on singular values: 1.759e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.0751, 1.0718, 1.0702, 1.0665, 1.0642, 1.0605, 1.06, 1.0578, 1.0553, 1.0519]
#
# — Rank 625 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_625.pkl)
# Relative ℓ₂ error on singular values: 1.791e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.0748, 1.0698, 1.0669, 1.0648, 1.0625, 1.0578, 1.0564, 1.0546, 1.052, 1.0512]
#
# — Rank 650 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_650.pkl)
# Relative ℓ₂ error on singular values: 1.809e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.0691, 1.0684, 1.065, 1.0632, 1.0618, 1.057, 1.0554, 1.0543, 1.0526, 1.0492]
#
# — Rank 675 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_675.pkl)
# Relative ℓ₂ error on singular values: 1.814e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.074, 1.0681, 1.0614, 1.0604, 1.0583, 1.0561, 1.0527, 1.052, 1.0506, 1.0495]
#
# — Rank 700 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_700.pkl)
# Relative ℓ₂ error on singular values: 1.833e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.0669, 1.0647, 1.0629, 1.0603, 1.0568, 1.0544, 1.0538, 1.0528, 1.0497, 1.046]
#
# — Rank 725 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_725.pkl)
# Relative ℓ₂ error on singular values: 1.864e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.0732, 1.0694, 1.066, 1.0639, 1.0618, 1.0583, 1.0557, 1.0529, 1.0508, 1.0481]
#
# — Rank 750 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_750.pkl)
# Relative ℓ₂ error on singular values: 1.882e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.067, 1.0625, 1.061, 1.0593, 1.0568, 1.0553, 1.0516, 1.0482, 1.0463, 1.0451]
#
# — Rank 775 —  (Noisy/MedMNIST/Matrices\tissuemnist\rank_775.pkl)
# Relative ℓ₂ error on singular values: 1.887e-01
# Top 10 σ(M_r): [0.9997, 0.9936, 0.9926, 0.9923, 0.9921, 0.9896, 0.988, 0.9869, 0.9866, 0.9834]
# Top 10 σ(A)  : [1.0669, 1.0646, 1.0619, 1.059, 1.0556, 1.0538, 1.0533, 1.0502, 1.046, 1.0451]
