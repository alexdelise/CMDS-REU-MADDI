# %%
import math
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from torchvision.transforms import Compose, ToTensor, GaussianBlur
import matplotlib.pyplot as plt
import numpy as np
import torchvision.transforms.functional as TF

# MedMNIST import
import medmnist
from medmnist import INFO

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# --- MedMNIST Data setup ---
data_flag = 'retinamnist'
info = INFO[data_flag]
DataClass = getattr(medmnist, info['python_class'])
train_dataset = DataClass(split='train', download=True)
numSamples = len(train_dataset)
# Out:
# Using device: cuda
# Using downloaded and verified file: C:\Users\alexr\.medmnist\retinamnist.npz

# %%
# Prepare data tensors --------------------------------------------------------
def _get_tensor(ds, n):
    """Stack first n samples, convert to float32 in [0,1]."""
    imgs = []
    for i in range(n):
        x, _ = ds[i]
        if isinstance(x, torch.Tensor):
            t = x.float() / 255.0
        elif isinstance(x, np.ndarray):
            t = torch.from_numpy(x).float() / 255.0
            if t.ndim == 3:
                t = t.permute(2, 0, 1)
        else:
            t = TF.to_tensor(x)
        imgs.append(t[0])
    return torch.stack(imgs).to(device)

# Prepare dataset
X_raw = _get_tensor(train_dataset, numSamples) 
dim = X_raw[0].numel()  # 28*28 = 784
r = 25  # bottleneck / testing rank

# X Stuff
X = X_raw.view(numSamples, -1).T
gammaX = (1/numSamples) * X @ X.T + 1e-5 * torch.eye(dim, device=device)
L_X = torch.linalg.cholesky(gammaX)

# F Stuff
blurKernelSizeF = 5
blurSigmaF = 1.0
forwardBlur = GaussianBlur(kernel_size=blurKernelSizeF, sigma=blurSigmaF)
basisImages = torch.eye(dim).reshape(dim, 1, 28, 28)
F_cols = []
for j in range(dim):
    F_cols.append(forwardBlur(basisImages[j]).flatten())
F = torch.stack(F_cols, dim=1).to(device)
FX = F @ X

# E Stuff
noiseSigma = 0.05
E = torch.randn_like(FX) * noiseSigma
gammaE = noiseSigma**2 * torch.eye(dim, device=device)

# Y Stuff
Y = FX + E
gammaY = F @ gammaX @ F.T + gammaE + 1e-5 * torch.eye(dim, device=device)
L_Y = torch.linalg.cholesky(gammaY)


# Theoretical Optimizer
C = F @ L_X
U, S, Vh = torch.linalg.svd(C)
U_r, S_r, Vh_r = U[:, :r], torch.diag(S[:r]), Vh[:r, :]
C_r = U_r @ S_r @ Vh_r
M_r = C_r @ torch.linalg.pinv(L_X)

# %%
# ── quick 1×3 preview: (\bar{X}, F \bar{X}, F \bar{X} + E) ─────────────────────
import os
import matplotlib.pyplot as plt

# random training-set index
#idx = np.random.randint(0, numSamples)
idx = 100

# (i) original image  →  (H,W)
orig_img = X_raw[idx].cpu()          # already in [0,1]
if orig_img.ndim == 3:               # safety: drop channel dim
    orig_img = orig_img[0]

# (ii) blurred image  F \bar{X}
blur_img = forwardBlur(orig_img.unsqueeze(0)).squeeze(0).cpu()

# (iii) blurred + noise image  F \bar{X} + E
noise            = torch.randn_like(blur_img) * noiseSigma
blur_noise_img   = (blur_img + noise).clamp(0, 1).cpu()

# ── plot & save ──────────────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 3, figsize=(7.5, 2.7))
axes[0].imshow(orig_img,        cmap='gray')
axes[0].set_title(r'Original $\mathbf{x}$')
axes[0].axis('off')

axes[1].imshow(blur_img,        cmap='gray')
axes[1].set_title(r'Blurred $\mathbf{F} \mathbf{x}$')
axes[1].axis('off')

axes[2].imshow(blur_noise_img,  cmap='gray')
axes[2].set_title(r'Observation $\mathbf{y} = \mathbf{F} \mathbf{x} + \varepsilon$')
axes[2].axis('off')

plt.tight_layout()

out_dir = f"E2EForward/MedMNIST/Pics"
os.makedirs(out_dir, exist_ok=True)
plt.savefig(f"{out_dir}/{data_flag}_mapping{idx}_{r}.png", dpi=300)
plt.show()

# %%
# --- Autoencoder setup -------------------------------------------------------
batch_size = 128
num_epochs = 350

X_tensor = X.clone().to(torch.float32)
Y_tensor = Y.clone().to(torch.float32)

class LinearAutoencoder(nn.Module):
    def __init__(self, input_dim, bottleneck_dim):
        super().__init__()
        self.encoder = nn.Linear(input_dim, bottleneck_dim, bias=False)
        self.decoder = nn.Linear(bottleneck_dim, input_dim, bias=False)
    def forward(self, x):
        return self.decoder(self.encoder(x))

model     = LinearAutoencoder(input_dim=dim, bottleneck_dim=r).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.MSELoss()

# Training loop using average per-sample L2 error -----------------------------
train_errors = []
for epoch in range(1, num_epochs + 1):
    model.train()
    optimizer.zero_grad()

    outputs = model(X.T)
    target  = Y.T

    loss = criterion(outputs, target)
    loss.backward()
    optimizer.step()

    # Evaluate average per-sample l2 error
    with torch.no_grad():
        A_learned = model.decoder.weight @ model.encoder.weight
        diffs = A_learned @ X - Y
        avg_l2_err = torch.norm(diffs, dim=0).mean().item()
        train_errors.append(avg_l2_err)


from matplotlib import gridspec

idx = 100

orig_img   = X_raw[idx].view(28, 28).cpu()
y_img      = Y[:, idx].view(28, 28).cpu()
opt_img    = (M_r @ Y)[:, idx].view(28, 28).cpu()
learn_img  = (A_learned @ Y)[:, idx].view(28, 28).cpu()

err_opt   = torch.abs(opt_img   - orig_img)
err_learn = torch.abs(learn_img - orig_img)
err_vmin, err_vmax = 0.0, max(err_opt.max(), err_learn.max()).item()

fig = plt.figure(figsize=(7, 4.2))
gs  = gridspec.GridSpec(
    2, 4,
    width_ratios=[1, 1, 1, 0.06],
    wspace=0.20, hspace=0.30
)

# row 0
ax = fig.add_subplot(gs[0, 0])
ax.imshow(orig_img, cmap='gray')
ax.set_title(r'Original $\mathbf{x}$', pad=4)
ax.axis('off')

ax = fig.add_subplot(gs[0, 1])
ax.imshow(opt_img, cmap='gray')
ax.set_title(fr'Optimal $\widehat{{\mathbf{{A}}}}_{{{r}}} \mathbf{{x}}$', pad=4)
ax.axis('off')

ax = fig.add_subplot(gs[0, 2])
im = ax.imshow(err_opt, cmap='inferno', vmin=err_vmin, vmax=err_vmax)
ax.set_title(fr'$|\widehat{{\mathbf{{A}}}}_{{{r}}} \mathbf{{x}} - \mathbf{{y}}|$', pad=4)
ax.axis('off')

# row 1
ax = fig.add_subplot(gs[1, 0])
ax.imshow(y_img, cmap='gray')
ax.set_title(r'Observation $\mathbf{y}$', pad=4)
ax.axis('off')

ax = fig.add_subplot(gs[1, 1])
ax.imshow(learn_img, cmap='gray')
ax.set_title(fr'Learned $\mathbf{{A}}_{{{r}}} \mathbf{{x}}$', pad=4)
ax.axis('off')

ax = fig.add_subplot(gs[1, 2])
ax.imshow(err_learn, cmap='inferno', vmin=err_vmin, vmax=err_vmax)
ax.set_title(fr'$|\mathbf{{A}}_{{{r}}} \mathbf{{x}} - \mathbf{{y}}|$', pad=4)
ax.axis('off')

# color-bar
cax = fig.add_subplot(gs[:, 3])
plt.colorbar(im, cax=cax)
cax.yaxis.tick_right()
plt.show()

# %%
import os, pickle, torch
from collections import defaultdict
from copy import deepcopy
from torchvision.transforms import GaussianBlur
import matplotlib.pyplot as plt



# where to stash matrices and final plots 
save_root     = "E2EForward"
matrices_root = os.path.join(save_root, "MedMNIST", "Matrices")
tests_root    = os.path.join(save_root, "MedMNIST", "Pics")
os.makedirs(matrices_root, exist_ok=True)
os.makedirs(tests_root, exist_ok=True)

# helper: run rank sweep on ONE MedMNIST subset 
def run_rank_sweep(data_flag, ranks, train_epochs=350, lr=1e-4):
    """Return ([theory avg l2], [AE avg l2]) for the given dataset
       and store matrices to pickles for every rank."""
    info = INFO[data_flag]
    DataClass = getattr(medmnist, info['python_class'])
    train_ds = DataClass(split='train', download=True)

    numSamples = int(0.8 * len(train_ds))
    X_raw = _get_tensor(train_ds, numSamples)
    dim = X_raw[0].numel()

    X = X_raw.view(numSamples, -1).T
    gammaX = (1 / numSamples) * X @ X.T + 1e-5 * torch.eye(dim, device=device)
    L_X = torch.linalg.cholesky(gammaX)

    blurKernelSizeF = 5
    blurSigmaF = 1.0
    blur = GaussianBlur(kernel_size=blurKernelSizeF, sigma=blurSigmaF)
    basisImages = torch.eye(dim).reshape(dim, 1, 28, 28)
    F_cols = [blur(basisImages[j]).flatten() for j in range(dim)]
    F = torch.stack(F_cols, dim=1).to(device)

    FX = F @ X
    noiseSigma = 0.05
    E = torch.randn_like(FX) * noiseSigma
    Y = FX + E

    gammaE = noiseSigma**2 * torch.eye(dim, device=device)
    gammaY = F @ gammaX @ F.T + gammaE + 1e-5 * torch.eye(dim, device=device)
    L_Y = torch.linalg.cholesky(gammaY)

    C = F @ L_X
    U, S, Vh = torch.linalg.svd(C)

    theory_err, learned_err = [], []
    ds_dir = os.path.join(matrices_root, data_flag)
    os.makedirs(ds_dir, exist_ok=True)

    for r in ranks:
        if r % 100 == 0:
            print(f"On Rank {r}")

        U_r = U[:, :r]
        S_r = torch.diag(S[:r])
        Vh_r = Vh[:r, :]
        C_r = U_r @ S_r @ Vh_r
        M_r = C_r @ torch.linalg.pinv(L_X)

        diffs_opt = M_r @ X - Y
        avg_l2_opt = torch.norm(diffs_opt, dim=0).mean().item()
        theory_err.append(avg_l2_opt)

        ae = LinearAutoencoder(dim, r).to(device)
        opt = optim.Adam(ae.parameters(), lr=lr)
        criterion = nn.MSELoss()

        for _ in range(train_epochs):
            opt.zero_grad()
            out = ae(Y.T)
            loss = criterion(out, X.T)
            loss.backward()
            opt.step()

        with torch.no_grad():
            W_enc = ae.encoder.weight.detach().cpu()
            W_dec = ae.decoder.weight.detach().cpu()
            A = W_dec @ W_enc
            diffs_learn = A.to(device) @ Y - X
            avg_l2_learn = torch.norm(diffs_learn, dim=0).mean().item()
        learned_err.append(avg_l2_learn)

        dump_path = os.path.join(ds_dir, f"rank_{r:03d}.pkl")
        with open(dump_path, "wb") as f:
            pickle.dump(
                {
                    "optimalMatrix": M_r.cpu(),
                    "encoderWeight": W_enc,
                    "decoderWeight": W_dec,
                },
                f,
                protocol=pickle.HIGHEST_PROTOCOL,
            )

    return theory_err, learned_err

# run all requested datasets (original sizes of: 200k, 100k, 50k, 10k, 1k)
datasets  = ['tissuemnist', 'chestmnist', 'organamnist', 'retinamnist']
ranks     = list(range(25, 776, 25))
results   = defaultdict(dict)
num_epochs = 200 # define here for training / plot naming

for flag in datasets:
    print(f"\n▶ Running rank sweep for {flag} …")
    th, le = run_rank_sweep(flag, ranks, train_epochs=num_epochs)
    results[flag]['theory']  = th
    results[flag]['learned'] = le
# Out:
# ▶ Running rank sweep for tissuemnist …
# Using downloaded and verified file: C:\Users\alexr\.medmnist\tissuemnist.npz
# On Rank 100
# On Rank 200
# On Rank 300
# On Rank 400
# On Rank 500
# On Rank 600
# On Rank 700
#
# ▶ Running rank sweep for chestmnist …
# Using downloaded and verified file: C:\Users\alexr\.medmnist\chestmnist.npz
# On Rank 100
# On Rank 200
# On Rank 300
# On Rank 400
# On Rank 500
# On Rank 600
# On Rank 700
#
# ▶ Running rank sweep for organamnist …
# Using downloaded and verified file: C:\Users\alexr\.medmnist\organamnist.npz
# On Rank 100
# On Rank 200
# On Rank 300
# On Rank 400
# On Rank 500
# On Rank 600
# On Rank 700
#
# ▶ Running rank sweep for retinamnist …
# Using downloaded and verified file: C:\Users\alexr\.medmnist\retinamnist.npz
# On Rank 100
# On Rank 200
# On Rank 300
# On Rank 400
# On Rank 500
# On Rank 600
# On Rank 700

# %%
# pastel-Everforest colours 
ef_pastel   = ['#a7c080', '#d3869b', "#83c0c0", '#e69875', '#a988b0', "#b8912f"]
line_styles = {'theory': '-',  'learned': '--'}
markers     = {'theory': 'o',  'learned': 's'}
lw, ms      = 1.5, 4


# combined plot
plt.figure(figsize=(7.8, 4.7))
short_label = {'theory': 'O', 'learned': 'L'}

for i, flag in enumerate(datasets):
    col = ef_pastel[i % len(ef_pastel)]
    for kind in ('theory', 'learned'):
        plt.plot(ranks,
                 results[flag][kind],
                 line_styles[kind],
                 marker=markers[kind],
                 color=col,
                 lw=lw,
                 ms=ms, 
                 label=f"{flag} ({short_label[kind]})")

plt.xlabel('Rank $r$')
plt.ylabel(r'Average $\ell_2$ Reconstruction Error')
plt.yscale('log')
#plt.title('Average $\ell_2$ Error vs. Rank')
plt.legend(ncol=3, fontsize='small')
plt.tight_layout()
plt.savefig("E2EForward/MedMNIST/Pics/e2eforward_ranksweep_200ep.png")
plt.show()

# %%
# ── Inspect stored matrices & compare singular values (4 decimals) ─────────
#    • Lists datasets / ranks, loads each pickle
#    • Computes singular values of
#        – Bayes–optimal map  Mr
#        – Learned map        A = W_dec @ W_enc
#    • Prints top-k singular values (rounded to 4 decimals) and relative ℓ2 error

import os, pickle, torch

base_dir  = "E2EForward/MedMNIST/Matrices"
top_k     = 10                              # how many singular values to show
torch.set_printoptions(edgeitems=3, linewidth=120, sci_mode=False)

for dataset in sorted(os.listdir(base_dir)):
    ds_dir = os.path.join(base_dir, dataset)
    if not os.path.isdir(ds_dir):
        continue

    print(f"\n══════════  {dataset.upper()}  ══════════")
    for fname in sorted(fn for fn in os.listdir(ds_dir) if fn.endswith(".pkl")):
        rank   = int(fname.split("_")[1].split(".")[0])        # rank_050.pkl → 50
        fpath  = os.path.join(ds_dir, fname)
 
        # ── load matrices ───────────────────────────────────────────────────
        with open(fpath, "rb") as f:
            mats = pickle.load(f)

        Mr   = mats["optimalMatrix"]
        Wenc = mats["encoderWeight"]
        Wdec = mats["decoderWeight"]
        A    = Wdec @ Wenc                                    # learned full map

        # ── singular values ────────────────────────────────────────────────
        s_opt    = torch.linalg.svdvals(Mr)
        s_learn  = torch.linalg.svdvals(A)

        rel_err = torch.norm(s_opt - s_learn) / torch.norm(s_opt)

        # Round singular values to 4 decimal places for print
        s_opt_rounded   = [round(v.item(), 4) for v in s_opt[:top_k]]
        s_learn_rounded = [round(v.item(), 4) for v in s_learn[:top_k]]

        print(f"\n— Rank {rank:3d} —  ({fpath})")
        #print("optimalMatrix shape :", tuple(Mr.shape))
        #print("encoderWeight shape :", tuple(Wenc.shape))
        #print("decoderWeight shape :", tuple(Wdec.shape))
        print(f"Relative ℓ₂ error on singular values: {rel_err:.3e}")
        print(f"Top {top_k} σ(M_r):", s_opt_rounded)
        print(f"Top {top_k} σ(A)  :", s_learn_rounded)

        # Uncomment next lines if you want FULL singular value lists
        # print("\nAll σ(M_r):\n", s_opt.cpu())
        # print("\nAll σ(A):\n",   s_learn.cpu())
# Out:
# ══════════  BREASTMNIST  ══════════
#
# ══════════  CHESTMNIST  ══════════
#
# — Rank  25 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_025.pkl)
# Relative ℓ₂ error on singular values: 1.035e+00
# Top 10 σ(M_r): [1.0146, 1.0118, 1.011, 1.0053, 0.9893, 0.9882, 0.9853, 0.9814, 0.9585, 0.9524]
# Top 10 σ(A)  : [2.3272, 2.2804, 2.1629, 2.1495, 2.0906, 2.0571, 2.0177, 1.9946, 1.9674, 1.9484]
#
# — Rank  50 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_050.pkl)
# Relative ℓ₂ error on singular values: 5.546e-01
# Top 10 σ(M_r): [1.0152, 1.013, 1.0128, 1.0105, 0.9904, 0.9901, 0.988, 0.9875, 0.9657, 0.9593]
# Top 10 σ(A)  : [1.7987, 1.7166, 1.6762, 1.6376, 1.6262, 1.6076, 1.5919, 1.568, 1.539, 1.5248]
#
# — Rank  75 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_075.pkl)
# Relative ℓ₂ error on singular values: 3.671e-01
# Top 10 σ(M_r): [1.0154, 1.0133, 1.0131, 1.0111, 0.9907, 0.9907, 0.9885, 0.9885, 0.9664, 0.9598]
# Top 10 σ(A)  : [1.5833, 1.5105, 1.4644, 1.4481, 1.4254, 1.4053, 1.3886, 1.3722, 1.3617, 1.3566]
#
# — Rank 100 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_100.pkl)
# Relative ℓ₂ error on singular values: 2.675e-01
# Top 10 σ(M_r): [1.0155, 1.0134, 1.0133, 1.0112, 0.9908, 0.9908, 0.9887, 0.9886, 0.9667, 0.96]
# Top 10 σ(A)  : [1.4795, 1.392, 1.3475, 1.3205, 1.2967, 1.2852, 1.278, 1.2597, 1.2457, 1.2413]
#
# — Rank 125 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_125.pkl)
# Relative ℓ₂ error on singular values: 2.154e-01
# Top 10 σ(M_r): [1.0155, 1.0135, 1.0133, 1.0113, 0.9909, 0.9908, 0.9888, 0.9887, 0.9668, 0.9601]
# Top 10 σ(A)  : [1.498, 1.2732, 1.2597, 1.2462, 1.2309, 1.1973, 1.1935, 1.1871, 1.1769, 1.1671]
#
# — Rank 150 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_150.pkl)
# Relative ℓ₂ error on singular values: 1.865e-01
# Top 10 σ(M_r): [1.0155, 1.0135, 1.0133, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9602]
# Top 10 σ(A)  : [1.3552, 1.2137, 1.1993, 1.1898, 1.1646, 1.1576, 1.1505, 1.1372, 1.1295, 1.1128]
#
# — Rank 175 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_175.pkl)
# Relative ℓ₂ error on singular values: 1.735e-01
# Top 10 σ(M_r): [1.0155, 1.0135, 1.0133, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9602]
# Top 10 σ(A)  : [1.4024, 1.1879, 1.1611, 1.1514, 1.1384, 1.1169, 1.1148, 1.0881, 1.0831, 1.0753]
#
# — Rank 200 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_200.pkl)
# Relative ℓ₂ error on singular values: 1.755e-01
# Top 10 σ(M_r): [1.0155, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3496, 1.16, 1.1241, 1.1163, 1.0874, 1.0715, 1.0689, 1.0616, 1.0537, 1.0515]
#
# — Rank 225 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_225.pkl)
# Relative ℓ₂ error on singular values: 1.766e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.364, 1.1187, 1.0938, 1.0726, 1.0618, 1.0499, 1.0393, 1.0253, 1.0225, 1.0179]
#
# — Rank 250 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_250.pkl)
# Relative ℓ₂ error on singular values: 1.894e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3446, 1.131, 1.0815, 1.079, 1.0573, 1.031, 1.021, 1.0056, 1.002, 0.9973]
#
# — Rank 275 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_275.pkl)
# Relative ℓ₂ error on singular values: 2.031e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.318, 1.0729, 1.0526, 1.0278, 1.0137, 1.01, 0.9981, 0.992, 0.9793, 0.9709]
#
# — Rank 300 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_300.pkl)
# Relative ℓ₂ error on singular values: 2.170e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3046, 1.0709, 1.0507, 1.0384, 1.011, 0.9969, 0.9914, 0.9751, 0.9659, 0.9534]
#
# — Rank 325 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_325.pkl)
# Relative ℓ₂ error on singular values: 2.327e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3098, 1.0716, 1.0384, 1.0137, 1.0051, 0.9883, 0.9786, 0.9649, 0.9555, 0.9449]
#
# — Rank 350 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_350.pkl)
# Relative ℓ₂ error on singular values: 2.508e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3199, 1.112, 1.0496, 0.9908, 0.9806, 0.9723, 0.9619, 0.9571, 0.9479, 0.9411]
#
# — Rank 375 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_375.pkl)
# Relative ℓ₂ error on singular values: 2.596e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2852, 1.1366, 1.0781, 0.9775, 0.9694, 0.9642, 0.9519, 0.9463, 0.9399, 0.9313]
#
# — Rank 400 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_400.pkl)
# Relative ℓ₂ error on singular values: 2.780e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3039, 1.1291, 1.1075, 0.9813, 0.9587, 0.9502, 0.9435, 0.9256, 0.913, 0.9066]
#
# — Rank 425 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_425.pkl)
# Relative ℓ₂ error on singular values: 2.890e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3134, 1.1087, 1.1006, 0.9668, 0.9534, 0.9424, 0.9281, 0.92, 0.9198, 0.9054]
#
# — Rank 450 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_450.pkl)
# Relative ℓ₂ error on singular values: 3.015e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2913, 1.1589, 1.1295, 0.969, 0.9539, 0.9285, 0.9109, 0.9025, 0.8971, 0.887]
#
# — Rank 475 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_475.pkl)
# Relative ℓ₂ error on singular values: 3.131e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2791, 1.127, 1.112, 0.9588, 0.9417, 0.9303, 0.9114, 0.9073, 0.8909, 0.8759]
#
# — Rank 500 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_500.pkl)
# Relative ℓ₂ error on singular values: 3.244e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2729, 1.1514, 1.1101, 0.98, 0.9412, 0.9158, 0.9069, 0.8963, 0.8863, 0.876]
#
# — Rank 525 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_525.pkl)
# Relative ℓ₂ error on singular values: 3.312e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2711, 1.1413, 1.0998, 0.9672, 0.9376, 0.904, 0.893, 0.8819, 0.8764, 0.8677]
#
# — Rank 550 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_550.pkl)
# Relative ℓ₂ error on singular values: 3.426e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2958, 1.1785, 1.1745, 1.0049, 0.9714, 0.8911, 0.8854, 0.8752, 0.8658, 0.8609]
#
# — Rank 575 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_575.pkl)
# Relative ℓ₂ error on singular values: 3.490e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2863, 1.174, 1.1245, 0.9769, 0.9492, 0.8912, 0.8773, 0.8598, 0.8562, 0.8494]
#
# — Rank 600 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_600.pkl)
# Relative ℓ₂ error on singular values: 3.580e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2686, 1.1673, 1.1537, 1.0144, 0.9389, 0.8815, 0.8745, 0.8642, 0.8533, 0.8457]
#
# — Rank 625 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_625.pkl)
# Relative ℓ₂ error on singular values: 3.661e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2733, 1.1946, 1.1385, 0.9857, 0.9403, 0.8856, 0.8725, 0.8653, 0.8509, 0.8417]
#
# — Rank 650 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_650.pkl)
# Relative ℓ₂ error on singular values: 3.706e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2674, 1.1791, 1.175, 1.0215, 0.9709, 0.8785, 0.8745, 0.8651, 0.862, 0.8487]
#
# — Rank 675 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_675.pkl)
# Relative ℓ₂ error on singular values: 3.772e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2757, 1.1782, 1.1693, 1.0014, 0.9624, 0.8843, 0.8652, 0.8627, 0.8423, 0.84]
#
# — Rank 700 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_700.pkl)
# Relative ℓ₂ error on singular values: 3.838e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2735, 1.1957, 1.174, 1.0496, 1.015, 0.8773, 0.8532, 0.8414, 0.8337, 0.8304]
#
# — Rank 725 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_725.pkl)
# Relative ℓ₂ error on singular values: 3.903e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2847, 1.2173, 1.1709, 1.056, 0.9966, 0.8833, 0.8535, 0.8481, 0.8361, 0.821]
#
# — Rank 750 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_750.pkl)
# Relative ℓ₂ error on singular values: 3.938e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2543, 1.1957, 1.1876, 1.0487, 1.002, 0.8802, 0.8408, 0.8291, 0.8241, 0.8179]
#
# — Rank 775 —  (E2EForward/MedMNIST/Matrices\chestmnist\rank_775.pkl)
# Relative ℓ₂ error on singular values: 4.000e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9888, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2495, 1.2232, 1.169, 1.0535, 0.9733, 0.8602, 0.8565, 0.8387, 0.8235, 0.8195]
#
# ══════════  ORGANAMNIST  ══════════
#
# — Rank  25 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_025.pkl)
# Relative ℓ₂ error on singular values: 9.679e-01
# Top 10 σ(M_r): [1.0141, 1.0119, 1.0111, 1.0061, 0.9896, 0.9864, 0.9858, 0.9824, 0.958, 0.955]
# Top 10 σ(A)  : [2.3182, 2.2151, 2.0967, 2.0735, 2.057, 2.0147, 1.9966, 1.9485, 1.9347, 1.8879]
#
# — Rank  50 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_050.pkl)
# Relative ℓ₂ error on singular values: 5.138e-01
# Top 10 σ(M_r): [1.0149, 1.0128, 1.0127, 1.0106, 0.9906, 0.9898, 0.9882, 0.9876, 0.9663, 0.9587]
# Top 10 σ(A)  : [1.804, 1.7122, 1.6561, 1.6492, 1.6106, 1.6057, 1.5966, 1.5566, 1.5268, 1.5191]
#
# — Rank  75 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_075.pkl)
# Relative ℓ₂ error on singular values: 3.333e-01
# Top 10 σ(M_r): [1.0151, 1.0131, 1.0131, 1.0111, 0.9908, 0.9905, 0.9885, 0.9885, 0.9666, 0.9598]
# Top 10 σ(A)  : [1.5153, 1.4974, 1.4901, 1.4565, 1.4173, 1.3941, 1.379, 1.3649, 1.3503, 1.3247]
#
# — Rank 100 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_100.pkl)
# Relative ℓ₂ error on singular values: 2.444e-01
# Top 10 σ(M_r): [1.0153, 1.0133, 1.0132, 1.0112, 0.9909, 0.9907, 0.9887, 0.9887, 0.9667, 0.9601]
# Top 10 σ(A)  : [1.5232, 1.3704, 1.3512, 1.3282, 1.3161, 1.2891, 1.2753, 1.2534, 1.2362, 1.2334]
#
# — Rank 125 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_125.pkl)
# Relative ℓ₂ error on singular values: 1.987e-01
# Top 10 σ(M_r): [1.0154, 1.0134, 1.0133, 1.0113, 0.9909, 0.9908, 0.9888, 0.9887, 0.9668, 0.9601]
# Top 10 σ(A)  : [1.4002, 1.2819, 1.2711, 1.2523, 1.2344, 1.2113, 1.2042, 1.1975, 1.1927, 1.1813]
#
# — Rank 150 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_150.pkl)
# Relative ℓ₂ error on singular values: 1.750e-01
# Top 10 σ(M_r): [1.0154, 1.0135, 1.0133, 1.0114, 0.9909, 0.9909, 0.9888, 0.9887, 0.9668, 0.9602]
# Top 10 σ(A)  : [1.3544, 1.2376, 1.2335, 1.1999, 1.1725, 1.1612, 1.1484, 1.1324, 1.1177, 1.1112]
#
# — Rank 175 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_175.pkl)
# Relative ℓ₂ error on singular values: 1.626e-01
# Top 10 σ(M_r): [1.0155, 1.0136, 1.0134, 1.0114, 0.9909, 0.9909, 0.9889, 0.9888, 0.9668, 0.9602]
# Top 10 σ(A)  : [1.4149, 1.2014, 1.159, 1.1538, 1.15, 1.1108, 1.1082, 1.1021, 1.0843, 1.0792]
#
# — Rank 200 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_200.pkl)
# Relative ℓ₂ error on singular values: 1.629e-01
# Top 10 σ(M_r): [1.0155, 1.0136, 1.0134, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3586, 1.2302, 1.1547, 1.1164, 1.1052, 1.0998, 1.0817, 1.065, 1.0587, 1.0444]
#
# — Rank 225 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_225.pkl)
# Relative ℓ₂ error on singular values: 1.709e-01
# Top 10 σ(M_r): [1.0155, 1.0136, 1.0134, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3389, 1.2405, 1.1104, 1.0952, 1.07, 1.0625, 1.0459, 1.0315, 1.0308, 1.0152]
#
# — Rank 250 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_250.pkl)
# Relative ℓ₂ error on singular values: 1.836e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0134, 1.0114, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3135, 1.2332, 1.115, 1.0723, 1.0568, 1.0309, 1.0174, 1.0101, 1.0058, 0.9995]
#
# — Rank 275 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_275.pkl)
# Relative ℓ₂ error on singular values: 1.993e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0135, 1.0115, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3261, 1.244, 1.1416, 1.0947, 1.0533, 1.0154, 1.0072, 0.992, 0.982, 0.9771]
#
# — Rank 300 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_300.pkl)
# Relative ℓ₂ error on singular values: 2.141e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0135, 1.0115, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3137, 1.2543, 1.0822, 1.0668, 1.0077, 0.9984, 0.9786, 0.9684, 0.9568, 0.9535]
#
# — Rank 325 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_325.pkl)
# Relative ℓ₂ error on singular values: 2.328e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0135, 1.0115, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3281, 1.2531, 1.0834, 1.0203, 0.9959, 0.9742, 0.9717, 0.9591, 0.9475, 0.9341]
#
# — Rank 350 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_350.pkl)
# Relative ℓ₂ error on singular values: 2.477e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0135, 1.0115, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3083, 1.2491, 1.1111, 1.0714, 0.9984, 0.9737, 0.9536, 0.9476, 0.9402, 0.9347]
#
# — Rank 375 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_375.pkl)
# Relative ℓ₂ error on singular values: 2.628e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0135, 1.0115, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3332, 1.2595, 1.1524, 1.1172, 0.9739, 0.9599, 0.9495, 0.9388, 0.9373, 0.9262]
#
# — Rank 400 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_400.pkl)
# Relative ℓ₂ error on singular values: 2.770e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0135, 1.0115, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2773, 1.256, 1.1632, 1.071, 0.9706, 0.9577, 0.9377, 0.9227, 0.9201, 0.9146]
#
# — Rank 425 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_425.pkl)
# Relative ℓ₂ error on singular values: 2.900e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0135, 1.0115, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2841, 1.251, 1.167, 1.1363, 0.9673, 0.9337, 0.9243, 0.9171, 0.9032, 0.8982]
#
# — Rank 450 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_450.pkl)
# Relative ℓ₂ error on singular values: 3.029e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0135, 1.0115, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2889, 1.2633, 1.1831, 1.1136, 0.959, 0.9434, 0.9188, 0.9079, 0.8929, 0.8867]
#
# — Rank 475 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_475.pkl)
# Relative ℓ₂ error on singular values: 3.146e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0135, 1.0115, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2711, 1.2349, 1.1678, 1.0928, 0.9374, 0.9249, 0.9052, 0.9004, 0.8981, 0.8867]
#
# — Rank 500 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_500.pkl)
# Relative ℓ₂ error on singular values: 3.250e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0135, 1.0115, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2777, 1.2508, 1.1914, 1.1485, 0.9328, 0.919, 0.9144, 0.8981, 0.8834, 0.8808]
#
# — Rank 525 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_525.pkl)
# Relative ℓ₂ error on singular values: 3.332e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0135, 1.0115, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2993, 1.2522, 1.1829, 1.1758, 0.9362, 0.9114, 0.9016, 0.8946, 0.8914, 0.8822]
#
# — Rank 550 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_550.pkl)
# Relative ℓ₂ error on singular values: 3.405e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0135, 1.0115, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2811, 1.2351, 1.1848, 1.1678, 0.9415, 0.9091, 0.8851, 0.8798, 0.8734, 0.8581]
#
# — Rank 575 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_575.pkl)
# Relative ℓ₂ error on singular values: 3.517e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0135, 1.0115, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2778, 1.2465, 1.2039, 1.1797, 0.937, 0.9175, 0.9006, 0.8885, 0.8701, 0.8669]
#
# — Rank 600 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_600.pkl)
# Relative ℓ₂ error on singular values: 3.597e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0135, 1.0115, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2996, 1.2573, 1.2136, 1.1962, 0.9795, 0.8993, 0.8862, 0.8806, 0.8604, 0.8552]
#
# — Rank 625 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_625.pkl)
# Relative ℓ₂ error on singular values: 3.642e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0135, 1.0115, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.269, 1.2374, 1.1853, 1.16, 0.9378, 0.8989, 0.877, 0.8754, 0.8581, 0.8488]
#
# — Rank 650 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_650.pkl)
# Relative ℓ₂ error on singular values: 3.719e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0135, 1.0115, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2662, 1.2515, 1.2147, 1.1691, 0.973, 0.9169, 0.8823, 0.8654, 0.8544, 0.8491]
#
# — Rank 675 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_675.pkl)
# Relative ℓ₂ error on singular values: 3.781e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0135, 1.0115, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2593, 1.2219, 1.1889, 1.1765, 0.9271, 0.9132, 0.8713, 0.8539, 0.8495, 0.8473]
#
# — Rank 700 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_700.pkl)
# Relative ℓ₂ error on singular values: 3.855e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0135, 1.0115, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2787, 1.2422, 1.1834, 1.1708, 1.0276, 0.9392, 0.8702, 0.8496, 0.8423, 0.8397]
#
# — Rank 725 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_725.pkl)
# Relative ℓ₂ error on singular values: 3.895e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0135, 1.0115, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2452, 1.2364, 1.1925, 1.1619, 1.0111, 0.9036, 0.8484, 0.8433, 0.8424, 0.8239]
#
# — Rank 750 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_750.pkl)
# Relative ℓ₂ error on singular values: 3.967e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0135, 1.0115, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2407, 1.2225, 1.1982, 1.1739, 0.9826, 0.9129, 0.8645, 0.8533, 0.8307, 0.8229]
#
# — Rank 775 —  (E2EForward/MedMNIST/Matrices\organamnist\rank_775.pkl)
# Relative ℓ₂ error on singular values: 4.006e-01
# Top 10 σ(M_r): [1.0156, 1.0136, 1.0135, 1.0115, 0.991, 0.991, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2759, 1.2485, 1.2067, 1.1611, 0.9995, 0.9208, 0.8656, 0.8548, 0.8416, 0.8293]
#
# ══════════  ORGANCMNIST  ══════════
#
# ══════════  ORGANSMNIST  ══════════
#
# ══════════  RETINAMNIST  ══════════
#
# — Rank  25 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_025.pkl)
# Relative ℓ₂ error on singular values: 1.061e+00
# Top 10 σ(M_r): [1.0142, 0.9917, 0.9882, 0.9845, 0.98, 0.9594, 0.9589, 0.9493, 0.9468, 0.9313]
# Top 10 σ(A)  : [2.3446, 2.1427, 2.1125, 2.0735, 2.0441, 2.0302, 1.9976, 1.9813, 1.923, 1.9159]
#
# — Rank  50 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_050.pkl)
# Relative ℓ₂ error on singular values: 5.813e-01
# Top 10 σ(M_r): [1.0144, 0.9992, 0.9958, 0.9878, 0.9871, 0.974, 0.965, 0.9629, 0.9581, 0.9456]
# Top 10 σ(A)  : [1.7667, 1.7331, 1.6942, 1.6666, 1.6349, 1.6192, 1.6086, 1.588, 1.5642, 1.5435]
#
# — Rank  75 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_075.pkl)
# Relative ℓ₂ error on singular values: 3.827e-01
# Top 10 σ(M_r): [1.0147, 1.0042, 1.0009, 0.9923, 0.99, 0.9884, 0.9797, 0.9734, 0.9656, 0.9553]
# Top 10 σ(A)  : [1.5478, 1.5169, 1.492, 1.4554, 1.4456, 1.4143, 1.4061, 1.3838, 1.3606, 1.3426]
#
# — Rank 100 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_100.pkl)
# Relative ℓ₂ error on singular values: 2.924e-01
# Top 10 σ(M_r): [1.0149, 1.0069, 1.0059, 1.001, 0.9906, 0.9894, 0.9839, 0.9817, 0.9661, 0.9574]
# Top 10 σ(A)  : [1.4769, 1.4076, 1.3842, 1.3442, 1.3196, 1.3051, 1.2957, 1.2749, 1.2652, 1.2459]
#
# — Rank 125 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_125.pkl)
# Relative ℓ₂ error on singular values: 2.330e-01
# Top 10 σ(M_r): [1.0152, 1.0103, 1.0089, 1.006, 0.9908, 0.99, 0.987, 0.9857, 0.9664, 0.9588]
# Top 10 σ(A)  : [1.4779, 1.297, 1.2764, 1.2637, 1.2464, 1.2162, 1.2069, 1.1939, 1.182, 1.1734]
#
# — Rank 150 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_150.pkl)
# Relative ℓ₂ error on singular values: 1.976e-01
# Top 10 σ(M_r): [1.0153, 1.0122, 1.0109, 1.008, 0.9909, 0.9904, 0.9882, 0.9871, 0.9667, 0.9595]
# Top 10 σ(A)  : [1.4272, 1.2657, 1.206, 1.1897, 1.1773, 1.1634, 1.1493, 1.1435, 1.132, 1.123]
#
# — Rank 175 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_175.pkl)
# Relative ℓ₂ error on singular values: 1.808e-01
# Top 10 σ(M_r): [1.0154, 1.0128, 1.0121, 1.01, 0.9909, 0.9905, 0.9885, 0.988, 0.9667, 0.9599]
# Top 10 σ(A)  : [1.3821, 1.2253, 1.1763, 1.1635, 1.1416, 1.1286, 1.1129, 1.1026, 1.0921, 1.0775]
#
# — Rank 200 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_200.pkl)
# Relative ℓ₂ error on singular values: 1.777e-01
# Top 10 σ(M_r): [1.0155, 1.0131, 1.013, 1.0108, 0.9909, 0.9906, 0.9887, 0.9885, 0.9668, 0.9601]
# Top 10 σ(A)  : [1.3664, 1.2891, 1.1438, 1.1105, 1.1055, 1.0818, 1.0771, 1.0696, 1.0653, 1.0549]
#
# — Rank 225 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_225.pkl)
# Relative ℓ₂ error on singular values: 1.814e-01
# Top 10 σ(M_r): [1.0156, 1.0133, 1.0132, 1.011, 0.9909, 0.9907, 0.9888, 0.9886, 0.9668, 0.9601]
# Top 10 σ(A)  : [1.3434, 1.2471, 1.106, 1.0878, 1.0712, 1.0608, 1.0394, 1.0252, 1.0232, 1.0087]
#
# — Rank 250 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_250.pkl)
# Relative ℓ₂ error on singular values: 1.913e-01
# Top 10 σ(M_r): [1.0156, 1.0135, 1.0134, 1.0112, 0.9909, 0.9907, 0.9888, 0.9887, 0.9668, 0.9602]
# Top 10 σ(A)  : [1.3414, 1.2872, 1.0773, 1.0698, 1.0512, 1.0303, 1.0248, 1.0081, 0.9997, 0.9953]
#
# — Rank 275 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_275.pkl)
# Relative ℓ₂ error on singular values: 2.052e-01
# Top 10 σ(M_r): [1.0157, 1.0135, 1.0135, 1.0113, 0.991, 0.9907, 0.9888, 0.9888, 0.9668, 0.9602]
# Top 10 σ(A)  : [1.3437, 1.2826, 1.0391, 1.0237, 1.0154, 1.0054, 0.9976, 0.9887, 0.9816, 0.9676]
#
# — Rank 300 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_300.pkl)
# Relative ℓ₂ error on singular values: 2.220e-01
# Top 10 σ(M_r): [1.0157, 1.0136, 1.0135, 1.0114, 0.991, 0.9908, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3612, 1.2628, 1.0376, 1.0233, 1.0124, 0.9972, 0.9862, 0.9778, 0.9669, 0.9546]
#
# — Rank 325 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_325.pkl)
# Relative ℓ₂ error on singular values: 2.375e-01
# Top 10 σ(M_r): [1.0157, 1.0136, 1.0136, 1.0114, 0.991, 0.9908, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3076, 1.2637, 0.9945, 0.9873, 0.9788, 0.9695, 0.9626, 0.955, 0.9459, 0.9383]
#
# — Rank 350 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_350.pkl)
# Relative ℓ₂ error on singular values: 2.518e-01
# Top 10 σ(M_r): [1.0157, 1.0137, 1.0136, 1.0114, 0.991, 0.9908, 0.9889, 0.9889, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.342, 1.2551, 0.9943, 0.9764, 0.9616, 0.949, 0.9434, 0.9369, 0.9297, 0.9245]
#
# — Rank 375 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_375.pkl)
# Relative ℓ₂ error on singular values: 2.653e-01
# Top 10 σ(M_r): [1.0157, 1.0137, 1.0136, 1.0114, 0.991, 0.9908, 0.9889, 0.9889, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.302, 1.2634, 1.0318, 0.9604, 0.9443, 0.9342, 0.9245, 0.9206, 0.9086, 0.9018]
#
# — Rank 400 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_400.pkl)
# Relative ℓ₂ error on singular values: 2.752e-01
# Top 10 σ(M_r): [1.0157, 1.0137, 1.0136, 1.0114, 0.991, 0.9908, 0.9889, 0.9889, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3114, 1.2529, 0.9832, 0.9659, 0.9543, 0.9253, 0.919, 0.9143, 0.9099, 0.9067]
#
# — Rank 425 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_425.pkl)
# Relative ℓ₂ error on singular values: 2.904e-01
# Top 10 σ(M_r): [1.0157, 1.0137, 1.0136, 1.0115, 0.991, 0.9908, 0.9889, 0.9889, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3249, 1.2534, 1.0213, 0.9534, 0.9351, 0.926, 0.9188, 0.9047, 0.9011, 0.8935]
#
# — Rank 450 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_450.pkl)
# Relative ℓ₂ error on singular values: 3.030e-01
# Top 10 σ(M_r): [1.0157, 1.0137, 1.0136, 1.0115, 0.991, 0.9908, 0.9889, 0.9889, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3128, 1.257, 1.1174, 0.9364, 0.9226, 0.9174, 0.9075, 0.905, 0.899, 0.8879]
#
# — Rank 475 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_475.pkl)
# Relative ℓ₂ error on singular values: 3.152e-01
# Top 10 σ(M_r): [1.0157, 1.0137, 1.0136, 1.0115, 0.991, 0.9908, 0.9889, 0.9889, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3052, 1.2691, 1.0123, 0.934, 0.9187, 0.915, 0.9082, 0.8969, 0.893, 0.8834]
#
# — Rank 500 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_500.pkl)
# Relative ℓ₂ error on singular values: 3.232e-01
# Top 10 σ(M_r): [1.0157, 1.0137, 1.0136, 1.0115, 0.991, 0.9908, 0.9889, 0.9889, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3316, 1.2444, 1.0487, 0.9156, 0.911, 0.8921, 0.8848, 0.8827, 0.8758, 0.8681]
#
# — Rank 525 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_525.pkl)
# Relative ℓ₂ error on singular values: 3.345e-01
# Top 10 σ(M_r): [1.0157, 1.0137, 1.0136, 1.0115, 0.991, 0.9908, 0.9889, 0.9889, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3187, 1.2642, 1.0754, 0.9041, 0.8927, 0.8881, 0.8802, 0.879, 0.872, 0.8675]
#
# — Rank 550 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_550.pkl)
# Relative ℓ₂ error on singular values: 3.424e-01
# Top 10 σ(M_r): [1.0157, 1.0137, 1.0136, 1.0115, 0.991, 0.9908, 0.9889, 0.9889, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3085, 1.2507, 1.1072, 0.9619, 0.8985, 0.887, 0.8762, 0.871, 0.8629, 0.8544]
#
# — Rank 575 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_575.pkl)
# Relative ℓ₂ error on singular values: 3.501e-01
# Top 10 σ(M_r): [1.0157, 1.0137, 1.0136, 1.0115, 0.991, 0.9908, 0.9889, 0.9889, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3125, 1.2312, 1.1235, 0.9143, 0.9041, 0.8846, 0.8707, 0.8653, 0.8602, 0.8543]
#
# — Rank 600 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_600.pkl)
# Relative ℓ₂ error on singular values: 3.567e-01
# Top 10 σ(M_r): [1.0157, 1.0137, 1.0136, 1.0115, 0.991, 0.9908, 0.9889, 0.9889, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3288, 1.2556, 1.0969, 0.9018, 0.8852, 0.8714, 0.8673, 0.8513, 0.8505, 0.8402]
#
# — Rank 625 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_625.pkl)
# Relative ℓ₂ error on singular values: 3.655e-01
# Top 10 σ(M_r): [1.0157, 1.0137, 1.0136, 1.0115, 0.991, 0.9908, 0.9889, 0.9889, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3146, 1.2391, 1.1231, 0.9451, 0.8699, 0.8591, 0.8524, 0.8423, 0.841, 0.8371]
#
# — Rank 650 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_650.pkl)
# Relative ℓ₂ error on singular values: 3.747e-01
# Top 10 σ(M_r): [1.0157, 1.0137, 1.0136, 1.0115, 0.991, 0.9908, 0.9889, 0.9889, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3031, 1.2514, 1.1759, 0.9255, 0.8642, 0.8608, 0.8484, 0.837, 0.8316, 0.8278]
#
# — Rank 675 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_675.pkl)
# Relative ℓ₂ error on singular values: 3.789e-01
# Top 10 σ(M_r): [1.0157, 1.0137, 1.0136, 1.0115, 0.991, 0.9908, 0.9889, 0.9889, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3081, 1.2259, 1.0923, 0.912, 0.8615, 0.857, 0.8448, 0.8414, 0.8332, 0.8308]
#
# — Rank 700 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_700.pkl)
# Relative ℓ₂ error on singular values: 3.851e-01
# Top 10 σ(M_r): [1.0157, 1.0137, 1.0136, 1.0115, 0.991, 0.9908, 0.9889, 0.9889, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3182, 1.2119, 1.1246, 0.8929, 0.8539, 0.8439, 0.8397, 0.8294, 0.8229, 0.8181]
#
# — Rank 725 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_725.pkl)
# Relative ℓ₂ error on singular values: 3.917e-01
# Top 10 σ(M_r): [1.0157, 1.0137, 1.0136, 1.0115, 0.991, 0.9908, 0.9889, 0.9889, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.3016, 1.231, 1.1685, 0.9147, 0.8588, 0.8457, 0.8355, 0.8268, 0.8229, 0.8203]
#
# — Rank 750 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_750.pkl)
# Relative ℓ₂ error on singular values: 3.945e-01
# Top 10 σ(M_r): [1.0157, 1.0137, 1.0136, 1.0115, 0.991, 0.9908, 0.9889, 0.9889, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2999, 1.2378, 1.1347, 0.9437, 0.8705, 0.8474, 0.8348, 0.8288, 0.8114, 0.8086]
#
# — Rank 775 —  (E2EForward/MedMNIST/Matrices\retinamnist\rank_775.pkl)
# Relative ℓ₂ error on singular values: 4.002e-01
# Top 10 σ(M_r): [1.0157, 1.0137, 1.0136, 1.0115, 0.991, 0.9908, 0.9889, 0.9889, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.301, 1.2227, 1.1477, 0.9537, 0.8627, 0.8447, 0.8409, 0.8288, 0.8232, 0.808]
#
# ══════════  TISSUEMNIST  ══════════
#
# — Rank  25 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_025.pkl)
# Relative ℓ₂ error on singular values: 8.569e-01
# Top 10 σ(M_r): [1.0148, 1.0115, 1.0114, 1.0084, 0.9898, 0.9894, 0.9872, 0.9872, 0.9658, 0.9582]
# Top 10 σ(A)  : [2.1582, 2.0522, 2.032, 1.9975, 1.9382, 1.9195, 1.8899, 1.8627, 1.8298, 1.8032]
#
# — Rank  50 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_050.pkl)
# Relative ℓ₂ error on singular values: 4.293e-01
# Top 10 σ(M_r): [1.0152, 1.0134, 1.0133, 1.0109, 0.9908, 0.9907, 0.9886, 0.9885, 0.9666, 0.9599]
# Top 10 σ(A)  : [1.6519, 1.5972, 1.5776, 1.5699, 1.5425, 1.5367, 1.4816, 1.473, 1.442, 1.4333]
#
# — Rank  75 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_075.pkl)
# Relative ℓ₂ error on singular values: 2.896e-01
# Top 10 σ(M_r): [1.0152, 1.0134, 1.0134, 1.0111, 0.9908, 0.9907, 0.9887, 0.9886, 0.9667, 0.9601]
# Top 10 σ(A)  : [1.5283, 1.4651, 1.4128, 1.3923, 1.3674, 1.3524, 1.3259, 1.3167, 1.3002, 1.293]
#
# — Rank 100 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_100.pkl)
# Relative ℓ₂ error on singular values: 1.935e-01
# Top 10 σ(M_r): [1.0153, 1.0135, 1.0134, 1.0111, 0.9909, 0.9907, 0.9887, 0.9886, 0.9667, 0.9601]
# Top 10 σ(A)  : [1.3793, 1.304, 1.293, 1.2733, 1.256, 1.2292, 1.2223, 1.2114, 1.1883, 1.183]
#
# — Rank 125 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_125.pkl)
# Relative ℓ₂ error on singular values: 1.568e-01
# Top 10 σ(M_r): [1.0153, 1.0135, 1.0135, 1.0112, 0.9909, 0.9908, 0.9888, 0.9886, 0.9667, 0.9602]
# Top 10 σ(A)  : [1.4129, 1.2214, 1.2079, 1.1875, 1.1858, 1.147, 1.145, 1.1341, 1.1249, 1.1122]
#
# — Rank 150 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_150.pkl)
# Relative ℓ₂ error on singular values: 1.368e-01
# Top 10 σ(M_r): [1.0154, 1.0135, 1.0135, 1.0112, 0.9909, 0.9908, 0.9888, 0.9887, 0.9667, 0.9602]
# Top 10 σ(A)  : [1.3371, 1.177, 1.1556, 1.133, 1.131, 1.1086, 1.1061, 1.0916, 1.0819, 1.0764]
#
# — Rank 175 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_175.pkl)
# Relative ℓ₂ error on singular values: 1.288e-01
# Top 10 σ(M_r): [1.0154, 1.0136, 1.0136, 1.0113, 0.991, 0.9908, 0.9888, 0.9887, 0.9667, 0.9602]
# Top 10 σ(A)  : [1.3157, 1.1547, 1.1318, 1.1093, 1.099, 1.0896, 1.0677, 1.0456, 1.0423, 1.0292]
#
# — Rank 200 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_200.pkl)
# Relative ℓ₂ error on singular values: 1.453e-01
# Top 10 σ(M_r): [1.0155, 1.0136, 1.0136, 1.0113, 0.991, 0.9908, 0.9889, 0.9887, 0.9668, 0.9602]
# Top 10 σ(A)  : [1.3231, 1.1565, 1.1258, 1.08, 1.0765, 1.0717, 1.066, 1.0518, 1.0426, 1.0338]
#
# — Rank 225 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_225.pkl)
# Relative ℓ₂ error on singular values: 1.599e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0136, 1.0113, 0.991, 0.9909, 0.9889, 0.9887, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2982, 1.1633, 1.1391, 1.119, 1.1073, 1.0871, 1.0343, 1.03, 1.0143, 0.9982]
#
# — Rank 250 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_250.pkl)
# Relative ℓ₂ error on singular values: 1.770e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0136, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2995, 1.181, 1.1401, 1.1304, 1.1057, 1.0765, 1.0224, 1.0147, 0.9893, 0.9842]
#
# — Rank 275 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_275.pkl)
# Relative ℓ₂ error on singular values: 1.911e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0137, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2971, 1.1762, 1.1569, 1.1371, 1.1146, 1.0593, 1.0161, 0.9874, 0.984, 0.9735]
#
# — Rank 300 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_300.pkl)
# Relative ℓ₂ error on singular values: 2.088e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0137, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2616, 1.2006, 1.161, 1.1396, 1.1184, 1.0951, 1.0183, 0.9926, 0.9868, 0.977]
#
# — Rank 325 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_325.pkl)
# Relative ℓ₂ error on singular values: 2.285e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0137, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2909, 1.1818, 1.1753, 1.1647, 1.151, 1.1058, 1.0153, 0.9904, 0.9856, 0.9677]
#
# — Rank 350 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_350.pkl)
# Relative ℓ₂ error on singular values: 2.435e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0137, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2629, 1.1863, 1.1667, 1.154, 1.1396, 1.1294, 1.0259, 1.0014, 0.9705, 0.9598]
#
# — Rank 375 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_375.pkl)
# Relative ℓ₂ error on singular values: 2.590e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0137, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2572, 1.1968, 1.1867, 1.1741, 1.1585, 1.1246, 1.053, 1.0239, 0.9799, 0.9459]
#
# — Rank 400 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_400.pkl)
# Relative ℓ₂ error on singular values: 2.740e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0137, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2473, 1.2026, 1.1931, 1.1735, 1.166, 1.139, 1.036, 0.9997, 0.9673, 0.9445]
#
# — Rank 425 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_425.pkl)
# Relative ℓ₂ error on singular values: 2.862e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0137, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2508, 1.1917, 1.1764, 1.1627, 1.1603, 1.1463, 1.0797, 1.0662, 1.0369, 0.9663]
#
# — Rank 450 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_450.pkl)
# Relative ℓ₂ error on singular values: 2.989e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0137, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2516, 1.205, 1.1873, 1.1733, 1.1625, 1.1573, 1.0771, 1.0562, 1.0176, 0.9511]
#
# — Rank 475 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_475.pkl)
# Relative ℓ₂ error on singular values: 3.114e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0137, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2408, 1.2249, 1.2021, 1.1839, 1.1679, 1.1621, 1.1072, 1.1035, 1.0804, 0.9827]
#
# — Rank 500 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_500.pkl)
# Relative ℓ₂ error on singular values: 3.197e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0137, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2384, 1.1959, 1.188, 1.1665, 1.1649, 1.1522, 1.0972, 1.0813, 1.0659, 0.9602]
#
# — Rank 525 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_525.pkl)
# Relative ℓ₂ error on singular values: 3.292e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0137, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.246, 1.2121, 1.1887, 1.1834, 1.1703, 1.154, 1.1159, 1.0949, 1.0792, 0.9823]
#
# — Rank 550 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_550.pkl)
# Relative ℓ₂ error on singular values: 3.374e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0137, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2409, 1.207, 1.1948, 1.1878, 1.1774, 1.1527, 1.1219, 1.091, 1.0624, 1.003]
#
# — Rank 575 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_575.pkl)
# Relative ℓ₂ error on singular values: 3.445e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0137, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2193, 1.2076, 1.1879, 1.1798, 1.1683, 1.1592, 1.1291, 1.1188, 1.0858, 1.0269]
#
# — Rank 600 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_600.pkl)
# Relative ℓ₂ error on singular values: 3.539e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0137, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2333, 1.2205, 1.1937, 1.1793, 1.1681, 1.1522, 1.1423, 1.1389, 1.1088, 1.0224]
#
# — Rank 625 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_625.pkl)
# Relative ℓ₂ error on singular values: 3.588e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0137, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2328, 1.1931, 1.1887, 1.1679, 1.1636, 1.153, 1.1375, 1.1329, 1.0705, 1.0348]
#
# — Rank 650 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_650.pkl)
# Relative ℓ₂ error on singular values: 3.663e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0137, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2345, 1.194, 1.1831, 1.1762, 1.1645, 1.1474, 1.1295, 1.1191, 1.0896, 1.0095]
#
# — Rank 675 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_675.pkl)
# Relative ℓ₂ error on singular values: 3.717e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0137, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2307, 1.2056, 1.1858, 1.1787, 1.1634, 1.1624, 1.1342, 1.1209, 1.1122, 1.0421]
#
# — Rank 700 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_700.pkl)
# Relative ℓ₂ error on singular values: 3.774e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0137, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2254, 1.2054, 1.1953, 1.1818, 1.1693, 1.1637, 1.1531, 1.1363, 1.1318, 1.0679]
#
# — Rank 725 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_725.pkl)
# Relative ℓ₂ error on singular values: 3.827e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0137, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2421, 1.2081, 1.1981, 1.1745, 1.1692, 1.1594, 1.1551, 1.1458, 1.1241, 1.0761]
#
# — Rank 750 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_750.pkl)
# Relative ℓ₂ error on singular values: 3.905e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0137, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2225, 1.191, 1.1854, 1.1719, 1.1682, 1.1577, 1.1464, 1.1394, 1.1323, 1.0962]
#
# — Rank 775 —  (E2EForward/MedMNIST/Matrices\tissuemnist\rank_775.pkl)
# Relative ℓ₂ error on singular values: 3.915e-01
# Top 10 σ(M_r): [1.0155, 1.0137, 1.0137, 1.0114, 0.991, 0.9909, 0.9889, 0.9888, 0.9668, 0.9603]
# Top 10 σ(A)  : [1.2235, 1.2026, 1.1831, 1.1753, 1.1666, 1.1599, 1.1497, 1.144, 1.1343, 1.0748]
