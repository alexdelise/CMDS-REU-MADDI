# %%
import math
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from torchvision.transforms import Compose, ToTensor, GaussianBlur
import matplotlib.pyplot as plt
import numpy as np
import torchvision.transforms.functional as TF

# MedMNIST import
import medmnist
from medmnist import INFO

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# --- MedMNIST Data setup ---
data_flag = 'retinamnist'
info = INFO[data_flag]
DataClass = getattr(medmnist, info['python_class'])
train_dataset = DataClass(split='train', download=True)
numSamples = len(train_dataset)
# Out:
# Using device: cuda
# Using downloaded and verified file: C:\Users\alexr\.medmnist\retinamnist.npz

# %%
# Prepare data tensors --------------------------------------------------------
def _get_tensor(ds, n):
    """Stack first n samples, convert to float32 in [0,1]."""
    imgs = []
    for i in range(n):
        x, _ = ds[i]
        if isinstance(x, torch.Tensor):
            t = x.float() / 255.0
        elif isinstance(x, np.ndarray):
            t = torch.from_numpy(x).float() / 255.0
            if t.ndim == 3:
                t = t.permute(2, 0, 1)
        else:
            t = TF.to_tensor(x)
        imgs.append(t[0])
    return torch.stack(imgs).to(device)

# Prepare dataset
X_raw = _get_tensor(train_dataset, numSamples) 
dim = X_raw[0].numel()  # 28*28 = 784
r = 25  # bottleneck / testing rank

# X Stuff
X = X_raw.view(numSamples, -1).T
gammaX = (1/numSamples) * X @ X.T + 1e-5 * torch.eye(dim, device=device)
L_X = torch.linalg.cholesky(gammaX)

# F Stuff
blurKernelSizeF = 5
blurSigmaF = 1.0
forwardBlur = GaussianBlur(kernel_size=blurKernelSizeF, sigma=blurSigmaF)
basisImages = torch.eye(dim).reshape(dim, 1, 28, 28)
F_cols = []
for j in range(dim):
    F_cols.append(forwardBlur(basisImages[j]).flatten())
F = torch.stack(F_cols, dim=1).to(device)
FX = F @ X

# E Stuff
noiseSigma = 0.05
E = torch.randn_like(FX) * noiseSigma
gammaE = noiseSigma**2 * torch.eye(dim, device=device)

# Y Stuff
Y = FX + E
gammaY = F @ gammaX @ F.T + gammaE + 1e-5 * torch.eye(dim, device=device)
L_Y = torch.linalg.cholesky(gammaY)


# Theoretical Optimizer
C = F @ L_X
U, S, Vh = torch.linalg.svd(C)
U_r, S_r, Vh_r = U[:, :r], torch.diag(S[:r]), Vh[:r, :]
C_r = U_r @ S_r @ Vh_r
M_r = C_r @ torch.linalg.pinv(L_X)

# %%
# ── quick 1×3 preview: (\bar{X}, F \bar{X}, F \bar{X} + E) ─────────────────────
import os
import matplotlib.pyplot as plt

# random training-set index
#idx = np.random.randint(0, numSamples)
idx = 100

# (i) original image  →  (H,W)
orig_img = X_raw[idx].cpu()          # already in [0,1]
if orig_img.ndim == 3:               # safety: drop channel dim
    orig_img = orig_img[0]

# (ii) blurred image  F \bar{X}
blur_img = forwardBlur(orig_img.unsqueeze(0)).squeeze(0).cpu()

# (iii) blurred + noise image  F \bar{X} + E
noise            = torch.randn_like(blur_img) * noiseSigma
blur_noise_img   = (blur_img + noise).clamp(0, 1).cpu()

# ── plot & save ──────────────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 3, figsize=(7.5, 2.7))
axes[0].imshow(orig_img,        cmap='gray')
axes[0].set_title(r'Original $\mathbf{x}$')
axes[0].axis('off')

axes[1].imshow(blur_img,        cmap='gray')
axes[1].set_title(r'Blurred $\mathbf{F} \mathbf{x}$')
axes[1].axis('off')

axes[2].imshow(blur_noise_img,  cmap='gray')
axes[2].set_title(r'Observation $\mathbf{y} = \mathbf{F} \mathbf{x} + \varepsilon$')
axes[2].axis('off')

plt.tight_layout()

out_dir = f"end2endpics/MedMNIST"
os.makedirs(out_dir, exist_ok=True)
#plt.savefig(f"{out_dir}/{data_flag}_mapping{idx}_{r}.png", dpi=300)
plt.show()

# %%
# --- Autoencoder setup -------------------------------------------------------
batch_size = 128
num_epochs = 350

X_tensor = X.clone().to(torch.float32)
Y_tensor = Y.clone().to(torch.float32)

class LinearAutoencoder(nn.Module):
    def __init__(self, input_dim, bottleneck_dim):
        super().__init__()
        self.encoder = nn.Linear(input_dim, bottleneck_dim, bias=False)
        self.decoder = nn.Linear(bottleneck_dim, input_dim, bias=False)
    def forward(self, x):
        return self.decoder(self.encoder(x))

model     = LinearAutoencoder(input_dim=dim, bottleneck_dim=r).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.MSELoss()

# Training loop using average per-sample L2 error -----------------------------
train_errors = []
for epoch in range(1, num_epochs + 1):
    model.train()
    optimizer.zero_grad()

    outputs = model(X.T)
    target  = Y.T

    loss = criterion(outputs, target)
    loss.backward()
    optimizer.step()

    # Evaluate average per-sample l2 error
    with torch.no_grad():
        A_learned = model.decoder.weight @ model.encoder.weight
        diffs = A_learned @ X - Y
        avg_l2_err = torch.norm(diffs, dim=0).mean().item()
        train_errors.append(avg_l2_err)


from matplotlib import gridspec

idx = 100

orig_img   = X_raw[idx].view(28, 28).cpu()
y_img      = Y[:, idx].view(28, 28).cpu()
opt_img    = (M_r @ Y)[:, idx].view(28, 28).cpu()
learn_img  = (A_learned @ Y)[:, idx].view(28, 28).cpu()

err_opt   = torch.abs(opt_img   - orig_img)
err_learn = torch.abs(learn_img - orig_img)
err_vmin, err_vmax = 0.0, max(err_opt.max(), err_learn.max()).item()

fig = plt.figure(figsize=(7, 4.2))
gs  = gridspec.GridSpec(
    2, 4,
    width_ratios=[1, 1, 1, 0.06],
    wspace=0.20, hspace=0.30
)

# row 0
ax = fig.add_subplot(gs[0, 0])
ax.imshow(orig_img, cmap='gray')
ax.set_title(r'Original $\mathbf{x}$', pad=4)
ax.axis('off')

ax = fig.add_subplot(gs[0, 1])
ax.imshow(opt_img, cmap='gray')
ax.set_title(fr'Optimal $\widehat{{\mathbf{{A}}}}_{{{r}}} \mathbf{{x}}$', pad=4)
ax.axis('off')

ax = fig.add_subplot(gs[0, 2])
im = ax.imshow(err_opt, cmap='inferno', vmin=err_vmin, vmax=err_vmax)
ax.set_title(fr'$|\widehat{{\mathbf{{A}}}}_{{{r}}} \mathbf{{x}} - \mathbf{{y}}|$', pad=4)
ax.axis('off')

# row 1
ax = fig.add_subplot(gs[1, 0])
ax.imshow(y_img, cmap='gray')
ax.set_title(r'Observation $\mathbf{y}$', pad=4)
ax.axis('off')

ax = fig.add_subplot(gs[1, 1])
ax.imshow(learn_img, cmap='gray')
ax.set_title(fr'Learned $\mathbf{{A}}_{{{r}}} \mathbf{{x}}$', pad=4)
ax.axis('off')

ax = fig.add_subplot(gs[1, 2])
ax.imshow(err_learn, cmap='inferno', vmin=err_vmin, vmax=err_vmax)
ax.set_title(fr'$|\mathbf{{A}}_{{{r}}} \mathbf{{x}} - \mathbf{{y}}|$', pad=4)
ax.axis('off')

# color-bar
cax = fig.add_subplot(gs[:, 3])
plt.colorbar(im, cax=cax)
cax.yaxis.tick_right()
plt.show()

# %%
import os, pickle, torch
from collections import defaultdict
from copy import deepcopy
from torchvision.transforms import GaussianBlur
import matplotlib.pyplot as plt



# where to stash matrices and final plots 
save_root     = "E2EForward"
matrices_root = os.path.join(save_root, "MedMNIST", "Matrices")
tests_root    = os.path.join(save_root, "MedMNIST", "Pics")
os.makedirs(matrices_root, exist_ok=True)
os.makedirs(tests_root, exist_ok=True)

# helper: run rank sweep on ONE MedMNIST subset 
def run_rank_sweep(data_flag, ranks, train_epochs=350, lr=1e-4):
    """Return ([theory avg l2], [AE avg l2]) for the given dataset
       and store matrices to pickles for every rank."""
    info = INFO[data_flag]
    DataClass = getattr(medmnist, info['python_class'])
    train_ds = DataClass(split='train', download=True)

    numSamples = int(0.8 * len(train_ds))
    X_raw = _get_tensor(train_ds, numSamples)
    dim = X_raw[0].numel()

    X = X_raw.view(numSamples, -1).T
    gammaX = (1 / numSamples) * X @ X.T + 1e-5 * torch.eye(dim, device=device)
    L_X = torch.linalg.cholesky(gammaX)

    blurKernelSizeF = 5
    blurSigmaF = 1.0
    blur = GaussianBlur(kernel_size=blurKernelSizeF, sigma=blurSigmaF)
    basisImages = torch.eye(dim).reshape(dim, 1, 28, 28)
    F_cols = [blur(basisImages[j]).flatten() for j in range(dim)]
    F = torch.stack(F_cols, dim=1).to(device)

    FX = F @ X
    noiseSigma = 0.05
    E = torch.randn_like(FX) * noiseSigma
    Y = FX + E

    gammaE = noiseSigma**2 * torch.eye(dim, device=device)
    gammaY = F @ gammaX @ F.T + gammaE + 1e-5 * torch.eye(dim, device=device)
    L_Y = torch.linalg.cholesky(gammaY)

    C = F @ L_X
    U, S, Vh = torch.linalg.svd(C)

    theory_err, learned_err = [], []
    ds_dir = os.path.join(matrices_root, data_flag)
    os.makedirs(ds_dir, exist_ok=True)

    for r in ranks:
        if r % 100 == 0:
            print(f"On Rank {r}")

        U_r = U[:, :r]
        S_r = torch.diag(S[:r])
        Vh_r = Vh[:r, :]
        C_r = U_r @ S_r @ Vh_r
        M_r = C_r @ torch.linalg.pinv(L_X)

        diffs_opt = M_r @ X - Y
        avg_l2_opt = torch.norm(diffs_opt, dim=0).mean().item()
        theory_err.append(avg_l2_opt)

        ae = LinearAutoencoder(dim, r).to(device)
        opt = optim.Adam(ae.parameters(), lr=lr)
        criterion = nn.MSELoss()

        for _ in range(train_epochs):
            opt.zero_grad()
            out = ae(Y.T)
            loss = criterion(out, X.T)
            loss.backward()
            opt.step()

        with torch.no_grad():
            W_enc = ae.encoder.weight.detach().cpu()
            W_dec = ae.decoder.weight.detach().cpu()
            A = W_dec @ W_enc
            diffs_learn = A.to(device) @ Y - X
            avg_l2_learn = torch.norm(diffs_learn, dim=0).mean().item()
        learned_err.append(avg_l2_learn)

        dump_path = os.path.join(ds_dir, f"rank_{r:03d}.pkl")
        with open(dump_path, "wb") as f:
            pickle.dump(
                {
                    "optimalMatrix": M_r.cpu(),
                    "encoderWeight": W_enc,
                    "decoderWeight": W_dec,
                },
                f,
                protocol=pickle.HIGHEST_PROTOCOL,
            )

    return theory_err, learned_err

# run all requested datasets (original sizes of: 200k, 100k, 50k, 10k, 1k)
datasets  = ['tissuemnist', 'chestmnist', 'organamnist', 'retinamnist']
ranks     = list(range(25, 776, 25))
results   = defaultdict(dict)
num_epochs = 10 # define here for training / plot naming

for flag in datasets:
    print(f"\n▶ Running rank sweep for {flag} …")
    th, le = run_rank_sweep(flag, ranks, train_epochs=num_epochs)
    results[flag]['theory']  = th
    results[flag]['learned'] = le
# Out:
# ▶ Running rank sweep for breastmnist …
# Using downloaded and verified file: C:\Users\alexr\.medmnist\breastmnist.npz
# On Rank 100
# On Rank 200
# On Rank 300
# On Rank 400
# On Rank 500
#
# ▶ Running rank sweep for chestmnist …
# Using downloaded and verified file: C:\Users\alexr\.medmnist\chestmnist.npz
# On Rank 100
# On Rank 200
# On Rank 300
# On Rank 400
# On Rank 500
#
# ▶ Running rank sweep for organamnist …
# Using downloaded and verified file: C:\Users\alexr\.medmnist\organamnist.npz
# On Rank 100
# On Rank 200
# On Rank 300
# On Rank 400
# On Rank 500
#
# ▶ Running rank sweep for organcmnist …
# Using downloaded and verified file: C:\Users\alexr\.medmnist\organcmnist.npz
# On Rank 100
# On Rank 200
# On Rank 300
# On Rank 400
# On Rank 500
#
# ▶ Running rank sweep for organsmnist …
# Using downloaded and verified file: C:\Users\alexr\.medmnist\organsmnist.npz
# On Rank 100
# On Rank 200
# On Rank 300
# On Rank 400
# On Rank 500
#
# ▶ Running rank sweep for retinamnist …
# Using downloaded and verified file: C:\Users\alexr\.medmnist\retinamnist.npz
# On Rank 100
# On Rank 200
# On Rank 300
# On Rank 400
# On Rank 500

# %%
# combined plot
plt.figure(figsize=(7.8, 4.7))
short_label = {'theory': 'O', 'learned': 'L'}

for i, flag in enumerate(datasets):
    col = ef_pastel[i % len(ef_pastel)]
    for kind in ('theory', 'learned'):
        plt.plot(ranks,
                 results[flag][kind],
                 line_styles[kind],
                 marker=markers[kind],
                 color=col,
                 lw=lw,
                 ms=ms, 
                 label=f"{flag} ({short_label[kind]})")

plt.xlabel('Rank $r$')
plt.ylabel(r'Average $\ell_2$ Reconstruction Error')
plt.yscale('log')
#plt.title('Average $\ell_2$ Error vs. Rank')
plt.legend(ncol=3, fontsize='small')
plt.tight_layout()
plt.savefig("E2EInverse/MedMNIST/Pics/e2einverse_ranksweep_200epoch.png")
plt.show()

# %%
# ── Inspect stored matrices & compare singular values (4 decimals) ─────────
#    • Lists datasets / ranks, loads each pickle
#    • Computes singular values of
#        – Bayes–optimal map  Mr
#        – Learned map        A = W_dec @ W_enc
#    • Prints top-k singular values (rounded to 4 decimals) and relative ℓ2 error

import os, pickle, torch

base_dir  = "E2EForward/MedMNIST/Matrices"
top_k     = 10                              # how many singular values to show
torch.set_printoptions(edgeitems=3, linewidth=120, sci_mode=False)

for dataset in sorted(os.listdir(base_dir)):
    ds_dir = os.path.join(base_dir, dataset)
    if not os.path.isdir(ds_dir):
        continue

    print(f"\n══════════  {dataset.upper()}  ══════════")
    for fname in sorted(fn for fn in os.listdir(ds_dir) if fn.endswith(".pkl")):
        rank   = int(fname.split("_")[1].split(".")[0])        # rank_050.pkl → 50
        fpath  = os.path.join(ds_dir, fname)
 
        # ── load matrices ───────────────────────────────────────────────────
        with open(fpath, "rb") as f:
            mats = pickle.load(f)

        Mr   = mats["optimalMatrix"]
        Wenc = mats["encoderWeight"]
        Wdec = mats["decoderWeight"]
        A    = Wdec @ Wenc                                    # learned full map

        # ── singular values ────────────────────────────────────────────────
        s_opt    = torch.linalg.svdvals(Mr)
        s_learn  = torch.linalg.svdvals(A)

        rel_err = torch.norm(s_opt - s_learn) / torch.norm(s_opt)

        # Round singular values to 4 decimal places for print
        s_opt_rounded   = [round(v.item(), 4) for v in s_opt[:top_k]]
        s_learn_rounded = [round(v.item(), 4) for v in s_learn[:top_k]]

        print(f"\n— Rank {rank:3d} —  ({fpath})")
        #print("optimalMatrix shape :", tuple(Mr.shape))
        #print("encoderWeight shape :", tuple(Wenc.shape))
        #print("decoderWeight shape :", tuple(Wdec.shape))
        print(f"Relative ℓ₂ error on singular values: {rel_err:.3e}")
        print(f"Top {top_k} σ(M_r):", s_opt_rounded)
        print(f"Top {top_k} σ(A)  :", s_learn_rounded)

        # Uncomment next lines if you want FULL singular value lists
        # print("\nAll σ(M_r):\n", s_opt.cpu())
        # print("\nAll σ(A):\n",   s_learn.cpu())
# Out:
# ══════════  BREASTMNIST  ══════════
#
# — Rank  25 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_025.pkl)
# Relative ℓ₂ error on singular values: 5.218e-01
# Top 10 σ(M_r): [1.6648, 1.3685, 1.2854, 1.2738, 1.2628, 1.2325, 1.213, 1.1919, 1.1804, 1.169]
# Top 10 σ(A)  : [2.3869, 2.2914, 2.0541, 1.993, 1.9408, 1.9219, 1.8896, 1.8734, 1.8491, 1.8009]
#
# — Rank  50 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_050.pkl)
# Relative ℓ₂ error on singular values: 6.171e-02
# Top 10 σ(M_r): [2.0153, 1.6919, 1.6112, 1.543, 1.5335, 1.496, 1.4713, 1.4503, 1.4273, 1.4002]
# Top 10 σ(A)  : [2.0582, 1.8061, 1.7736, 1.7158, 1.6994, 1.6385, 1.5882, 1.5457, 1.5217, 1.4963]
#
# — Rank  75 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_075.pkl)
# Relative ℓ₂ error on singular values: 1.599e-01
# Top 10 σ(M_r): [2.1153, 1.7367, 1.6999, 1.6286, 1.5956, 1.5777, 1.5544, 1.5294, 1.5108, 1.4922]
# Top 10 σ(A)  : [2.0352, 1.6477, 1.6183, 1.5929, 1.552, 1.5354, 1.4945, 1.4881, 1.4187, 1.4031]
#
# — Rank 100 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_100.pkl)
# Relative ℓ₂ error on singular values: 2.198e-01
# Top 10 σ(M_r): [2.126, 1.7387, 1.7061, 1.6323, 1.6103, 1.5863, 1.5638, 1.5373, 1.5176, 1.507]
# Top 10 σ(A)  : [1.8759, 1.5638, 1.5102, 1.4872, 1.4684, 1.4564, 1.4276, 1.4149, 1.3845, 1.3783]
#
# — Rank 125 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_125.pkl)
# Relative ℓ₂ error on singular values: 2.263e-01
# Top 10 σ(M_r): [2.1268, 1.7389, 1.7064, 1.6332, 1.611, 1.587, 1.5643, 1.5377, 1.5182, 1.5074]
# Top 10 σ(A)  : [1.7898, 1.5037, 1.4948, 1.4845, 1.4563, 1.448, 1.4089, 1.4003, 1.3876, 1.3719]
#
# — Rank 150 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_150.pkl)
# Relative ℓ₂ error on singular values: 2.288e-01
# Top 10 σ(M_r): [2.1269, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.7996, 1.4949, 1.4453, 1.4273, 1.4229, 1.4026, 1.3847, 1.3711, 1.3662, 1.3339]
#
# — Rank 175 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_175.pkl)
# Relative ℓ₂ error on singular values: 2.387e-01
# Top 10 σ(M_r): [2.1269, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.6903, 1.4877, 1.4507, 1.434, 1.3975, 1.3941, 1.3728, 1.3538, 1.3462, 1.34]
#
# — Rank 200 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_200.pkl)
# Relative ℓ₂ error on singular values: 2.530e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.5867, 1.4509, 1.4334, 1.3942, 1.3815, 1.3692, 1.3557, 1.3489, 1.334, 1.3283]
#
# — Rank 225 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_225.pkl)
# Relative ℓ₂ error on singular values: 2.697e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.6861, 1.441, 1.4148, 1.3912, 1.3705, 1.3613, 1.357, 1.3492, 1.3303, 1.319]
#
# — Rank 250 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_250.pkl)
# Relative ℓ₂ error on singular values: 2.882e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.6437, 1.4643, 1.4071, 1.3953, 1.369, 1.3514, 1.3471, 1.3463, 1.3267, 1.3094]
#
# — Rank 275 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_275.pkl)
# Relative ℓ₂ error on singular values: 3.037e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.5463, 1.4582, 1.436, 1.3848, 1.3806, 1.3605, 1.35, 1.339, 1.3193, 1.3095]
#
# — Rank 300 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_300.pkl)
# Relative ℓ₂ error on singular values: 3.209e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.5949, 1.4599, 1.4296, 1.3961, 1.3623, 1.3448, 1.3375, 1.332, 1.3279, 1.32]
#
# — Rank 325 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_325.pkl)
# Relative ℓ₂ error on singular values: 3.330e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.5327, 1.4645, 1.4381, 1.3825, 1.3723, 1.3391, 1.3277, 1.3227, 1.3152, 1.2961]
#
# — Rank 350 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_350.pkl)
# Relative ℓ₂ error on singular values: 3.453e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.5735, 1.4962, 1.4353, 1.3909, 1.3741, 1.3493, 1.3395, 1.3302, 1.3207, 1.306]
#
# — Rank 375 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_375.pkl)
# Relative ℓ₂ error on singular values: 3.539e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.5576, 1.4952, 1.4624, 1.4114, 1.3756, 1.3491, 1.3426, 1.3368, 1.3328, 1.3119]
#
# — Rank 400 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_400.pkl)
# Relative ℓ₂ error on singular values: 3.670e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.4938, 1.4466, 1.4161, 1.3975, 1.3842, 1.3459, 1.3266, 1.3253, 1.3059, 1.2982]
#
# — Rank 425 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_425.pkl)
# Relative ℓ₂ error on singular values: 3.760e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.5133, 1.4496, 1.4148, 1.3713, 1.3586, 1.3403, 1.3197, 1.3094, 1.2995, 1.2932]
#
# — Rank 450 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_450.pkl)
# Relative ℓ₂ error on singular values: 3.809e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.5552, 1.4454, 1.4276, 1.4104, 1.3726, 1.3527, 1.3384, 1.334, 1.3113, 1.3042]
#
# — Rank 475 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_475.pkl)
# Relative ℓ₂ error on singular values: 3.866e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.586, 1.4896, 1.4168, 1.3827, 1.3681, 1.3523, 1.3381, 1.3259, 1.3141, 1.3031]
#
# — Rank 500 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_500.pkl)
# Relative ℓ₂ error on singular values: 3.915e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.54, 1.4645, 1.4262, 1.3937, 1.3789, 1.3613, 1.3432, 1.3323, 1.3184, 1.3124]
#
# — Rank 525 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_525.pkl)
# Relative ℓ₂ error on singular values: 3.965e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.5815, 1.4825, 1.4213, 1.4073, 1.37, 1.3533, 1.3441, 1.3281, 1.3154, 1.3082]
#
# — Rank 550 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_550.pkl)
# Relative ℓ₂ error on singular values: 4.006e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.563, 1.498, 1.4323, 1.3998, 1.3731, 1.3512, 1.3496, 1.3375, 1.3206, 1.3164]
#
# — Rank 575 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_575.pkl)
# Relative ℓ₂ error on singular values: 4.055e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.5397, 1.4383, 1.4193, 1.3854, 1.3782, 1.3463, 1.343, 1.3298, 1.3218, 1.3047]
#
# — Rank 600 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_600.pkl)
# Relative ℓ₂ error on singular values: 4.096e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.5635, 1.46, 1.4184, 1.4012, 1.3718, 1.3621, 1.3372, 1.3368, 1.3233, 1.3062]
#
# — Rank 625 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_625.pkl)
# Relative ℓ₂ error on singular values: 4.146e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.5555, 1.4667, 1.421, 1.3969, 1.3776, 1.365, 1.3484, 1.3372, 1.3288, 1.3072]
#
# — Rank 650 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_650.pkl)
# Relative ℓ₂ error on singular values: 4.170e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.5533, 1.4482, 1.4035, 1.3877, 1.3761, 1.3629, 1.3436, 1.3412, 1.3229, 1.3089]
#
# — Rank 675 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_675.pkl)
# Relative ℓ₂ error on singular values: 4.192e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.5603, 1.4924, 1.4443, 1.4121, 1.3725, 1.3655, 1.3508, 1.3441, 1.3291, 1.3026]
#
# — Rank 700 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_700.pkl)
# Relative ℓ₂ error on singular values: 4.204e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.5745, 1.4558, 1.4462, 1.4245, 1.3896, 1.382, 1.3687, 1.3527, 1.3394, 1.3271]
#
# — Rank 725 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_725.pkl)
# Relative ℓ₂ error on singular values: 4.262e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.5907, 1.5027, 1.4455, 1.4159, 1.3913, 1.3717, 1.3617, 1.3462, 1.3382, 1.3116]
#
# — Rank 750 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_750.pkl)
# Relative ℓ₂ error on singular values: 4.275e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.5518, 1.4626, 1.4309, 1.4054, 1.3831, 1.3717, 1.3594, 1.3375, 1.3323, 1.324]
#
# — Rank 775 —  (E2EInvPics/MedMNIST/Matrices\breastmnist\rank_775.pkl)
# Relative ℓ₂ error on singular values: 4.319e-01
# Top 10 σ(M_r): [2.127, 1.7389, 1.7064, 1.6333, 1.6111, 1.5871, 1.5643, 1.5378, 1.5183, 1.5075]
# Top 10 σ(A)  : [1.5853, 1.4654, 1.4065, 1.382, 1.37, 1.3571, 1.3521, 1.3398, 1.3119, 1.2964]
#
# ══════════  CHESTMNIST  ══════════
#
# — Rank  25 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_025.pkl)
# Relative ℓ₂ error on singular values: 4.267e-01
# Top 10 σ(M_r): [2.2094, 2.1051, 1.9945, 1.8059, 1.3866, 1.2883, 1.2568, 1.2393, 1.2179, 1.1894]
# Top 10 σ(A)  : [2.5088, 2.2396, 2.1937, 2.0569, 2.0134, 1.9976, 1.9475, 1.9205, 1.8834, 1.8631]
#
# — Rank  50 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_050.pkl)
# Relative ℓ₂ error on singular values: 1.229e-01
# Top 10 σ(M_r): [2.6018, 2.4375, 2.3246, 2.2152, 1.8566, 1.7056, 1.6253, 1.5559, 1.4953, 1.3863]
# Top 10 σ(A)  : [2.162, 1.8516, 1.7952, 1.7682, 1.7362, 1.6888, 1.6431, 1.5512, 1.5275, 1.488]
#
# — Rank  75 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_075.pkl)
# Relative ℓ₂ error on singular values: 1.718e-01
# Top 10 σ(M_r): [2.6357, 2.5033, 2.3739, 2.274, 1.9063, 1.7665, 1.6929, 1.6043, 1.5734, 1.4526]
# Top 10 σ(A)  : [1.9801, 1.7223, 1.6451, 1.6291, 1.5786, 1.5736, 1.4888, 1.4179, 1.3808, 1.3652]
#
# — Rank 100 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_100.pkl)
# Relative ℓ₂ error on singular values: 1.899e-01
# Top 10 σ(M_r): [2.6413, 2.5094, 2.3782, 2.279, 1.9096, 1.7778, 1.6981, 1.6102, 1.5801, 1.4602]
# Top 10 σ(A)  : [1.9236, 1.6198, 1.5772, 1.5317, 1.5174, 1.4924, 1.457, 1.3917, 1.3524, 1.3437]
#
# — Rank 125 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_125.pkl)
# Relative ℓ₂ error on singular values: 2.043e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.7923, 1.6112, 1.5395, 1.5248, 1.4707, 1.4641, 1.4249, 1.3944, 1.323, 1.3078]
#
# — Rank 150 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_150.pkl)
# Relative ℓ₂ error on singular values: 2.163e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.8333, 1.6482, 1.5359, 1.4743, 1.4626, 1.4374, 1.4108, 1.3877, 1.3557, 1.3374]
#
# — Rank 175 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_175.pkl)
# Relative ℓ₂ error on singular values: 2.410e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.7269, 1.6742, 1.5403, 1.4895, 1.4621, 1.4114, 1.3788, 1.3518, 1.3448, 1.3292]
#
# — Rank 200 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_200.pkl)
# Relative ℓ₂ error on singular values: 2.680e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.6792, 1.6146, 1.5353, 1.4602, 1.4421, 1.4294, 1.3872, 1.3454, 1.331, 1.3266]
#
# — Rank 225 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_225.pkl)
# Relative ℓ₂ error on singular values: 2.900e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.7022, 1.669, 1.5424, 1.4807, 1.4454, 1.3914, 1.3636, 1.3467, 1.3172, 1.3039]
#
# — Rank 250 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_250.pkl)
# Relative ℓ₂ error on singular values: 3.150e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.6674, 1.6198, 1.553, 1.4833, 1.4231, 1.3952, 1.3591, 1.3333, 1.3002, 1.2932]
#
# — Rank 275 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_275.pkl)
# Relative ℓ₂ error on singular values: 3.318e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.7017, 1.6173, 1.5596, 1.4674, 1.4167, 1.402, 1.3756, 1.3445, 1.3185, 1.3016]
#
# — Rank 300 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_300.pkl)
# Relative ℓ₂ error on singular values: 3.470e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.7255, 1.5877, 1.5627, 1.5319, 1.4191, 1.4008, 1.3626, 1.3372, 1.3108, 1.2911]
#
# — Rank 325 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_325.pkl)
# Relative ℓ₂ error on singular values: 3.620e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.6955, 1.5903, 1.5427, 1.5031, 1.4175, 1.4069, 1.3689, 1.3183, 1.3045, 1.2976]
#
# — Rank 350 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_350.pkl)
# Relative ℓ₂ error on singular values: 3.748e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.7295, 1.5827, 1.5326, 1.5284, 1.474, 1.3959, 1.3777, 1.3451, 1.3224, 1.2842]
#
# — Rank 375 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_375.pkl)
# Relative ℓ₂ error on singular values: 3.851e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.7, 1.6186, 1.5411, 1.5261, 1.422, 1.406, 1.3626, 1.3218, 1.2967, 1.2891]
#
# — Rank 400 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_400.pkl)
# Relative ℓ₂ error on singular values: 3.964e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.7472, 1.6037, 1.5412, 1.5087, 1.4465, 1.4043, 1.37, 1.3493, 1.3131, 1.277]
#
# — Rank 425 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_425.pkl)
# Relative ℓ₂ error on singular values: 4.026e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.7278, 1.6183, 1.5418, 1.4986, 1.4365, 1.4174, 1.3889, 1.3418, 1.2982, 1.2908]
#
# — Rank 450 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_450.pkl)
# Relative ℓ₂ error on singular values: 4.146e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.7009, 1.5761, 1.5235, 1.5143, 1.4153, 1.4071, 1.3785, 1.3352, 1.3035, 1.2659]
#
# — Rank 475 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_475.pkl)
# Relative ℓ₂ error on singular values: 4.195e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.709, 1.6303, 1.5607, 1.5008, 1.4302, 1.3958, 1.3839, 1.3464, 1.3081, 1.286]
#
# — Rank 500 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_500.pkl)
# Relative ℓ₂ error on singular values: 4.260e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.7412, 1.5958, 1.5449, 1.4558, 1.4034, 1.3903, 1.3563, 1.3426, 1.3199, 1.2755]
#
# — Rank 525 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_525.pkl)
# Relative ℓ₂ error on singular values: 4.363e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.706, 1.5976, 1.505, 1.44, 1.3993, 1.3776, 1.3417, 1.3134, 1.2739, 1.2614]
#
# — Rank 550 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_550.pkl)
# Relative ℓ₂ error on singular values: 4.383e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.7341, 1.6179, 1.5367, 1.456, 1.4245, 1.422, 1.3764, 1.3341, 1.2903, 1.272]
#
# — Rank 575 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_575.pkl)
# Relative ℓ₂ error on singular values: 4.444e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.7389, 1.6216, 1.5449, 1.4186, 1.4137, 1.3857, 1.3628, 1.3414, 1.2857, 1.2758]
#
# — Rank 600 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_600.pkl)
# Relative ℓ₂ error on singular values: 4.500e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.7638, 1.6142, 1.5539, 1.4435, 1.4208, 1.3867, 1.3717, 1.3312, 1.2878, 1.2821]
#
# — Rank 625 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_625.pkl)
# Relative ℓ₂ error on singular values: 4.537e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.7254, 1.5951, 1.5427, 1.4343, 1.4075, 1.3628, 1.344, 1.3285, 1.296, 1.2757]
#
# — Rank 650 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_650.pkl)
# Relative ℓ₂ error on singular values: 4.571e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.7488, 1.6221, 1.5582, 1.4513, 1.4261, 1.3668, 1.3454, 1.3055, 1.2834, 1.2708]
#
# — Rank 675 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_675.pkl)
# Relative ℓ₂ error on singular values: 4.614e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.7401, 1.6127, 1.5472, 1.4309, 1.3842, 1.3724, 1.3486, 1.3067, 1.2871, 1.27]
#
# — Rank 700 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_700.pkl)
# Relative ℓ₂ error on singular values: 4.621e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.7577, 1.6454, 1.5604, 1.4724, 1.4216, 1.4142, 1.3703, 1.3238, 1.2918, 1.2778]
#
# — Rank 725 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_725.pkl)
# Relative ℓ₂ error on singular values: 4.670e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.7467, 1.6341, 1.5659, 1.4491, 1.4229, 1.3653, 1.3405, 1.3222, 1.2945, 1.2643]
#
# — Rank 750 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_750.pkl)
# Relative ℓ₂ error on singular values: 4.687e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.7438, 1.637, 1.5618, 1.4497, 1.4348, 1.3988, 1.3742, 1.323, 1.2931, 1.2676]
#
# — Rank 775 —  (E2EInvPics/MedMNIST/Matrices\chestmnist\rank_775.pkl)
# Relative ℓ₂ error on singular values: 4.698e-01
# Top 10 σ(M_r): [2.6417, 2.5098, 2.3784, 2.2795, 1.9099, 1.7783, 1.6985, 1.6104, 1.5804, 1.4607]
# Top 10 σ(A)  : [1.7635, 1.6274, 1.5799, 1.4851, 1.4461, 1.3974, 1.3646, 1.3279, 1.3032, 1.2806]
#
# ══════════  ORGANAMNIST  ══════════
#
# — Rank  25 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_025.pkl)
# Relative ℓ₂ error on singular values: 5.612e-01
# Top 10 σ(M_r): [1.4365, 1.4019, 1.3693, 1.2812, 1.2624, 1.2403, 1.2082, 1.1716, 1.1662, 1.1471]
# Top 10 σ(A)  : [2.4336, 2.2166, 2.1492, 2.0914, 2.0252, 1.9744, 1.9313, 1.9064, 1.8744, 1.8375]
#
# — Rank  50 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_050.pkl)
# Relative ℓ₂ error on singular values: 5.837e-02
# Top 10 σ(M_r): [1.906, 1.8129, 1.7932, 1.7252, 1.6611, 1.6119, 1.5741, 1.5207, 1.4795, 1.4741]
# Top 10 σ(A)  : [2.1159, 1.7974, 1.7238, 1.6993, 1.6819, 1.6184, 1.6126, 1.5818, 1.5505, 1.5289]
#
# — Rank  75 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_075.pkl)
# Relative ℓ₂ error on singular values: 1.943e-01
# Top 10 σ(M_r): [2.1846, 2.1487, 2.0587, 2.0148, 1.9685, 1.934, 1.9186, 1.8508, 1.8286, 1.776]
# Top 10 σ(A)  : [2.0226, 1.6617, 1.623, 1.5912, 1.5707, 1.5472, 1.5364, 1.4864, 1.4711, 1.4674]
#
# — Rank 100 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_100.pkl)
# Relative ℓ₂ error on singular values: 3.198e-01
# Top 10 σ(M_r): [2.3891, 2.3106, 2.2698, 2.2241, 2.14, 2.1152, 2.0843, 2.0658, 2.0375, 2.0103]
# Top 10 σ(A)  : [1.8557, 1.6043, 1.5786, 1.5586, 1.5439, 1.504, 1.4887, 1.4793, 1.4604, 1.4356]
#
# — Rank 125 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_125.pkl)
# Relative ℓ₂ error on singular values: 4.056e-01
# Top 10 σ(M_r): [2.492, 2.4638, 2.4319, 2.351, 2.3009, 2.2639, 2.2554, 2.191, 2.1686, 2.1635]
# Top 10 σ(A)  : [1.7526, 1.5385, 1.5153, 1.5077, 1.4826, 1.4756, 1.4502, 1.4355, 1.421, 1.4128]
#
# — Rank 150 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_150.pkl)
# Relative ℓ₂ error on singular values: 4.623e-01
# Top 10 σ(M_r): [2.5589, 2.5087, 2.4983, 2.3961, 2.3698, 2.3437, 2.3157, 2.274, 2.2562, 2.2353]
# Top 10 σ(A)  : [1.7241, 1.5627, 1.5522, 1.5318, 1.4815, 1.4678, 1.4485, 1.4444, 1.438, 1.4114]
#
# — Rank 175 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_175.pkl)
# Relative ℓ₂ error on singular values: 5.031e-01
# Top 10 σ(M_r): [2.5862, 2.538, 2.5255, 2.4365, 2.385, 2.361, 2.3335, 2.2965, 2.2882, 2.2619]
# Top 10 σ(A)  : [1.6933, 1.5351, 1.5046, 1.4975, 1.4953, 1.445, 1.434, 1.4279, 1.4245, 1.4154]
#
# — Rank 200 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_200.pkl)
# Relative ℓ₂ error on singular values: 5.331e-01
# Top 10 σ(M_r): [2.5945, 2.547, 2.5325, 2.4467, 2.3977, 2.3699, 2.3428, 2.3037, 2.2945, 2.2666]
# Top 10 σ(A)  : [1.6301, 1.5259, 1.4923, 1.4788, 1.4559, 1.452, 1.4351, 1.4215, 1.4128, 1.3951]
#
# — Rank 225 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_225.pkl)
# Relative ℓ₂ error on singular values: 5.476e-01
# Top 10 σ(M_r): [2.5974, 2.5496, 2.5362, 2.4504, 2.4005, 2.3717, 2.3447, 2.3054, 2.2955, 2.2687]
# Top 10 σ(A)  : [1.665, 1.5302, 1.4992, 1.4826, 1.4612, 1.4486, 1.4415, 1.4215, 1.4031, 1.3997]
#
# — Rank 250 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_250.pkl)
# Relative ℓ₂ error on singular values: 5.520e-01
# Top 10 σ(M_r): [2.5979, 2.5501, 2.5369, 2.451, 2.4012, 2.3722, 2.3453, 2.306, 2.2962, 2.2692]
# Top 10 σ(A)  : [1.5893, 1.5364, 1.5224, 1.4933, 1.4865, 1.452, 1.4415, 1.4222, 1.4164, 1.4078]
#
# — Rank 275 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_275.pkl)
# Relative ℓ₂ error on singular values: 5.523e-01
# Top 10 σ(M_r): [2.5981, 2.5502, 2.5372, 2.4512, 2.4013, 2.3723, 2.3454, 2.3061, 2.2963, 2.2693]
# Top 10 σ(A)  : [1.5428, 1.5263, 1.5148, 1.4851, 1.4616, 1.4536, 1.4474, 1.4345, 1.4012, 1.39]
#
# — Rank 300 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_300.pkl)
# Relative ℓ₂ error on singular values: 5.501e-01
# Top 10 σ(M_r): [2.5982, 2.5503, 2.5373, 2.4512, 2.4014, 2.3723, 2.3455, 2.3062, 2.2964, 2.2693]
# Top 10 σ(A)  : [1.5543, 1.5234, 1.5151, 1.4856, 1.4697, 1.4602, 1.4346, 1.4329, 1.4225, 1.3873]
#
# — Rank 325 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_325.pkl)
# Relative ℓ₂ error on singular values: 5.494e-01
# Top 10 σ(M_r): [2.5982, 2.5503, 2.5373, 2.4512, 2.4014, 2.3723, 2.3455, 2.3062, 2.2964, 2.2693]
# Top 10 σ(A)  : [1.5636, 1.5101, 1.502, 1.4805, 1.4602, 1.4497, 1.4375, 1.4305, 1.4126, 1.4084]
#
# — Rank 350 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_350.pkl)
# Relative ℓ₂ error on singular values: 5.432e-01
# Top 10 σ(M_r): [2.5982, 2.5503, 2.5373, 2.4512, 2.4014, 2.3723, 2.3455, 2.3062, 2.2964, 2.2693]
# Top 10 σ(A)  : [1.6109, 1.5478, 1.5406, 1.5034, 1.4883, 1.4735, 1.447, 1.44, 1.4246, 1.4102]
#
# — Rank 375 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_375.pkl)
# Relative ℓ₂ error on singular values: 5.393e-01
# Top 10 σ(M_r): [2.5982, 2.5503, 2.5373, 2.4512, 2.4014, 2.3723, 2.3455, 2.3062, 2.2964, 2.2693]
# Top 10 σ(A)  : [1.5818, 1.5632, 1.5345, 1.4983, 1.4829, 1.4575, 1.4559, 1.4454, 1.4159, 1.4138]
#
# — Rank 400 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_400.pkl)
# Relative ℓ₂ error on singular values: 5.392e-01
# Top 10 σ(M_r): [2.5982, 2.5503, 2.5373, 2.4512, 2.4014, 2.3723, 2.3455, 2.3062, 2.2964, 2.2693]
# Top 10 σ(A)  : [1.5861, 1.5435, 1.5192, 1.478, 1.4732, 1.441, 1.4325, 1.4156, 1.4091, 1.3963]
#
# — Rank 425 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_425.pkl)
# Relative ℓ₂ error on singular values: 5.356e-01
# Top 10 σ(M_r): [2.5982, 2.5503, 2.5373, 2.4512, 2.4014, 2.3723, 2.3455, 2.3062, 2.2964, 2.2693]
# Top 10 σ(A)  : [1.5851, 1.5669, 1.4991, 1.4618, 1.4605, 1.4486, 1.44, 1.4301, 1.4244, 1.3911]
#
# — Rank 450 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_450.pkl)
# Relative ℓ₂ error on singular values: 5.330e-01
# Top 10 σ(M_r): [2.5982, 2.5503, 2.5373, 2.4512, 2.4014, 2.3723, 2.3455, 2.3062, 2.2964, 2.2693]
# Top 10 σ(A)  : [1.5798, 1.5547, 1.5406, 1.4981, 1.4684, 1.4519, 1.4408, 1.4281, 1.4114, 1.3935]
#
# — Rank 475 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_475.pkl)
# Relative ℓ₂ error on singular values: 5.292e-01
# Top 10 σ(M_r): [2.5982, 2.5503, 2.5373, 2.4512, 2.4014, 2.3723, 2.3455, 2.3062, 2.2964, 2.2693]
# Top 10 σ(A)  : [1.6, 1.5832, 1.5108, 1.5068, 1.4919, 1.4522, 1.4395, 1.4349, 1.4262, 1.4057]
#
# — Rank 500 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_500.pkl)
# Relative ℓ₂ error on singular values: 5.289e-01
# Top 10 σ(M_r): [2.5982, 2.5503, 2.5373, 2.4512, 2.4014, 2.3723, 2.3455, 2.3062, 2.2964, 2.2693]
# Top 10 σ(A)  : [1.5995, 1.5481, 1.5126, 1.4867, 1.4655, 1.4604, 1.4474, 1.4368, 1.4252, 1.4167]
#
# — Rank 525 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_525.pkl)
# Relative ℓ₂ error on singular values: 5.297e-01
# Top 10 σ(M_r): [2.5982, 2.5503, 2.5373, 2.4512, 2.4014, 2.3723, 2.3455, 2.3062, 2.2964, 2.2693]
# Top 10 σ(A)  : [1.5794, 1.5635, 1.5359, 1.4874, 1.4753, 1.4501, 1.44, 1.4223, 1.4077, 1.4041]
#
# — Rank 550 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_550.pkl)
# Relative ℓ₂ error on singular values: 5.231e-01
# Top 10 σ(M_r): [2.5982, 2.5503, 2.5373, 2.4512, 2.4014, 2.3723, 2.3455, 2.3062, 2.2964, 2.2693]
# Top 10 σ(A)  : [1.5853, 1.5752, 1.5321, 1.5305, 1.4912, 1.4776, 1.4544, 1.4344, 1.4287, 1.4203]
#
# — Rank 575 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_575.pkl)
# Relative ℓ₂ error on singular values: 5.207e-01
# Top 10 σ(M_r): [2.5982, 2.5503, 2.5373, 2.4512, 2.4014, 2.3723, 2.3455, 2.3062, 2.2964, 2.2693]
# Top 10 σ(A)  : [1.6086, 1.588, 1.5342, 1.5258, 1.4963, 1.4812, 1.4681, 1.4425, 1.4339, 1.4203]
#
# — Rank 600 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_600.pkl)
# Relative ℓ₂ error on singular values: 5.215e-01
# Top 10 σ(M_r): [2.5982, 2.5503, 2.5373, 2.4512, 2.4014, 2.3723, 2.3455, 2.3062, 2.2964, 2.2693]
# Top 10 σ(A)  : [1.6003, 1.5686, 1.5519, 1.5179, 1.5126, 1.4733, 1.4443, 1.4362, 1.4311, 1.413]
#
# — Rank 625 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_625.pkl)
# Relative ℓ₂ error on singular values: 5.228e-01
# Top 10 σ(M_r): [2.5982, 2.5503, 2.5373, 2.4512, 2.4014, 2.3723, 2.3455, 2.3062, 2.2964, 2.2693]
# Top 10 σ(A)  : [1.5951, 1.5773, 1.531, 1.5064, 1.4895, 1.4662, 1.4571, 1.4408, 1.4156, 1.4111]
#
# — Rank 650 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_650.pkl)
# Relative ℓ₂ error on singular values: 5.211e-01
# Top 10 σ(M_r): [2.5982, 2.5503, 2.5373, 2.4512, 2.4014, 2.3723, 2.3455, 2.3062, 2.2964, 2.2693]
# Top 10 σ(A)  : [1.6016, 1.5863, 1.5366, 1.5314, 1.5003, 1.4694, 1.4546, 1.4407, 1.4377, 1.4166]
#
# — Rank 675 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_675.pkl)
# Relative ℓ₂ error on singular values: 5.184e-01
# Top 10 σ(M_r): [2.5982, 2.5503, 2.5373, 2.4512, 2.4014, 2.3723, 2.3455, 2.3062, 2.2964, 2.2693]
# Top 10 σ(A)  : [1.62, 1.6002, 1.5488, 1.5173, 1.5073, 1.4886, 1.4703, 1.4509, 1.4315, 1.4226]
#
# — Rank 700 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_700.pkl)
# Relative ℓ₂ error on singular values: 5.195e-01
# Top 10 σ(M_r): [2.5982, 2.5503, 2.5373, 2.4512, 2.4014, 2.3723, 2.3455, 2.3062, 2.2964, 2.2693]
# Top 10 σ(A)  : [1.6032, 1.5797, 1.5268, 1.5162, 1.4989, 1.4805, 1.4765, 1.4365, 1.4192, 1.4081]
#
# — Rank 725 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_725.pkl)
# Relative ℓ₂ error on singular values: 5.170e-01
# Top 10 σ(M_r): [2.5982, 2.5503, 2.5373, 2.4512, 2.4014, 2.3723, 2.3455, 2.3062, 2.2964, 2.2693]
# Top 10 σ(A)  : [1.6205, 1.6147, 1.5636, 1.5226, 1.5064, 1.4746, 1.4558, 1.4412, 1.4274, 1.4173]
#
# — Rank 750 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_750.pkl)
# Relative ℓ₂ error on singular values: 5.176e-01
# Top 10 σ(M_r): [2.5982, 2.5503, 2.5373, 2.4512, 2.4014, 2.3723, 2.3455, 2.3062, 2.2964, 2.2693]
# Top 10 σ(A)  : [1.604, 1.5929, 1.5528, 1.5145, 1.4815, 1.4636, 1.4623, 1.4357, 1.4246, 1.4197]
#
# — Rank 775 —  (E2EInvPics/MedMNIST/Matrices\organamnist\rank_775.pkl)
# Relative ℓ₂ error on singular values: 5.159e-01
# Top 10 σ(M_r): [2.5982, 2.5503, 2.5373, 2.4512, 2.4014, 2.3723, 2.3455, 2.3062, 2.2964, 2.2693]
# Top 10 σ(A)  : [1.6217, 1.6021, 1.5481, 1.5227, 1.4971, 1.4825, 1.4719, 1.4467, 1.4248, 1.4188]
#
# ══════════  ORGANCMNIST  ══════════
#
# — Rank  25 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_025.pkl)
# Relative ℓ₂ error on singular values: 5.640e-01
# Top 10 σ(M_r): [1.4839, 1.3648, 1.3173, 1.2742, 1.2512, 1.2158, 1.2002, 1.1711, 1.1574, 1.1454]
# Top 10 σ(A)  : [2.454, 2.1372, 2.0781, 2.0588, 2.0028, 1.968, 1.9523, 1.8653, 1.8529, 1.8271]
#
# — Rank  50 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_050.pkl)
# Relative ℓ₂ error on singular values: 6.625e-02
# Top 10 σ(M_r): [2.0328, 1.863, 1.686, 1.6265, 1.5959, 1.5717, 1.5126, 1.4815, 1.4629, 1.438]
# Top 10 σ(A)  : [2.2255, 1.751, 1.7361, 1.7065, 1.6864, 1.635, 1.6038, 1.5726, 1.5465, 1.5422]
#
# — Rank  75 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_075.pkl)
# Relative ℓ₂ error on singular values: 1.892e-01
# Top 10 σ(M_r): [2.4049, 2.2805, 1.9949, 1.9584, 1.939, 1.8926, 1.8412, 1.8369, 1.7885, 1.768]
# Top 10 σ(A)  : [1.9671, 1.6759, 1.6392, 1.6066, 1.5774, 1.5624, 1.5539, 1.5418, 1.512, 1.4771]
#
# — Rank 100 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_100.pkl)
# Relative ℓ₂ error on singular values: 3.250e-01
# Top 10 σ(M_r): [2.5751, 2.5277, 2.26, 2.2009, 2.1653, 2.1187, 2.0847, 2.0504, 2.019, 1.9919]
# Top 10 σ(A)  : [1.9586, 1.5805, 1.5533, 1.5318, 1.5193, 1.4964, 1.4807, 1.4642, 1.4561, 1.4263]
#
# — Rank 125 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_125.pkl)
# Relative ℓ₂ error on singular values: 4.072e-01
# Top 10 σ(M_r): [2.6644, 2.5786, 2.3613, 2.3412, 2.2865, 2.2339, 2.2308, 2.1609, 2.151, 2.133]
# Top 10 σ(A)  : [1.8598, 1.5483, 1.5383, 1.5132, 1.4877, 1.4697, 1.4467, 1.4352, 1.4233, 1.404]
#
# — Rank 150 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_150.pkl)
# Relative ℓ₂ error on singular values: 4.643e-01
# Top 10 σ(M_r): [2.6983, 2.6159, 2.4142, 2.3729, 2.3344, 2.2896, 2.2815, 2.2263, 2.2079, 2.1738]
# Top 10 σ(A)  : [1.6941, 1.5368, 1.5141, 1.4978, 1.4624, 1.4463, 1.4196, 1.4169, 1.3946, 1.3914]
#
# — Rank 175 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_175.pkl)
# Relative ℓ₂ error on singular values: 5.078e-01
# Top 10 σ(M_r): [2.7195, 2.6327, 2.4438, 2.3939, 2.3528, 2.3087, 2.3005, 2.2434, 2.2238, 2.1954]
# Top 10 σ(A)  : [1.6264, 1.5031, 1.4841, 1.4688, 1.445, 1.4262, 1.4179, 1.4051, 1.3917, 1.3847]
#
# — Rank 200 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_200.pkl)
# Relative ℓ₂ error on singular values: 5.324e-01
# Top 10 σ(M_r): [2.7263, 2.6344, 2.4456, 2.399, 2.3562, 2.3138, 2.3105, 2.2458, 2.2314, 2.1988]
# Top 10 σ(A)  : [1.7014, 1.559, 1.4872, 1.4811, 1.4403, 1.4246, 1.4142, 1.4099, 1.3918, 1.38]
#
# — Rank 225 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_225.pkl)
# Relative ℓ₂ error on singular values: 5.450e-01
# Top 10 σ(M_r): [2.7283, 2.6359, 2.448, 2.401, 2.3581, 2.315, 2.3122, 2.2463, 2.2327, 2.1999]
# Top 10 σ(A)  : [1.6235, 1.5415, 1.473, 1.4553, 1.4382, 1.4165, 1.4062, 1.3867, 1.3823, 1.3721]
#
# — Rank 250 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_250.pkl)
# Relative ℓ₂ error on singular values: 5.488e-01
# Top 10 σ(M_r): [2.7292, 2.636, 2.4485, 2.4016, 2.3583, 2.3153, 2.3128, 2.2465, 2.2332, 2.2001]
# Top 10 σ(A)  : [1.6075, 1.5517, 1.4823, 1.4583, 1.4495, 1.4428, 1.4178, 1.4069, 1.3979, 1.3843]
#
# — Rank 275 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_275.pkl)
# Relative ℓ₂ error on singular values: 5.495e-01
# Top 10 σ(M_r): [2.7293, 2.6362, 2.4486, 2.4017, 2.3584, 2.3154, 2.3128, 2.2465, 2.2333, 2.2001]
# Top 10 σ(A)  : [1.58, 1.5281, 1.4672, 1.448, 1.4393, 1.4112, 1.4004, 1.393, 1.3857, 1.3785]
#
# — Rank 300 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_300.pkl)
# Relative ℓ₂ error on singular values: 5.474e-01
# Top 10 σ(M_r): [2.7293, 2.6362, 2.4487, 2.4018, 2.3584, 2.3154, 2.3129, 2.2465, 2.2333, 2.2001]
# Top 10 σ(A)  : [1.6169, 1.5495, 1.4825, 1.4637, 1.4426, 1.419, 1.3942, 1.3855, 1.375, 1.3675]
#
# — Rank 325 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_325.pkl)
# Relative ℓ₂ error on singular values: 5.434e-01
# Top 10 σ(M_r): [2.7293, 2.6362, 2.4487, 2.4018, 2.3584, 2.3154, 2.3129, 2.2465, 2.2333, 2.2002]
# Top 10 σ(A)  : [1.5643, 1.5086, 1.47, 1.4504, 1.4382, 1.4231, 1.4066, 1.395, 1.3817, 1.3595]
#
# — Rank 350 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_350.pkl)
# Relative ℓ₂ error on singular values: 5.419e-01
# Top 10 σ(M_r): [2.7293, 2.6362, 2.4487, 2.4018, 2.3584, 2.3154, 2.3129, 2.2466, 2.2333, 2.2002]
# Top 10 σ(A)  : [1.5412, 1.4869, 1.4703, 1.459, 1.4384, 1.4216, 1.4119, 1.3972, 1.3795, 1.3661]
#
# — Rank 375 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_375.pkl)
# Relative ℓ₂ error on singular values: 5.408e-01
# Top 10 σ(M_r): [2.7293, 2.6362, 2.4487, 2.4018, 2.3584, 2.3154, 2.3129, 2.2465, 2.2333, 2.2002]
# Top 10 σ(A)  : [1.5519, 1.5119, 1.4843, 1.4579, 1.4382, 1.4201, 1.4071, 1.3947, 1.3755, 1.3675]
#
# — Rank 400 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_400.pkl)
# Relative ℓ₂ error on singular values: 5.331e-01
# Top 10 σ(M_r): [2.7293, 2.6362, 2.4487, 2.4018, 2.3584, 2.3154, 2.3129, 2.2466, 2.2333, 2.2002]
# Top 10 σ(A)  : [1.5734, 1.5325, 1.498, 1.464, 1.4591, 1.4198, 1.4114, 1.4042, 1.3958, 1.385]
#
# — Rank 425 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_425.pkl)
# Relative ℓ₂ error on singular values: 5.337e-01
# Top 10 σ(M_r): [2.7293, 2.6362, 2.4487, 2.4018, 2.3584, 2.3154, 2.3129, 2.2465, 2.2333, 2.2002]
# Top 10 σ(A)  : [1.5388, 1.5136, 1.495, 1.4585, 1.4332, 1.4137, 1.404, 1.4002, 1.3804, 1.3761]
#
# — Rank 450 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_450.pkl)
# Relative ℓ₂ error on singular values: 5.288e-01
# Top 10 σ(M_r): [2.7293, 2.6362, 2.4487, 2.4018, 2.3584, 2.3154, 2.3129, 2.2466, 2.2333, 2.2002]
# Top 10 σ(A)  : [1.5769, 1.505, 1.4826, 1.4696, 1.4468, 1.4135, 1.4065, 1.3903, 1.3768, 1.3749]
#
# — Rank 475 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_475.pkl)
# Relative ℓ₂ error on singular values: 5.276e-01
# Top 10 σ(M_r): [2.7293, 2.6362, 2.4487, 2.4018, 2.3584, 2.3154, 2.3129, 2.2465, 2.2333, 2.2002]
# Top 10 σ(A)  : [1.5555, 1.5194, 1.4763, 1.4503, 1.4416, 1.4238, 1.4135, 1.3924, 1.3809, 1.376]
#
# — Rank 500 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_500.pkl)
# Relative ℓ₂ error on singular values: 5.285e-01
# Top 10 σ(M_r): [2.7293, 2.6362, 2.4487, 2.4018, 2.3584, 2.3154, 2.3129, 2.2466, 2.2333, 2.2002]
# Top 10 σ(A)  : [1.5603, 1.5099, 1.455, 1.4463, 1.4309, 1.4133, 1.4088, 1.3845, 1.3808, 1.3723]
#
# — Rank 525 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_525.pkl)
# Relative ℓ₂ error on singular values: 5.261e-01
# Top 10 σ(M_r): [2.7293, 2.6362, 2.4487, 2.4018, 2.3584, 2.3154, 2.3129, 2.2465, 2.2333, 2.2002]
# Top 10 σ(A)  : [1.5367, 1.5296, 1.4862, 1.4656, 1.4433, 1.4387, 1.4249, 1.4029, 1.391, 1.3741]
#
# — Rank 550 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_550.pkl)
# Relative ℓ₂ error on singular values: 5.236e-01
# Top 10 σ(M_r): [2.7293, 2.6362, 2.4487, 2.4018, 2.3584, 2.3154, 2.3129, 2.2466, 2.2333, 2.2002]
# Top 10 σ(A)  : [1.5417, 1.5347, 1.5018, 1.454, 1.4331, 1.4182, 1.3929, 1.3909, 1.3827, 1.3723]
#
# — Rank 575 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_575.pkl)
# Relative ℓ₂ error on singular values: 5.220e-01
# Top 10 σ(M_r): [2.7293, 2.6362, 2.4487, 2.4018, 2.3584, 2.3154, 2.3129, 2.2466, 2.2333, 2.2002]
# Top 10 σ(A)  : [1.5744, 1.5336, 1.496, 1.4516, 1.439, 1.4321, 1.4163, 1.4064, 1.3814, 1.375]
#
# — Rank 600 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_600.pkl)
# Relative ℓ₂ error on singular values: 5.235e-01
# Top 10 σ(M_r): [2.7293, 2.6362, 2.4487, 2.4018, 2.3584, 2.3154, 2.3129, 2.2466, 2.2333, 2.2002]
# Top 10 σ(A)  : [1.5717, 1.5326, 1.4748, 1.4556, 1.44, 1.4335, 1.4149, 1.4079, 1.3887, 1.3876]
#
# — Rank 625 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_625.pkl)
# Relative ℓ₂ error on singular values: 5.206e-01
# Top 10 σ(M_r): [2.7293, 2.6362, 2.4487, 2.4018, 2.3584, 2.3154, 2.3129, 2.2466, 2.2333, 2.2002]
# Top 10 σ(A)  : [1.5836, 1.557, 1.4818, 1.4657, 1.447, 1.4305, 1.4202, 1.4128, 1.4106, 1.3822]
#
# — Rank 650 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_650.pkl)
# Relative ℓ₂ error on singular values: 5.215e-01
# Top 10 σ(M_r): [2.7293, 2.6362, 2.4487, 2.4018, 2.3584, 2.3154, 2.3129, 2.2466, 2.2333, 2.2002]
# Top 10 σ(A)  : [1.5809, 1.5641, 1.4821, 1.4639, 1.4332, 1.4139, 1.4067, 1.3941, 1.3871, 1.3672]
#
# — Rank 675 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_675.pkl)
# Relative ℓ₂ error on singular values: 5.187e-01
# Top 10 σ(M_r): [2.7293, 2.6362, 2.4487, 2.4018, 2.3584, 2.3154, 2.3129, 2.2466, 2.2333, 2.2002]
# Top 10 σ(A)  : [1.564, 1.5359, 1.5036, 1.4712, 1.4463, 1.4303, 1.4132, 1.4092, 1.3959, 1.3945]
#
# — Rank 700 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_700.pkl)
# Relative ℓ₂ error on singular values: 5.160e-01
# Top 10 σ(M_r): [2.7293, 2.6362, 2.4487, 2.4018, 2.3584, 2.3154, 2.3129, 2.2466, 2.2333, 2.2002]
# Top 10 σ(A)  : [1.5724, 1.5595, 1.5178, 1.4913, 1.4695, 1.452, 1.4316, 1.4159, 1.4114, 1.3958]
#
# — Rank 725 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_725.pkl)
# Relative ℓ₂ error on singular values: 5.152e-01
# Top 10 σ(M_r): [2.7293, 2.6362, 2.4487, 2.4018, 2.3584, 2.3154, 2.3129, 2.2466, 2.2333, 2.2002]
# Top 10 σ(A)  : [1.5866, 1.5783, 1.5132, 1.4897, 1.47, 1.4414, 1.4332, 1.4088, 1.3995, 1.3859]
#
# — Rank 750 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_750.pkl)
# Relative ℓ₂ error on singular values: 5.178e-01
# Top 10 σ(M_r): [2.7293, 2.6362, 2.4487, 2.4018, 2.3584, 2.3154, 2.3129, 2.2466, 2.2333, 2.2002]
# Top 10 σ(A)  : [1.5721, 1.5487, 1.4929, 1.4575, 1.4458, 1.4331, 1.4198, 1.4084, 1.3888, 1.3822]
#
# — Rank 775 —  (E2EInvPics/MedMNIST/Matrices\organcmnist\rank_775.pkl)
# Relative ℓ₂ error on singular values: 5.147e-01
# Top 10 σ(M_r): [2.7293, 2.6362, 2.4487, 2.4018, 2.3584, 2.3154, 2.3129, 2.2466, 2.2333, 2.2002]
# Top 10 σ(A)  : [1.6037, 1.5472, 1.5182, 1.4788, 1.4425, 1.4372, 1.4252, 1.4105, 1.3928, 1.3804]
#
# ══════════  ORGANSMNIST  ══════════
#
# — Rank  25 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_025.pkl)
# Relative ℓ₂ error on singular values: 5.878e-01
# Top 10 σ(M_r): [1.5236, 1.3348, 1.3043, 1.2741, 1.2374, 1.1854, 1.1741, 1.1656, 1.1369, 1.1292]
# Top 10 σ(A)  : [2.5628, 2.1543, 2.0923, 2.0815, 2.0645, 1.9632, 1.9422, 1.9031, 1.8571, 1.845]
#
# — Rank  50 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_050.pkl)
# Relative ℓ₂ error on singular values: 7.948e-02
# Top 10 σ(M_r): [1.9472, 1.8265, 1.7128, 1.6602, 1.5857, 1.5445, 1.473, 1.4406, 1.4159, 1.4055]
# Top 10 σ(A)  : [2.1868, 1.768, 1.7141, 1.7, 1.6704, 1.6583, 1.644, 1.6001, 1.5753, 1.5604]
#
# — Rank  75 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_075.pkl)
# Relative ℓ₂ error on singular values: 1.827e-01
# Top 10 σ(M_r): [2.2313, 2.1337, 2.0568, 1.9089, 1.8652, 1.8214, 1.798, 1.7483, 1.6727, 1.6624]
# Top 10 σ(A)  : [1.9532, 1.6662, 1.6339, 1.6299, 1.5649, 1.5474, 1.5255, 1.5181, 1.4702, 1.4609]
#
# — Rank 100 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_100.pkl)
# Relative ℓ₂ error on singular values: 3.138e-01
# Top 10 σ(M_r): [2.4746, 2.2824, 2.2615, 2.1231, 2.0919, 1.9949, 1.9786, 1.941, 1.9077, 1.8896]
# Top 10 σ(A)  : [1.9624, 1.5649, 1.5429, 1.5323, 1.5087, 1.5028, 1.4788, 1.4609, 1.4556, 1.4337]
#
# — Rank 125 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_125.pkl)
# Relative ℓ₂ error on singular values: 4.039e-01
# Top 10 σ(M_r): [2.5122, 2.4077, 2.3536, 2.2576, 2.2054, 2.1821, 2.0963, 2.0807, 2.0376, 2.0094]
# Top 10 σ(A)  : [1.8194, 1.5585, 1.4917, 1.4754, 1.4568, 1.4458, 1.4371, 1.4156, 1.4042, 1.4002]
#
# — Rank 150 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_150.pkl)
# Relative ℓ₂ error on singular values: 4.622e-01
# Top 10 σ(M_r): [2.593, 2.4522, 2.4082, 2.302, 2.2729, 2.2394, 2.1513, 2.1314, 2.1195, 2.0601]
# Top 10 σ(A)  : [1.7603, 1.5282, 1.4831, 1.4749, 1.4324, 1.4268, 1.4146, 1.4064, 1.3906, 1.3726]
#
# — Rank 175 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_175.pkl)
# Relative ℓ₂ error on singular values: 5.024e-01
# Top 10 σ(M_r): [2.6055, 2.4873, 2.4304, 2.3156, 2.2973, 2.2559, 2.1719, 2.1528, 2.1404, 2.0744]
# Top 10 σ(A)  : [1.6831, 1.5191, 1.4681, 1.4474, 1.436, 1.4286, 1.3946, 1.3905, 1.3801, 1.3603]
#
# — Rank 200 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_200.pkl)
# Relative ℓ₂ error on singular values: 5.271e-01
# Top 10 σ(M_r): [2.615, 2.4916, 2.4347, 2.3226, 2.2998, 2.2608, 2.1802, 2.1565, 2.1451, 2.0817]
# Top 10 σ(A)  : [1.6487, 1.4983, 1.4664, 1.4399, 1.4302, 1.4247, 1.4141, 1.4038, 1.3903, 1.3646]
#
# — Rank 225 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_225.pkl)
# Relative ℓ₂ error on singular values: 5.393e-01
# Top 10 σ(M_r): [2.6157, 2.4934, 2.4358, 2.3236, 2.3009, 2.2621, 2.1818, 2.1575, 2.1458, 2.0834]
# Top 10 σ(A)  : [1.6684, 1.4922, 1.4601, 1.4422, 1.4192, 1.3963, 1.38, 1.3675, 1.3513, 1.3471]
#
# — Rank 250 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_250.pkl)
# Relative ℓ₂ error on singular values: 5.457e-01
# Top 10 σ(M_r): [2.6164, 2.4937, 2.436, 2.324, 2.3011, 2.2624, 2.1821, 2.1578, 2.1462, 2.0838]
# Top 10 σ(A)  : [1.5935, 1.4657, 1.4581, 1.4337, 1.4153, 1.3995, 1.3893, 1.3742, 1.3652, 1.3513]
#
# — Rank 275 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_275.pkl)
# Relative ℓ₂ error on singular values: 5.425e-01
# Top 10 σ(M_r): [2.6165, 2.4938, 2.436, 2.3241, 2.3012, 2.2625, 2.1824, 2.1578, 2.1463, 2.0838]
# Top 10 σ(A)  : [1.5781, 1.5019, 1.4661, 1.4176, 1.414, 1.3993, 1.3775, 1.3677, 1.3621, 1.3463]
#
# — Rank 300 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_300.pkl)
# Relative ℓ₂ error on singular values: 5.428e-01
# Top 10 σ(M_r): [2.6165, 2.4938, 2.4361, 2.3241, 2.3012, 2.2625, 2.1824, 2.1579, 2.1463, 2.0839]
# Top 10 σ(A)  : [1.5457, 1.489, 1.4364, 1.4259, 1.4124, 1.4049, 1.3868, 1.3799, 1.374, 1.3547]
#
# — Rank 325 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_325.pkl)
# Relative ℓ₂ error on singular values: 5.397e-01
# Top 10 σ(M_r): [2.6165, 2.4938, 2.4361, 2.3241, 2.3012, 2.2625, 2.1824, 2.1579, 2.1463, 2.0839]
# Top 10 σ(A)  : [1.5256, 1.505, 1.4536, 1.4163, 1.4036, 1.3841, 1.3699, 1.3647, 1.356, 1.3366]
#
# — Rank 350 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_350.pkl)
# Relative ℓ₂ error on singular values: 5.332e-01
# Top 10 σ(M_r): [2.6165, 2.4938, 2.4361, 2.3241, 2.3012, 2.2625, 2.1824, 2.1579, 2.1463, 2.0839]
# Top 10 σ(A)  : [1.5399, 1.4622, 1.4474, 1.429, 1.4143, 1.4047, 1.3841, 1.378, 1.3653, 1.3546]
#
# — Rank 375 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_375.pkl)
# Relative ℓ₂ error on singular values: 5.312e-01
# Top 10 σ(M_r): [2.6165, 2.4938, 2.4361, 2.3241, 2.3012, 2.2625, 2.1824, 2.1579, 2.1463, 2.0839]
# Top 10 σ(A)  : [1.5172, 1.4688, 1.4521, 1.4396, 1.4118, 1.3958, 1.3926, 1.3855, 1.3755, 1.3561]
#
# — Rank 400 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_400.pkl)
# Relative ℓ₂ error on singular values: 5.286e-01
# Top 10 σ(M_r): [2.6165, 2.4938, 2.4361, 2.3241, 2.3012, 2.2625, 2.1824, 2.1579, 2.1463, 2.0839]
# Top 10 σ(A)  : [1.5115, 1.4674, 1.4565, 1.4299, 1.41, 1.4049, 1.392, 1.3839, 1.3647, 1.3466]
#
# — Rank 425 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_425.pkl)
# Relative ℓ₂ error on singular values: 5.242e-01
# Top 10 σ(M_r): [2.6165, 2.4938, 2.4361, 2.3241, 2.3012, 2.2625, 2.1824, 2.1579, 2.1463, 2.0839]
# Top 10 σ(A)  : [1.5667, 1.5058, 1.4863, 1.4336, 1.4249, 1.4125, 1.4001, 1.3691, 1.3651, 1.3533]
#
# — Rank 450 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_450.pkl)
# Relative ℓ₂ error on singular values: 5.245e-01
# Top 10 σ(M_r): [2.6165, 2.4938, 2.4361, 2.3241, 2.3012, 2.2625, 2.1824, 2.1579, 2.1463, 2.0839]
# Top 10 σ(A)  : [1.5336, 1.4821, 1.4528, 1.4395, 1.4047, 1.396, 1.3794, 1.3747, 1.3626, 1.3573]
#
# — Rank 475 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_475.pkl)
# Relative ℓ₂ error on singular values: 5.198e-01
# Top 10 σ(M_r): [2.6165, 2.4938, 2.4361, 2.3241, 2.3012, 2.2625, 2.1824, 2.1579, 2.1463, 2.0839]
# Top 10 σ(A)  : [1.5471, 1.4515, 1.446, 1.4356, 1.4215, 1.3942, 1.3916, 1.377, 1.366, 1.3582]
#
# — Rank 500 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_500.pkl)
# Relative ℓ₂ error on singular values: 5.235e-01
# Top 10 σ(M_r): [2.6165, 2.4938, 2.4361, 2.3241, 2.3012, 2.2625, 2.1824, 2.1579, 2.1463, 2.0839]
# Top 10 σ(A)  : [1.5186, 1.4488, 1.4209, 1.4132, 1.3992, 1.3968, 1.3876, 1.3616, 1.3576, 1.3496]
#
# — Rank 525 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_525.pkl)
# Relative ℓ₂ error on singular values: 5.212e-01
# Top 10 σ(M_r): [2.6165, 2.4938, 2.4361, 2.3241, 2.3012, 2.2625, 2.1824, 2.1579, 2.1463, 2.0839]
# Top 10 σ(A)  : [1.5335, 1.4961, 1.4564, 1.4279, 1.4089, 1.3923, 1.383, 1.3753, 1.3618, 1.3539]
#
# — Rank 550 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_550.pkl)
# Relative ℓ₂ error on singular values: 5.207e-01
# Top 10 σ(M_r): [2.6165, 2.4938, 2.4361, 2.3241, 2.3012, 2.2625, 2.1824, 2.1579, 2.1463, 2.0839]
# Top 10 σ(A)  : [1.5651, 1.5177, 1.4537, 1.4336, 1.4126, 1.4028, 1.3956, 1.3908, 1.3638, 1.3576]
#
# — Rank 575 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_575.pkl)
# Relative ℓ₂ error on singular values: 5.161e-01
# Top 10 σ(M_r): [2.6165, 2.4938, 2.4361, 2.3241, 2.3012, 2.2625, 2.1824, 2.1579, 2.1463, 2.0839]
# Top 10 σ(A)  : [1.5474, 1.5013, 1.4588, 1.4433, 1.4333, 1.4113, 1.3987, 1.3889, 1.3737, 1.3697]
#
# — Rank 600 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_600.pkl)
# Relative ℓ₂ error on singular values: 5.178e-01
# Top 10 σ(M_r): [2.6165, 2.4938, 2.4361, 2.3241, 2.3012, 2.2625, 2.1824, 2.1579, 2.1463, 2.0839]
# Top 10 σ(A)  : [1.5312, 1.4714, 1.4363, 1.4228, 1.4099, 1.3948, 1.3832, 1.3714, 1.368, 1.3532]
#
# — Rank 625 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_625.pkl)
# Relative ℓ₂ error on singular values: 5.144e-01
# Top 10 σ(M_r): [2.6165, 2.4938, 2.4361, 2.3241, 2.3012, 2.2625, 2.1824, 2.1579, 2.1463, 2.0839]
# Top 10 σ(A)  : [1.5624, 1.481, 1.4649, 1.4309, 1.4151, 1.4119, 1.3855, 1.3764, 1.3742, 1.3486]
#
# — Rank 650 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_650.pkl)
# Relative ℓ₂ error on singular values: 5.139e-01
# Top 10 σ(M_r): [2.6165, 2.4938, 2.4361, 2.3241, 2.3012, 2.2625, 2.1824, 2.1579, 2.1463, 2.0839]
# Top 10 σ(A)  : [1.5513, 1.4877, 1.4522, 1.4342, 1.4244, 1.4103, 1.4037, 1.3865, 1.3759, 1.3742]
#
# — Rank 675 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_675.pkl)
# Relative ℓ₂ error on singular values: 5.144e-01
# Top 10 σ(M_r): [2.6165, 2.4938, 2.4361, 2.3241, 2.3012, 2.2625, 2.1824, 2.1579, 2.1463, 2.0839]
# Top 10 σ(A)  : [1.519, 1.4893, 1.4373, 1.4343, 1.4041, 1.3989, 1.3857, 1.375, 1.3686, 1.3644]
#
# — Rank 700 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_700.pkl)
# Relative ℓ₂ error on singular values: 5.112e-01
# Top 10 σ(M_r): [2.6165, 2.4938, 2.4361, 2.3241, 2.3012, 2.2625, 2.1824, 2.1579, 2.1463, 2.0839]
# Top 10 σ(A)  : [1.5397, 1.5252, 1.4921, 1.4525, 1.4359, 1.4262, 1.4092, 1.4011, 1.387, 1.3713]
#
# — Rank 725 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_725.pkl)
# Relative ℓ₂ error on singular values: 5.144e-01
# Top 10 σ(M_r): [2.6165, 2.4938, 2.4361, 2.3241, 2.3012, 2.2625, 2.1824, 2.1579, 2.1463, 2.0839]
# Top 10 σ(A)  : [1.5408, 1.4875, 1.4682, 1.4554, 1.4309, 1.4133, 1.3899, 1.3802, 1.3642, 1.361]
#
# — Rank 750 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_750.pkl)
# Relative ℓ₂ error on singular values: 5.139e-01
# Top 10 σ(M_r): [2.6165, 2.4938, 2.4361, 2.3241, 2.3012, 2.2625, 2.1824, 2.1579, 2.1463, 2.0839]
# Top 10 σ(A)  : [1.5378, 1.484, 1.4447, 1.4349, 1.4254, 1.4129, 1.3927, 1.3716, 1.3614, 1.3532]
#
# — Rank 775 —  (E2EInvPics/MedMNIST/Matrices\organsmnist\rank_775.pkl)
# Relative ℓ₂ error on singular values: 5.143e-01
# Top 10 σ(M_r): [2.6165, 2.4938, 2.4361, 2.3241, 2.3012, 2.2625, 2.1824, 2.1579, 2.1463, 2.0839]
# Top 10 σ(A)  : [1.5275, 1.4728, 1.4518, 1.4295, 1.3947, 1.3908, 1.3798, 1.3655, 1.3602, 1.3462]
#
# ══════════  RETINAMNIST  ══════════
#
# — Rank  25 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_025.pkl)
# Relative ℓ₂ error on singular values: 5.446e-01
# Top 10 σ(M_r): [1.7294, 1.4676, 1.3727, 1.2621, 1.2019, 1.1747, 1.1502, 1.1227, 1.1051, 1.0903]
# Top 10 σ(A)  : [2.4508, 2.2242, 2.0276, 1.9594, 1.9123, 1.9012, 1.8643, 1.8342, 1.804, 1.7906]
#
# — Rank  50 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_050.pkl)
# Relative ℓ₂ error on singular values: 2.951e-01
# Top 10 σ(M_r): [1.7436, 1.496, 1.3932, 1.2801, 1.2147, 1.1935, 1.1593, 1.1347, 1.1178, 1.1034]
# Top 10 σ(A)  : [2.0827, 1.9186, 1.7186, 1.6582, 1.605, 1.5518, 1.5123, 1.4902, 1.4744, 1.4443]
#
# — Rank  75 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_075.pkl)
# Relative ℓ₂ error on singular values: 3.065e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.933, 1.7532, 1.5733, 1.5173, 1.4859, 1.4462, 1.3863, 1.3498, 1.339, 1.3068]
#
# — Rank 100 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_100.pkl)
# Relative ℓ₂ error on singular values: 3.919e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.8546, 1.6145, 1.4953, 1.4778, 1.4301, 1.3949, 1.3347, 1.2876, 1.264, 1.2358]
#
# — Rank 125 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_125.pkl)
# Relative ℓ₂ error on singular values: 4.659e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.8053, 1.5776, 1.4747, 1.4278, 1.3954, 1.3727, 1.3639, 1.2946, 1.1837, 1.1571]
#
# — Rank 150 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_150.pkl)
# Relative ℓ₂ error on singular values: 5.213e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7392, 1.6013, 1.4995, 1.4034, 1.3792, 1.3674, 1.3446, 1.3307, 1.178, 1.1116]
#
# — Rank 175 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_175.pkl)
# Relative ℓ₂ error on singular values: 5.692e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7103, 1.5981, 1.4999, 1.3842, 1.377, 1.3571, 1.35, 1.3198, 1.1603, 1.0916]
#
# — Rank 200 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_200.pkl)
# Relative ℓ₂ error on singular values: 6.055e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.6827, 1.5813, 1.4747, 1.3733, 1.3555, 1.3303, 1.3125, 1.304, 1.1313, 1.0991]
#
# — Rank 225 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_225.pkl)
# Relative ℓ₂ error on singular values: 6.378e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.656, 1.5918, 1.4281, 1.3613, 1.3419, 1.3275, 1.3063, 1.2995, 1.1746, 1.1233]
#
# — Rank 250 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_250.pkl)
# Relative ℓ₂ error on singular values: 6.573e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.709, 1.5883, 1.4597, 1.357, 1.3508, 1.3302, 1.3198, 1.2859, 1.2106, 1.1552]
#
# — Rank 275 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_275.pkl)
# Relative ℓ₂ error on singular values: 6.847e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7014, 1.5925, 1.4489, 1.3768, 1.3201, 1.2945, 1.2807, 1.2746, 1.2434, 1.1442]
#
# — Rank 300 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_300.pkl)
# Relative ℓ₂ error on singular values: 7.004e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7249, 1.5533, 1.4351, 1.3502, 1.3022, 1.2868, 1.277, 1.269, 1.2231, 1.1462]
#
# — Rank 325 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_325.pkl)
# Relative ℓ₂ error on singular values: 7.191e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7581, 1.5269, 1.455, 1.3503, 1.2971, 1.2859, 1.257, 1.2562, 1.2482, 1.2021]
#
# — Rank 350 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_350.pkl)
# Relative ℓ₂ error on singular values: 7.346e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7385, 1.5374, 1.4572, 1.3432, 1.2958, 1.2936, 1.2752, 1.2574, 1.2264, 1.1788]
#
# — Rank 375 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_375.pkl)
# Relative ℓ₂ error on singular values: 7.453e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7636, 1.5492, 1.4477, 1.3467, 1.3097, 1.2975, 1.2668, 1.2536, 1.2324, 1.2247]
#
# — Rank 400 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_400.pkl)
# Relative ℓ₂ error on singular values: 7.534e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7353, 1.4844, 1.4068, 1.3384, 1.2817, 1.2681, 1.256, 1.2404, 1.234, 1.1985]
#
# — Rank 425 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_425.pkl)
# Relative ℓ₂ error on singular values: 7.651e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7748, 1.4819, 1.4076, 1.3394, 1.2867, 1.2696, 1.2624, 1.2423, 1.2235, 1.2223]
#
# — Rank 450 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_450.pkl)
# Relative ℓ₂ error on singular values: 7.744e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7623, 1.5138, 1.4393, 1.3272, 1.3012, 1.2719, 1.2534, 1.2434, 1.2375, 1.205]
#
# — Rank 475 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_475.pkl)
# Relative ℓ₂ error on singular values: 7.816e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7682, 1.5478, 1.4538, 1.3235, 1.2804, 1.2701, 1.2634, 1.2329, 1.2185, 1.2172]
#
# — Rank 500 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_500.pkl)
# Relative ℓ₂ error on singular values: 7.883e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7695, 1.4728, 1.3719, 1.3281, 1.2861, 1.2756, 1.2459, 1.2364, 1.2288, 1.2053]
#
# — Rank 525 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_525.pkl)
# Relative ℓ₂ error on singular values: 7.964e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7454, 1.4652, 1.4151, 1.3114, 1.3013, 1.2693, 1.2604, 1.2466, 1.2354, 1.2205]
#
# — Rank 550 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_550.pkl)
# Relative ℓ₂ error on singular values: 8.022e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7799, 1.5037, 1.4473, 1.3072, 1.2776, 1.2624, 1.2575, 1.2467, 1.2185, 1.2112]
#
# — Rank 575 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_575.pkl)
# Relative ℓ₂ error on singular values: 8.068e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7906, 1.499, 1.4504, 1.3168, 1.2772, 1.2545, 1.2496, 1.2424, 1.2231, 1.2163]
#
# — Rank 600 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_600.pkl)
# Relative ℓ₂ error on singular values: 8.110e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7807, 1.5158, 1.4199, 1.332, 1.272, 1.2627, 1.2528, 1.2367, 1.2138, 1.2084]
#
# — Rank 625 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_625.pkl)
# Relative ℓ₂ error on singular values: 8.171e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7812, 1.4543, 1.3449, 1.2979, 1.2772, 1.2627, 1.2506, 1.2451, 1.2278, 1.2028]
#
# — Rank 650 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_650.pkl)
# Relative ℓ₂ error on singular values: 8.178e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.794, 1.5097, 1.4321, 1.3096, 1.2618, 1.2493, 1.2439, 1.2326, 1.2225, 1.2071]
#
# — Rank 675 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_675.pkl)
# Relative ℓ₂ error on singular values: 8.258e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7547, 1.4557, 1.359, 1.3283, 1.2856, 1.2626, 1.2525, 1.2322, 1.2257, 1.2138]
#
# — Rank 700 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_700.pkl)
# Relative ℓ₂ error on singular values: 8.296e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7689, 1.5399, 1.4648, 1.3238, 1.2745, 1.2543, 1.2424, 1.2275, 1.2153, 1.1977]
#
# — Rank 725 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_725.pkl)
# Relative ℓ₂ error on singular values: 8.320e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7878, 1.4706, 1.4034, 1.3034, 1.2711, 1.2685, 1.2455, 1.2255, 1.2124, 1.1893]
#
# — Rank 750 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_750.pkl)
# Relative ℓ₂ error on singular values: 8.364e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7995, 1.5026, 1.4311, 1.3057, 1.2802, 1.2568, 1.2484, 1.2284, 1.2161, 1.2099]
#
# — Rank 775 —  (E2EInvPics/MedMNIST/Matrices\retinamnist\rank_775.pkl)
# Relative ℓ₂ error on singular values: 8.381e-01
# Top 10 σ(M_r): [1.7442, 1.4966, 1.3936, 1.281, 1.2154, 1.1939, 1.1596, 1.1354, 1.1181, 1.1036]
# Top 10 σ(A)  : [1.7811, 1.4504, 1.3587, 1.3149, 1.2673, 1.2596, 1.2493, 1.2311, 1.2268, 1.2098]
